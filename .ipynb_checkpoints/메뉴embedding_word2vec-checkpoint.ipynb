# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.input_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>"))
display(HTML("<style>.output_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.input_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>
# <style>.output_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/15/89/b785d557e3c806abc8beaae664571d71e8c4eb736a2c32b69aba9932cbd1/gensim-4.0.1-cp37-cp37m-win_amd64.whl (23.9MB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Using cached https://files.pythonhosted.org/packages/e9/90/6ca525991e281ecdf204c5c1de854da6334068e44121c384b68c6a838e14/smart_open-5.1.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.11.3 in c:\anaconda3\lib\site-packages (from gensim) (1.20.1)
# Requirement already satisfied: scipy>=0.18.1 in c:\anaconda3\lib\site-packages (from gensim) (1.2.1)
# Collecting Cython==0.29.21 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/79/f4/28002920834b292a4dece255d59860c9996d16002f1bca30d7794e0b7884/Cython-0.29.21-cp37-cp37m-win_amd64.whl (1.6MB)
# Installing collected packages: smart-open, Cython, gensim
#   Found existing installation: Cython 0.29.12
#     Uninstalling Cython-0.29.12:
#       Successfully uninstalled Cython-0.29.12
# Successfully installed Cython-0.29.21 gensim-4.0.1 smart-open-5.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
# Out:
# C:\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# HYPER PARAMETERS

class CFG:
    emb_dim = 200

args = CFG

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %% [markdown]
# # Word Embedding

# %%
df_all = pd.concat([df_train, df_test])

# %%
df_all.head(2)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0

# %%
# Basic text preprocessing

def split_process(x, q):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    return x_

# %%
# Get all combinations for training w2v (train + test)

food_combinations = []
for i in ['조식메뉴', '중식메뉴', '석식메뉴']:
    food_combinations += df_all[i].apply(lambda x: split_process(x, i)).to_list()

# %%
len(food_combinations)
# Out:
# 3765

# %%
food_combinations
# Out:
# [['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '쥐어채무침',
#   '찐빵',
#   '된장찌개',
#   '계란후라이',
#   '두유',
#   '호두죽',
#   '포기김치'],
#  ['시래기조림',
#   '주스',
#   '호박젓국찌개',
#   '팥죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '단호박샌드'],
#  ['느타리호박볶음',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '콩나물국',
#   '표고버섯죽',
#   '베이글',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '멸치볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '닭죽',
#   '토마토샌드',
#   '근대국',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '쇠고기죽', '계란후라이', '두유', '포기김치', '방풍나물', '재첩국'],
#  ['감자찌개',
#   '견과류죽',
#   '주스',
#   '우유',
#   '쌀밥',
#   '명엽채무침',
#   '팬케익',
#   '찐빵',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '야채샌드',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '봄동된장국',
#   '고구마죽',
#   '숙주나물',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '잣죽',
#   '콩조림',
#   '치즈프레즐',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스', '김구이', '우유', '모닝롤', '쌀밥', '어묵국', '마늘빵', '단호박죽', '계란후라이', '두유', '포기김치'],
#  ['무생채',
#   '주스',
#   '모닝롤',
#   '우유',
#   '흑임자죽',
#   '쌀밥',
#   '북어계란국',
#   '참치샌드',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스', '인절미토스트', '선지해장국', '톳두부무침', '우유', '모닝롤', '계란후라이', '두유', '포기김치'],
#  ['홍합탕',
#   '주스',
#   '밤죽',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '오이생채',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스', '고추장찌개', '우유', '모닝롤', '쌀밥', '팬케익', '브로컬리죽', '계란후라이', '시금치나물', '포기김치'],
#  ['주스', '야채샌드', '우유', '모닝롤', '쌀밥', '참나물땅콩가루무침', '닭죽', '계란후라이', '포기김치', '재첩국'],
#  ['김치죽', '주스', '우유', '모닝롤', '꿀호떡', '쌀밥', '포기김치', '무채국', '계란후라이', '애호박나물'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '봄동된장국', '쇠고기죽', '어묵볶음', '계란후라이', '포기김치'],
#  ['시래기조림', '주스', '밤죽', '꽃게탕', '우유', '모닝롤', '계란후라이', '쌀밥', '에그샌드', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '곰피초장',
#   '계란후라이',
#   '두유',
#   '호두죽',
#   '포기김치',
#   '콩나물김치국'],
#  ['주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '올갱이아욱국',
#   '오이무침',
#   '단팥빵',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '참치야채죽'],
#  ['주스',
#   '팥죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '가지볶음',
#   '피바지락국',
#   '계란후라이',
#   '두유',
#   '바나나샌드',
#   '포기김치'],
#  ['주스',
#   '볼어묵볶음',
#   '야채죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '사과파이',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '시금치국'],
#  ['쑥갓무침',
#   '주스',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브라우니',
#   '무채국',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '호박젓국찌개',
#   '고구마샌드',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '유채나물',
#   '새송이죽',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '어묵국', '단호박죽', '롤케익', '김자반', '계란후라이', '두유', '포기김치'],
#  ['주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '명엽채무침',
#   '냉이된장국',
#   '햄치즈샌드',
#   '계란후라이',
#   '두유',
#   '녹두죽',
#   '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '찐빵',
#   '고구마죽',
#   '검정콩조림',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '재첩국'],
#  ['주스', '우유', '모닝롤', '쌀밥', '황태국', '롤케이크', '미역줄기볶음', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스', '쇠고기무국', '우유', '모닝롤', '계란후라이', '쌀밥', '브로컬리들깨찜', '에그샌드', '해물죽', '포기김치'],
#  ['느타리호박볶음',
#   '주스',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '시래기국',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치'],
#  ['베이컨샌드', '주스', '모닝롤', '우유', '쌀밥', '숙주나물', '브로컬리죽', '오징어국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '표고버섯죽', '계란후라이', '들깨미역국', '포기김치', '방풍나물'],
#  ['김치죽', '주스', '김실파무침', '우유', '모닝롤', '쌀밥', '마늘빵', '무채국', '계란후라이', '포기김치'],
#  ['주스',
#   '선지해장국',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '브로컬리초장',
#   '계란후라이',
#   '포기김치',
#   '참치야채죽'],
#  ['주스', '모닝롤', '우유', '새송이버섯죽', '쌀밥', '쑥갓두부무침', '카스텔라', '근대국', '계란후라이', '포기김치'],
#  ['주스', '밤죽', '순두부국', '우유', '모닝롤', '쌀밥', '토마토샌드', '계란후라이', '크랜베리멸치볶음', '포기김치'],
#  ['진미채무침', '견과류죽', '주스', '우유', '모닝롤', '와플', '쌀밥', '콩나물국', '계란후라이', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '새우살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '포기김치',
#   '계란후라이',
#   '두부김치국',
#   '미역레몬초무침'],
#  ['주스', '야채죽', '쇠고기버섯국', '모닝롤', '우유', '쌀밥', '참치샌드', '오이무침', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '감자국', '닭죽', '참나물무침', '핫도그', '계란후라이', '포기김치'],
#  ['바지락쑥국', '주스', '모닝롤', '우유', '늙은호박죽', '쌀밥', '마늘쫑무침', '단팥빵', '계란후라이', '포기김치'],
#  ['구이김', '주스', '야채샌드', '민물새우찌개', '우유', '모닝롤', '쌀밥', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '팬케익', '잣죽', '마늘쫑무침', '근대국', '계란후라이', '두유', '포기김치'],
#  ['양송이죽',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '두부젓국찌개',
#   '미역줄기볶음',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '단호박샌드'],
#  ['주스',
#   '꽃게탕',
#   '팥죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '치즈프레즐',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '방풍나물'],
#  ['진미채무침',
#   '주스',
#   '우유',
#   '모닝롤',
#   '흑임자죽',
#   '쌀밥',
#   '치킨샌드',
#   '열무된장국',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브라우니',
#   '고구마죽',
#   '콩조림',
#   '계란후라이',
#   '두유',
#   '포기김치',
#   '대구찌개'],
#  ['견과류죽',
#   '주스',
#   '고추장찌개',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '마늘빵',
#   '김자반',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '쇠고기죽',
#   '감자채볶음',
#   '얼갈이된장국',
#   '계란후라이',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '쌀밥',
#   '황태국',
#   '콩나물무침',
#   '브로컬리죽',
#   '에그샌드',
#   '두유',
#   '포기김치'],
#  ['주스',
#   '새우살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '크로와상',
#   '계란후라이',
#   '두유',
#   '시금치나물',
#   '포기김치',
#   '재첩국'],
#  ['주스', '우유', '모닝롤', '꿀호떡', '쌀밥', '감자국', '오이무침', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '콩나물국',
#   '곤약어묵볶음',
#   '표고버섯죽',
#   '토마토샌드',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '홍게살죽', '느타리볶음', '우유', '모닝롤', '쌀밥', '포기김치', '베이글', '계란후라이', '김치국'],
#  ['비름나물', '주스', '고구마샌드', '선지해장국', '우유', '모닝롤', '늙은호박죽', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '카스텔라', '고구마죽', '숙주나물', '아욱국', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '김구이', '땅콩죽', '차돌박이찌개', '우유', '모닝롤', '쌀밥', '계란후라이', '포기김치'],
#  ['베이컨샌드', '주스', '연두부탕', '모닝롤', '우유', '쌀밥', '열무나물', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '매운어묵국', '닭죽', '감자채볶음', '계란후라이', '포기김치'],
#  ['주스', '우거지해장국', '우유', '모닝롤', '쌀밥', '마늘쫑볶음', '표고버섯죽', '롤케익', '계란후라이', '포기김치'],
#  ['김치죽', '진미채무침', '주스', '야채햄샌드', '우유', '모닝롤', '쌀밥', '계란후라이', '우렁살된장국', '포기김치'],
#  ['주스', '호박젓국찌개', '야채죽', '우유', '모닝롤', '쌀밥', '마늘빵', '김자반', '계란후라이', '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '오이도라지무침', '계란후라이', '포기김치', '옥수수샌드', '재첩국'],
#  ['주스', '밤죽', '우유', '모닝롤', '쌀밥', '찐빵', '브로컬리들깨찜', '계란후라이', '포기김치', '콩나물김치국'],
#  ['진미채무침', '들깨미역국', '주스', '우유', '모닝롤', '쌀밥', '팬케익', '계란후라이', '호두죽', '포기김치'],
#  ['주스', '우유', '모닝롤', '계란후라이', '쌀밥', '브로컬리죽', '감자채볶음', '근대국', '에그샌드', '포기김치'],
#  ['주스', '홍게살죽', '호박나물', '우유', '모닝롤', '쌀밥', '크로와상', '느타리버섯국', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '모닝롤', '우유', '쌀밥', '북어계란국', '참치샌드', '취나물', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '노각무침', '아욱국', '치즈프레즐', '계란후라이', '흑임자죽', '포기김치'],
#  ['프렌치토스트', '주스', '연두부탕', '우유', '모닝롤', '쌀밥', '잣죽', '김자반', '계란후라이', '포기김치'],
#  ['주스', '새우살죽', '스크램블에그', '느타리볶음', '모닝롤', '우유', '쌀밥', '콩나물국', '햄치즈샌드', '포기김치'],
#  ['주스', '민물새우찌개', '모닝롤', '우유', '쌀밥', '쇠고기죽', '어묵볶음', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '명엽채무침', '포기김치', '대구찌개', '양송이죽'],
#  ['주스', '우유', '모닝롤', '쌀밥', '단호박죽', '머위대나물', '근대국', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '마늘빵', '얼갈이된장국', '계란후라이', '포기김치', '미역레몬초무침'],
#  ['주스', '스크램블에그', '인절미토스트', '김구이', '우유', '모닝롤', '쌀밥', '콩나물국', '녹두죽', '포기김치'],
#  ['김치죽', '주스', '야채샌드', '우유', '모닝롤', '쌀밥', '검정콩조림', '계란후라이', '열무김치', '올갱이아욱국'],
#  ['주스', '스크램블에그', '소라살죽', '우유', '모닝롤', '쌀밥', '어묵국', '마늘쫑무침', '베이글', '포기김치'],
#  ['주스', '밤죽', '우유', '모닝롤', '식빵피자', '쌀밥', '브로컬리초장', '피바지락국', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '카스텔라', '멸치캐슈넛볶음', '계란후라이', '흑임자죽', '포기김치', '미역국'],
#  ['가지나물', '주스', '새우살죽', '쇠고기무국', '우유', '모닝롤', '쌀밥', '치킨샌드', '계란후라이', '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '브라우니', '김자반', '계란후라이', '포기김치', '홍초콩나물국'],
#  ['주스', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '황태국', '포기김치', '에그샌드', '애호박나물'],
#  ['주스', '홍게살죽', '사각어묵무침', '우유', '모닝롤', '쌀밥', '크로와상', '무채국', '계란후라이', '열무김치'],
#  ['견과류죽', '주스', '모닝롤', '우유', '쌀밥', '명엽채무침', '포기김치', '치즈프레즐', '계란후라이', '두부김치국'],
#  ['주스', '우유', '모닝롤', '쌀밥', '오이생채', '고구마죽', '아욱국', '계란후라이', '바나나샌드', '포기김치'],
#  ['주스', '스크램블에그', '모닝롤', '우유', '늙은호박죽', '쌀밥', '느타리버섯국', '핫도그', '숙주나물', '포기김치'],
#  ['주스', '꽃게탕', '우유', '모닝롤', '쌀밥', '토마토샌드', '취나물', '계란후라이', '포기김치', '참치야채죽'],
#  ['멸치고추장무침',
#   '프렌치토스트',
#   '주스',
#   '쇠고기무국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '잣죽',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '새송이버섯볶음', '계란후라이', '동태찌개', '녹두죽', '포기김치', '옥수수샌드'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '쇠고기죽', '감자채볶음', '계란후라이', '포기김치', '시금치국'],
#  ['베이컨샌드',
#   '고구마순나물',
#   '주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '콩나물국',
#   '표고버섯죽',
#   '계란후라이',
#   '포기김치'],
#  ['느타리호박볶음', '주스', '우거지해장국', '우유', '모닝롤', '쌀밥', '팬케익', '닭죽', '계란후라이', '포기김치'],
#  ['진미채무침', '주스', '야채죽', '우유', '모닝롤', '쌀밥', '근대된장국', '마늘빵', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '김치콩나물국', '우유', '모닝롤', '쌀밥', '김자반', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스', '스크램블에그', '팥죽', '우유', '모닝롤', '쌀밥', '노각무침', '롤케익', '오징어국', '포기김치'],
#  ['주스', '홍게살죽', '우유', '모닝롤', '쌀밥', '북어계란국', '치킨샌드', '검정콩조림', '계란후라이', '열무김치'],
#  ['비름나물', '주스', '밤죽', '우유', '모닝롤', '쌀밥', '된장찌개', '베이글', '계란후라이', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '쥐어채무침',
#   '계란후라이',
#   '포기김치',
#   '북어콩나물국'],
#  ['주스', '녹두죽', '느타리볶음', '우유', '모닝롤', '쌀밥', '새우살미역국', '계란후라이', '햄야채샌드', '포기김치'],
#  ['주스', '스크램블에그', '애플파이', '모닝롤', '우유', '쌀밥', '포기김치', '잣죽', '동태찌개', '애호박나물'],
#  ['가지나물', '주스', '소고기무국', '모닝롤', '우유', '쌀밥', '단호박죽', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '볼어묵조림', '모닝롤', '우유', '쌀밥', '참치샌드', '브로컬리죽', '계란후라이', '포기김치', '시금치국'],
#  ['두부조림', '주스', '모닝롤', '우유', '쌀밥', '카스텔라', '무채국', '계란후라이', '호두죽', '포기김치'],
#  ['주스', '꽃게탕', '시금치나물', '우유', '모닝롤', '쌀밥', '표고버섯죽', '계란후라이', '바나나샌드', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '명엽채무침', '크로와상', '닭죽', '느타리버섯국', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '씨크립샌드',
#   '김치콩나물국',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '멸치호두볶음',
#   '쇠고기죽',
#   '포기김치'],
#  ['김치죽', '주스', '모닝롤', '우유', '쌀밥', '머위대나물', '치즈프레즐', '근대국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '마늘쫑볶음', '감자국', '베이글', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스',
#   '홍게살죽',
#   '쇠고기무국',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '쌀밥',
#   '숙주미나리나물',
#   '에그샌드',
#   '포기김치'],
#  ['고구마순나물',
#   '주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브라우니',
#   '포기김치',
#   '대구찌개',
#   '참치야채죽'],
#  ['진미채무침', '주스', '모닝롤', '우유', '쌀밥', '새송이죽', '햄치즈샌드', '계란후라이', '새알미역국', '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '포기김치', '찐빵', '김자반', '계란후라이', '두부김치국'],
#  ['프렌치토스트', '주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '명엽채무침', '계란후라이', '포기김치', '시금치국'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '어묵국', '토마토샌드', '녹두죽', '콩자반', '포기김치'],
#  ['양송이죽', '주스', '우유', '모닝롤', '쌀밥', '무채국', '오이무침', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '우유', '모닝롤', '쌀밥', '버섯볶음', '근대된장국', '계란후라이', '해물죽', '포기김치', '옥수수샌드'],
#  ['주스', '멸치볶음', '우유', '모닝롤', '쌀밥', '북어계란국', '닭죽', '계란후라이', '포기김치', '바나나팬케이크'],
#  ['주스', '누룽지탕', '김실파무침', '민물새우찌개', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치'],
#  ['김치죽', '바지락콩나물국', '주스', '우유', '모닝롤', '식빵피자', '쌀밥', '시래기나물', '계란후라이', '포기김치'],
#  ['주스', '고추장찌개', '누룽지탕', '모닝롤', '우유', '쌀밥', '브로컬리들깨찜', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '새우살죽', '우유', '모닝롤', '계란후라이', '쌀밥', '감자국', '숙주나물', '에그샌드', '포기김치'],
#  ['주스', '스크램블', '모닝롤', '우유', '쌀밥', '포기김치', '카스텔라', '북어국', '쇠고기죽', '애호박나물'],
#  ['프렌치토스트',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '사각어묵볶음',
#   '보리누룽지탕',
#   '근대국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '새송이볶음', '단호박죽', '오징어국', '포기김치'],
#  ['주스', '누룽지탕', '차돌박이찌개', '모닝롤', '우유', '쌀밥', '김자반', '치즈프레즐', '계란후라이', '포기김치'],
#  ['주스',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '참치샌드',
#   '느타리버섯국',
#   '구운계란',
#   '크랜베리멸치볶음',
#   '포기김치'],
#  ['주스', '홍게살죽', '우유', '모닝롤', '쌀밥', '크로와상', '아삭고추무침', '계란후라이', '동태찌개', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '김치두부국', '롤케익', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '호박볶음', '포기김치', '올갱이아욱국'],
#  ['고구마순나물', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '베이글', '새우살미역국', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '쇠고기샤브국', '우유', '모닝롤', '쌀밥', '구운계란', '녹두죽', '참나물땅콩무침', '포기김치'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '감자국', '가지볶음', '계란후라이', '해물죽', '포기김치'],
#  ['진미채무침', '주스', '스크램블에그', '우유', '모닝롤', '꿀호떡', '쌀밥', '잣죽', '북어국', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '어묵국', '콩나물무침', '토마토샌드', '계란후라이', '포기김치'],
#  ['주스', '우거지해장국', '우유', '모닝롤', '쌀밥', '브라우니', '구운계란', '미역줄기볶음', '흑임자죽', '포기김치'],
#  ['도라지나물', '주스', '우유', '모닝롤', '쌀밥', '쇠고기죽', '오징어국', '계란후라이', '포기김치', '옥수수샌드'],
#  ['주스', '우거지해장국', '스크램블에그', '우유', '모닝롤', '와플', '쌀밥', '잣죽', '새송이버섯볶음', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '꽈리고추찜', '호박죽', '조랭이떡미역국', '참치샌드', '계란후라이', '포기김치'],
#  ['애호박볶음', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '북어국', '계란후라이', '포기김치'],
#  ['김잔파무침', '주스', '우유', '모닝롤', '쌀밥', '고구마죽', '인절미샌드', '구운계란', '포기김치', '시금치국'],
#  ['도라지나물', '주스', '누룽지탕', '민물새우찌깨', '모닝롤', '우유', '쌀밥', '카스텔라', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '느타리버섯국', '김자반', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '쌀밥', '명엽채무침', '구운계란', '근대국', '바나나샌드', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '사과파이',
#   '곤약어묵볶음',
#   '크림누룽지탕',
#   '포기김치',
#   '대구찌개'],
#  ['김치죽', '고구마순나물', '주스', '우유', '쌀밥', '콩나물국', '구운계란', '포기김치', '햄에그치즈토스트'],
#  ['가지나물', '주스', '팥죽', '우유', '모닝롤', '쌀밥', '크로와상', '계란후라이', '포기김치', '맑은만두육개장'],
#  ['주스', '호박젓국찌개', '누룽지탕', '바나나팬케익', '우유', '모닝롤', '쌀밥', '감자조림', '구운계란', '포기김치'],
#  ['구이김', '주스', '콩나물된장국', '스크램블에그', '우유', '모닝롤', '쌀밥', '에그샌드', '해물죽', '포기김치'],
#  ['진미채무침', '주스', '누룽지탕', '쇠고기무국', '우유', '모닝롤', '쌀밥', '베이글', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '늙은호박죽', '쌀밥', '김치두부국', '취나물', '구운계란', '햄치즈샌드', '포기김치'],
#  ['주스', '아욱된장국', '땅콩죽', '모닝롤', '우유', '쌀밥', '단팥빵', '계란후라이', '포기김치', '미역줄기볶음'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '쌀밥', '김자반', '구운계란', '포기김치', '고구마파이'],
#  ['주스', '스크램블에그', '멸치볶음', '우유', '모닝롤', '쌀밥', '감자국', '토마토샌드', '새송이죽', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '와플', '쌀밥', '북어해장국', '구운계란', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '쇠고기미역국', '명엽채무침', '잣죽', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '사과파이',
#   '김가루실파무침',
#   '버섯들깨탕',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '포기김치',
#   '된장찌개',
#   '구운계란',
#   '쇠고기죽',
#   '브로컬리들깨무침',
#   '옥수수샌드'],
#  ['주스', '모닝롤', '우유', '쌀밥', '포기김치', '카스텔라', '숙주나물', '크림누룽지탕', '계란후라이', '김치국'],
#  ['프렌치토스트', '주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '쌀밥', '미역줄기볶음', '계란후라이', '포기김치'],
#  ['도라지나물',
#   '주스',
#   '스크램블에그',
#   '씨크립샌드',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '흑임자죽',
#   '포기김치'],
#  ['무생채', '주스', '수삼닭죽', '모닝롤', '우유', '쌀밥', '치즈프레즐', '계란후라이', '포기김치', '맑은만두육개장'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '치커리무침', '감자국', '구운계란', '에그샌드', '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '콩나물국',
#   '크로와상',
#   '단호박죽',
#   '계란후라이',
#   '크랜베리멸치볶음',
#   '포기김치'],
#  ['후르츠팬케익', '견과류죽', '주스', '우유', '모닝롤', '쌀밥', '북어채국', '김자반', '구운계란', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '어묵국', '참치샌드', '감자채볶음', '포기김치'],
#  ['주스', '고추장찌개', '우유', '모닝롤', '쌀밥', '브라우니', '구구마순나물', '구운계란', '해물죽', '포기김치'],
#  ['베이컨샌드', '시래기조림', '주스', '팥죽', '모닝롤', '우유', '쌀밥', '연두부탕', '계란후라이', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '호박젓국찌개',
#   '홍게살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '검정콩조림',
#   '구운계란',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '오징어국', '계란후라이', '바나나샌드', '포기김치', '미역나물', '양송이죽'],
#  ['주스', '스크램블에그', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '롤케익', '얼큰소고기국', '포기김치'],
#  ['주스', '우유', '모닝롤', '식빵피자', '쌀밥', '꽈리고추찜', '김치두부국', '구운계란', '브로컬리죽', '포기김치'],
#  ['진미채무침', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '아욱국', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '명엽채무침', '감자국', '마늘빵', '구운계란', '흑임자죽', '포기김치'],
#  ['주스', '야채샌드', '매운버섯국', '시금치나물', '우유', '모닝롤', '쌀밥', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '북어해장국', '베이글', '감자채볶음', '포기김치'],
#  ['주스', '고추장찌개', '씨크립샌드', '모닝롤', '우유', '늙은호박죽', '쌀밥', '연근조림', '구운계란', '포기김치'],
#  ['주스', '누룽지탕', '쇠고기무국', '우유', '모닝롤', '쌀밥', '프레즐', '콩나물무침', '계란후라이', '포기김치'],
#  ['삶은계란', '고구마순나물', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '어묵국', '포기김치'],
#  ['견과류죽', '주스', '모닝롤', '우유', '쌀밥', '근대국', '오이무침', '햄치즈샌드', '계란후라이', '포기김치'],
#  ['삶은계란',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '연두부찌개',
#   '마늘쫑맛살볶음',
#   '포기김치',
#   '단호박샌드'],
#  ['가지나물',
#   '주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '모시조개시금치국',
#   '호박죽',
#   '포기김치',
#   '고구마파이'],
#  ['주스', '인절미토스트', '야채죽', '우유', '모닝롤', '쌀밥', '콩나물국', '쥐포무침', '계란후라이', '포기김치'],
#  ['후르츠팬케익',
#   '주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '호박볶음',
#   '들깨미역국',
#   '포기김치'],
#  ['주스', '아욱된장국', '우유', '모닝롤', '계란후라이', '쌀밥', '쇠고기죽', '콩조림', '에그샌드', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '크로와상', '김자반', '포기김치', '대구찌개'],
#  ['삶은계란', '두부조림', '주스', '우유', '모닝롤', '쌀밥', '시래기국', '토마토샌드', '포기김치', '양송이죽'],
#  ['주스', '우유', '모닝롤', '쌀밥', '브라우니', '포기김치', '김치두부국', '닭죽', '계란후라이', '브로컬리들깨무침'],
#  ['김잔파무침', '주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘빵', '북어해장국', '포기김치'],
#  ['주스',
#   '고추장찌개',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '청포묵무침',
#   '크림누룽지탕',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '애플파이',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '시금치나물',
#   '포기김치',
#   '맑은만두육개장'],
#  ['삶은계란', '주스', '어묵탕', '야채죽', '우유', '모닝롤', '식빵피자', '쌀밥', '마늘쫑무침', '포기김치'],
#  ['주스', '건새우무국', '가지두반장볶음', '우유', '모닝롤', '쌀밥', '롤케익', '계란후라이', '흑임자죽', '포기김치'],
#  ['진미채무침', '주스', '스크램블에그', '누룽지탕', '바나나팬케익', '우유', '모닝롤', '쌀밥', '감자국', '포기김치'],
#  ['시래기조림', '주스', '밤죽', '우유', '모닝롤', '계란후라이', '쌀밥', '피바지락국', '에그샌드', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '우엉조림', '찐빵', '얼큰소고기국', '포기김치'],
#  ['삶은계란', '주스', '호박젓국찌개', '야채샌드', '홍게살죽', '우유', '모닝롤', '쌀밥', '미역줄기볶음', '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '근대된장국', '콩나물무침', '계란후라이', '포기김치', '고구마파이'],
#  ['프렌치토스트',
#   '주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '콩나물국',
#   '쑥갓두부무침',
#   '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '명엽채무침', '참치샌드', '무채국', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '꽈리고추찜', '포기김치', '재첩국'],
#  ['삶은계란', '주스', '우유', '모닝롤', '쌀밥', '단호박죽', '아욱국', '숙주미나리나물', '바나나샌드', '포기김치'],
#  ['주스', '꽃게탕', '모닝롤', '우유', '쌀밥', '느타리버섯볶음', '치즈프레즐', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '호박젓국찌개', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '치커리무침', '단팥빵', '포기김치'],
#  ['주스', '새우살죽', '우유', '모닝롤', '쌀밥', '어묵국', '방풍나물', '계란후라이', '포기김치', '옥수수샌드'],
#  ['주스', '고추장찌개', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '카스텔라', '김자반', '포기김치'],
#  ['삶은계란', '주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '토마토샌드', '쥐포무침', '포기김치', '배추된장국'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '새송이볶음', '황태국', '베이글', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘빵', '무채국', '오이무침', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '포기김치', '북어계란국', '롤케익', '계란후라이', '흑임자죽', '애호박나물'],
#  ['두부조림', '주스', '냉이국', '고구마샌드', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '포기김치'],
#  ['삶은계란', '시래기조림', '주스', '호박젓국찌개', '야채샌드', '우유', '모닝롤', '쌀밥', '닭죽', '포기김치'],
#  ['진미채무침', '주스', '우유', '모닝롤', '쌀밥', '베이글', '얼갈이국', '계란후라이', '해물죽', '포기김치'],
#  ['프렌치토스트', '주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '꽃맛살볶음', '토란국', '포기김치'],
#  ['주스',
#   '선지해장국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '검정콩조림',
#   '크림누룽지탕',
#   '계란후라이',
#   '바나나샌드',
#   '포기김치'],
#  ['녹차카스테라',
#   '주스',
#   '스크램블에그',
#   '누룽지탕',
#   '연두부탕',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '미역줄기볶음',
#   '포기김치'],
#  ['삶은계란', '주스', '씨크립샌드', '모닝롤', '우유', '쌀밥', '어묵국', '콩나물무침', '포기김치', '참치야채죽'],
#  ['주스', '김구이', '모닝롤', '우유', '쌀밥', '잣죽', '치즈프레즐', '계란후라이', '포기김치', '재첩국'],
#  ['주스', '스크램블에그', '누룽지탕', '멸치볶음', '우유', '모닝롤', '쌀밥', '팬케익', '김치두부국', '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '미니새송이볶음',
#   '열무된장국',
#   '계란후라이',
#   '해물죽',
#   '포기김치',
#   '단호박샌드'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '쇠고기매운국', '크로와상', '김자반', '포기김치'],
#  ['삶은계란', '주스', '우유', '모닝롤', '쌀밥', '명엽채무침', '근대국', '에그샌드', '포기김치', '양송이죽'],
#  ['주스', '고추장찌개', '우유', '모닝롤', '쌀밥', '브라우니', '호박죽', '계란후라이', '시금치나물', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '아욱국', '쥐포무침', '포기김치'],
#  ['베이컨샌드',
#   '주스',
#   '홍게살죽',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '브로컬리들깨찜',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '북어계란국',
#   '느타리호박볶음',
#   '포기김치',
#   '고구마파이'],
#  ['삶은계란', '주스', '모닝롤', '우유', '쌀밥', '유채나물', '감자국', '새송이죽', '햄치즈샌드', '포기김치'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '매운어묵국', '쇠고기죽', '취나물', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '냉이된장국', '마늘빵', '콩자반', '포기김치'],
#  ['주스', '새우살죽', '인절미토스트', '차돌박이찌개', '우유', '모닝롤', '쌀밥', '톳무침', '계란후라이', '포기김치'],
#  ['진미채무침', '주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '토란탕', '포기김치'],
#  ['삶은계란', '주스', '밤죽', '연두부탕', '우유', '모닝롤', '쌀밥', '오이무침', '토마토샌드', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '포기김치', '베이글', '쇠고기죽', '겨울초나물', '계란후라이', '김치국'],
#  ['두부조림',
#   '주스',
#   '누룽지탕',
#   '바나나팬케익',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '느타리버섯국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '피자토스트', '숙주나물', '근대국', '계란후라이', '해물죽', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '꿀호떡',
#   '쌀밥',
#   '미역줄기볶음',
#   '포기김치',
#   '맑은만두육개장'],
#  ['주스', '씨크립샌드', '모닝롤', '우유', '쌀밥', '마늘쫑무침', '계란후라이', '흑임자죽', '포기김치', '재첩국'],
#  ['주스', '우유', '모닝롤', '쌀밥', '찐빵', '북어국', '무채나물', '크림누룽지탕', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '고추장찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '취나물', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '스크램블에그', '팥죽', '우유', '모닝롤', '쌀밥', '어묵볶음', '열무된장국', '포기김치'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '롤케익', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '땅콩죽',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '포기김치',
#   '참치샌드',
#   '브로컬리무침'],
#  ['주스',
#   '소라살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '새송이볶음',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치',
#   '콩나물김치국'],
#  ['가지나물', '주스', '누룽지탕', '우유', '모닝롤', '시금치핫케익', '쌀밥', '북어계란국', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '느타리볶음', '우유', '모닝롤', '쌀밥', '크로와상', '단호박죽', '근대국', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '두부젓국찌개', '김자반', '토마토샌드', '계란후라이', '포기김치'],
#  ['크래미숙주무침', '주스', '스크램블에그', '야채죽', '우유', '모닝롤', '와플', '쌀밥', '오징어국', '포기김치'],
#  ['주스', '스크램블에그', '김구이', '땅콩죽', '꽃게탕', '모닝롤', '우유', '쌀밥', '치즈프레즐', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '황태국', '검정콩조림', '계란후라이', '포기김치', '옥수수샌드'],
#  ['시금치죽', '주스', '스크램블에그', '선지해장국', '우유', '모닝롤', '쌀밥', '연근조림', '포기김치', '고구마파이'],
#  ['홍합탕', '겨울초겉절이', '주스', '우유', '모닝롤', '쌀밥', '새송이죽', '계란후라이', '바나나샌드', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '마늘빵',
#   '느타리호박볶음',
#   '포기김치',
#   '콩나물김치국'],
#  ['가지나물', '양송이죽', '주스', '재첩국', '우유', '모닝롤', '쌀밥', '계란후라이', '포기김치', '단호박샌드'],
#  ['주스', '스크램블에그', '아욱된장국', '우유', '모닝롤', '쌀밥', '사과파이', '호박죽', '어묵볶음', '포기김치'],
#  ['삶은계란', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '감자국', '참치샌드', '오이무침', '포기김치'],
#  ['주스', '우유', '모닝롤', '꿀호떡', '쌀밥', '참나물생채', '닭죽', '맑은연두부탕', '계란후라이', '포기김치'],
#  ['진미채무침',
#   '프렌치토스트',
#   '주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '봄동된장국',
#   '포기김치'],
#  ['주스',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '표고버섯죽',
#   '브로컬리들깨찜',
#   '햄치즈샌드',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '북어국', '아삭고추무침', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '김치콩나물국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '새송이볶음',
#   '고구마죽',
#   '에그샌드',
#   '포기김치'],
#  ['무생채', '주스', '홍게살죽', '우유', '모닝롤', '쌀밥', '베이글', '근대국', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '찐빵',
#   '달래된장찌개',
#   '크랜베리멸치볶음',
#   '포기김치'],
#  ['주스',
#   '고추장찌개',
#   '야채샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '김가루실파무침',
#   '해물죽',
#   '포기김치'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '쌀밥', '브라우니', '명엽채무침', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '호박젓국찌개', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '녹두죽', '포기김치'],
#  ['두부조림', '주스', '아욱된장국', '우유', '모닝롤', '쌀밥', '롤케익', '쇠고기죽', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '건새우무채국', '계란후라이', '토스트', '포기김치'],
#  ['주스', '스크램블에그', '팥죽', '모닝롤', '우유', '쌀밥', '시금치된장국', '참치샌드', '콩자반', '포기김치'],
#  ['시래기조림', '주스', '우유', '모닝롤', '쌀밥', '잣죽', '매운감자국', '계란후라이', '포기김치', '옥수수샌드'],
#  ['쇠고기우거지국', '주스', '스크램블에그', '참나물', '모닝롤', '우유', '쌀밥', '표고버섯죽', '핫도그', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '팬케익', '쑥갓두부무침', '시래기된장국', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '단호박죽', '북어해장국', '햄치즈샌드', '포기김치'],
#  ['주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '마늘빵', '아삭고추무침', '계란후라이', '포기김치', '맑은만두육개장'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '유채나물', '계란후라이', '포기김치', '피자빵', '재첩국'],
#  ['주스', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '크로와상', '미역줄기볶음', '포기김치', '대구찌개'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '감자국', '어묵볶음', '계란후라이', '포기김치'],
#  ['견과류죽', '주스', '스크램블에그', '느타리볶음', '씨크립샌드', '모닝롤', '우유', '쌀밥', '된장찌개', '포기김치'],
#  ['주스', '새우살죽', '모닝롤', '우유', '쌀밥', '두부젓국찌개', '단팥빵', '쥐포무침', '계란후라이', '포기김치'],
#  ['베이컨샌드', '주스', '누룽지탕', '쑥국', '모닝롤', '우유', '쌀밥', '브로컬리들깨찜', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '김치두부국', '김자반', '치즈프레즐', '흑임자죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '시금치핫케익', '쌀밥', '어묵국', '미역줄기볶음', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '홍게살죽', '들깨감자국', '우유', '모닝롤', '쌀밥', '오이생채', '바나나샌드', '포기김치'],
#  ['김치죽', '주스', '김실파무침', '우유', '모닝롤', '쌀밥', '콩나물국', '찐빵', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '와플', '쌀밥', '명엽채볶음', '계란후라이', '포기김치'],
#  ['시래기조림',
#   '주스',
#   '스크램블에그',
#   '선지해장국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '사과파이',
#   '포기김치',
#   '참치야채죽'],
#  ['진미채무침',
#   '프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '건새우아욱국',
#   '계란후라이',
#   '포기김치'],
#  ['배추맑은국', '두부조림', '주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '참치샌드', '브로컬리죽', '포기김치'],
#  ['느타리호박볶음',
#   '주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '시래기들깨탕',
#   '계란후라이',
#   '메론롤케익',
#   '포기김치',
#   '양송이죽'],
#  ['주스',
#   '닭곰탕',
#   '누룽지탕',
#   '인절미토스트',
#   '대추채멸치볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '포기김치', '쇠고기죽', '두부김치국', '미역나물', '고구마파이'],
#  ['무생채', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '감자국', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '팥죽', '모닝롤', '우유', '쌀밥', '콩나물국', '햄치즈샌드', '꽃맛살볶음', '포기김치'],
#  ['주스',
#   '차돌박이찌개',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '크로와상',
#   '검정콩조림',
#   '크림누룽지탕',
#   '계란후라이',
#   '포기김치'],
#  ['깍두기', '주스', '홍게살죽', '우유', '모닝롤', '쌀밥', '단배추나물', '두부들깨탕', '계란후라이', '단호박샌드'],
#  ['가지나물', '견과류죽', '주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '치즈프레즐', '포기김치', '김치황태국'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '콩나물국', '팬케익', '쥐포무침', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '민물새우찌개', '우유', '모닝롤', '쌀밥', '표고버섯죽', '취나물', '에그샌드', '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '유채나물', '쇠고기해장국', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '느타리볶음', '밤죽', '우유', '모닝롤', '쌀밥', '두부젓국찌개', '치킨샌드', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '늙은호박죽',
#   '쌀밥',
#   '베이글',
#   '마늘쫑건새우볶음',
#   '근대국',
#   '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '브라우니', '어묵국', '땅콩조림', '계란후라이', '포기김치'],
#  ['김치죽', '주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '멸치호두볶음', '감자국', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '찐빵', '오징어국', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '매운버섯국', '우유', '모닝롤', '쌀밥', '쑥갓두부무침', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '명엽채무침', '닭죽', '롤케익', '피바지락국', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '근대감자국', '김자반', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '팥죽', '모닝롤', '우유', '쌀밥', '콩나물국', '참치샌드', '우엉어묵볶음', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '된장찌개', '검정콩조림', '계란후라이', '포기김치'],
#  ['애호박볶음', '주스', '야채죽', '우유', '모닝롤', '쌀밥', '북어해장국', '계란후라이', '포기김치', '피자빵'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '사과파이', '오이무침', '흑임자죽', '조랭이떡국', '포기김치'],
#  ['시금치죽', '주스', '야채샌드', '김구이', '우유', '모닝롤', '쌀밥', '황태국', '계란후라이', '포기김치'],
#  ['진미채무침',
#   '주스',
#   '홍게살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '시래기된장국',
#   '계란후라이',
#   '포기김치',
#   '단호박샌드'],
#  ['멸치크랜베리볶음',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '베이글',
#   '열무된장국',
#   '계란후라이',
#   '포기김치'],
#  ['김치죽', '주스', '김구이', '모닝롤', '우유', '쌀밥', '어묵국', '치즈프레즐', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '감자국', '포기김치', '청경채무침'],
#  ['가지나물', '주스', '호박젓국찌개', '스크램블에그', '모닝롤', '우유', '쌀밥', '카스텔라', '해물죽', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '민물새우찌개',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '쑥갓두부무침',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '계란후라이', '쌀밥', '북어채국', '브로컬리들깨찜', '에그샌드', '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '대구매운탕', '검정콩조림', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '우거지해장국',
#   '스크램블에그',
#   '인절미토스트',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '명엽채무침',
#   '참치죽',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '김치두부국', '크로와상', '단호박죽', '계란후라이', '시금치나물', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '어묵국', '마늘빵', '숙주나물', '크림누룽지탕', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '땅콩죽', '우유', '모닝롤', '쌀밥', '김가루실파무침', '오징어국', '계란후라이', '포기김치'],
#  ['애호박볶음', '주스', '닭곰탕', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '감자국', '열무나물', '브로컬리죽', '포기김치', '옥수수샌드'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '맑은만두육개장', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '누룽지탕', '대추채멸치볶음', '우유', '모닝롤', '쌀밥', '계란후라이', '토스트', '포기김치', '미역국'],
#  ['비름나물', '주스', '수삼닭죽', '스크램블에그', '소고기무국', '우유', '모닝롤', '쌀밥', '토마토샌드', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '두부젓국찌개', '베이글', '자반김', '계란후라이', '포기김치'],
#  ['주스',
#   '고구마샌드',
#   '스크램블에그',
#   '밤죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브로컬리들깨소스',
#   '동태찌개',
#   '포기김치'],
#  ['주스',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '건새우아욱국',
#   '감자채볶음',
#   '계란후라이',
#   '메론롤케익',
#   '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '쇠고기버섯국',
#   '우유',
#   '모닝롤',
#   '시금치핫케익',
#   '쌀밥',
#   '쥐포무침',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '호박나물', '모닝롤', '우유', '쌀밥', '김치두부국', '치즈프레즐', '계란후라이', '호두죽', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '어묵국', '참치샌드', '땅콩조림', '포기김치'],
#  ['시래기조림', '주스', '우유', '모닝롤', '쌀밥', '찐빵', '고구마죽', '계란후라이', '포기김치', '대구찌개'],
#  ['주스', '누룽지탕', '느타리볶음', '우유', '모닝롤', '쌀밥', '브라우니', '오징어국', '계란후라이', '포기김치'],
#  ['주스',
#   '씨크립샌드',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '쑥갓두부무침',
#   '표고버섯죽',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '쇠고기무국',
#   '우유',
#   '모닝롤',
#   '꿀호떡',
#   '쌀밥',
#   '마늘쫑건새우볶음',
#   '계란후라이',
#   '포기김치'],
#  ['김치죽', '진미채무침', '주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '치킨샌드', '포기김치', '시금치국'],
#  ['주스', '우유', '모닝롤', '쌀밥', '사과파이', '북어국', '미역줄기볶음', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '꽃게탕', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치'],
#  ['비름나물', '주스', '우유', '모닝롤', '쌀밥', '무채국', '계란후라이', '포기김치', '옥수수샌드', '양송이죽'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '새송이버섯볶음',
#   '계란후라이',
#   '동태찌개',
#   '포기김치',
#   '고구마파이'],
#  ['주스', '스크램블에그', '팥죽', '우유', '모닝롤', '쌀밥', '검정콩조림', '열무된장국', '포기김치', '단호박샌드'],
#  ['주스', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '잣죽', '크로와상', '계란후라이', '조랭이떡국', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '팬케익', '김치두부국', '느타리버섯볶음', '계란후라이', '포기김치'],
#  ['주스', '호박잎찌개', '모닝롤', '우유', '쌀밥', '김자반', '햄치즈샌드', '계란후라이', '해물죽', '포기김치'],
#  ['고구마순나물', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '쇠고기매운국', '단팥빵', '계란후라이', '포기김치'],
#  ['베이컨샌드',
#   '주스',
#   '고추장찌개',
#   '스크램블에그',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '브로컬리두부무침',
#   '참치죽',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '시래기국', '쇠고기죽', '오이무침', '계란후라이', '포기김치'],
#  ['가지나물', '프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '된장찌개', '계란후라이', '포기김치'],
#  ['주스', '밤죽', '우유', '모닝롤', '계란후라이', '쌀밥', '두부젓국찌개', '명엽채무침', '에그샌드', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '시금치프리타타', '쌀밥', '호박볶음', '오징어국', '포기김치'],
#  ['주스', '녹두죽', '쇠고기무국', '우유', '모닝롤', '쌀밥', '포기김치', '계란후라이', '바나나샌드', '지리멸치볶음'],
#  ['주스', '꽃게탕', '모닝롤', '우유', '쌀밥', '땅콩조림', '단호박죽', '계란후라이', '메론롤케익', '포기김치'],
#  ['주스', '무청된장국', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '쥐포무침', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '식빵피자', '쌀밥', '황태국', '열무나물', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '오이도라지무침', '우유', '모닝롤', '쌀밥', '브라우니', '바지락국', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '느타리볶음', '팥죽', '우유', '모닝롤', '쌀밥', '연두부탕', '포기김치'],
#  ['깻순나물', '주스', '새우살죽', '우거지해장국', '모닝롤', '우유', '쌀밥', '치즈프레즐', '계란후라이', '포기김치'],
#  ['호떡',
#   '주스',
#   '누룽지탕',
#   '브로컬리된장무침',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '김치순두부찌개',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '콩나물국', '잣죽', '김자반', '햄치즈샌드', '계란후라이', '포기김치'],
#  ['시래기조림', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '쇠고기미역국', '베이글', '계란후라이', '포기김치'],
#  ['진미채무침',
#   '주스',
#   '스크램블에그',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '건새우아욱국',
#   '녹두죽',
#   '포기김치'],
#  ['주스', '차돌박이찌개', '우유', '모닝롤', '쌀밥', '사과파이', '검정콩조림', '계란후라이', '흑임자죽', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '계란후라이', '포기김치', '시금치국'],
#  ['김치죽', '주스', '모닝롤', '우유', '쌀밥', '참치샌드', '오징어국', '계란후라이', '포기김치', '고구마줄기볶음'],
#  ['주스', '누룽지탕', '민물새우찌개', '모닝롤', '우유', '쌀밥', '숙주나물', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '무청된장국',
#   '야채샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '호박죽',
#   '새송이버섯볶음',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '마늘빵', '크림누룽지탕', '취나물', '계란후라이', '동태찌개', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '포기김치', '핫케익', '계란후라이', '두부김치국'],
#  ['주스', '수삼닭죽', '우유', '모닝롤', '쌀밥', '북어국', '오이무침', '계란후라이', '포기김치', '단호박샌드'],
#  ['주스',
#   '호박젓국찌개',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '크로와상',
#   '미역줄기볶음',
#   '계란후라이',
#   '포기김치'],
#  ['도라지나물', '주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '쇠고기죽', '에그샌드', '포기김치', '대구찌개'],
#  ['주스', '땅콩죽', '김실파무침', '우유', '모닝롤', '쌀밥', '감자국', '찐빵', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '된장찌개', '베이글', '김자반', '계란후라이', '포기김치'],
#  ['들깨버섯국', '주스', '야채죽', '씨크립샌드', '모닝롤', '우유', '쌀밥', '연근조림', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '콩나물무침', '열무된장국', '계란후라이', '포기김치'],
#  ['주스',
#   '우거지해장국',
#   '스크램블에그',
#   '홍게살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '영양부추생채',
#   '토마토샌드',
#   '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '무채국', '고구마죽', '치즈프레즐', '계란후라이', '시금치나물', '포기김치'],
#  ['주스', '누룽지탕', '감자조림', '우유', '모닝롤', '쌀밥', '포기김치', '마늘빵', '계란후라이', '김치국'],
#  ['주스',
#   '고추장찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '쇠고기죽',
#   '문어꽈리초조림',
#   '계란후라이',
#   '메론롤케익',
#   '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '황태국',
#   '치킨샌드',
#   '포기김치',
#   '느타리애호박볶음'],
#  ['주스', '애플파이', '차돌박이찌개', '멸치볶음', '모닝롤', '우유', '쌀밥', '계란후라이', '포기김치', '양송이죽'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '와플',
#   '버섯죽',
#   '쌀밥',
#   '시금치프리타타',
#   '키위드레싱샐러드',
#   '북어해장국',
#   '옥수수스프',
#   '포기김치',
#   '사과'],
#  ['주스', '모닝롤', '우유', '쌀밥', '버섯볶음', '감자국', '잣죽', '참치샌드', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '카스텔라', '얼갈이나물', '포기김치', '연두부국'],
#  ['주스', '새우살죽', '우유', '모닝롤', '쌀밥', '어묵국', '인절미샌드', '계란후라이', '포기김치', '고구마줄기볶음'],
#  ['주스', '우유', '모닝롤', '쌀밥', '김자반', '호박새우젓찌개', '계란후라이', '흑임자죽', '포기김치', '고구마파이'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '근대국', '계란후라이', '포기김치'],
#  ['주스', '매운버섯국', '모닝롤', '우유', '쌀밥', '취나물', '햄치즈샌드', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '브라우니', '도라지볶음', '오징어국', '포기김치'],
#  ['주스', '홍게살죽', '우유', '모닝롤', '쌀밥', '무채국', '미역줄기볶음', '계란후라이', '바나나샌드', '포기김치'],
#  ['깻순나물', '주스', '모닝롤', '우유', '쌀밥', '단호박죽', '단팥빵', '계란후라이', '포기김치', '대구찌개'],
#  ['진미채무침', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '아욱국', '계란후라이', '포기김치'],
#  ['주스',
#   '민물새우찌개',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '쌀밥',
#   '꽈리고추찜',
#   '표고버섯죽',
#   '에그샌드',
#   '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '크로와상', '어묵국', '참나물무침', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '스크램블에그', '팥죽', '우유', '모닝롤', '쌀밥', '콩나물무침', '얼갈이된장국', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '감자국', '닭죽', '마늘빵', '브로컬리들깨찜', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '꿀호떡', '쌀밥', '숙주나물', '계란후라이', '열무김치', '두부김치국'],
#  ['주스', '새우살죽', '우유', '모닝롤', '쌀밥', '무나물', '토마토샌드', '계란후라이', '포기김치', '대구찌개'],
#  ['주스', '누룽지탕', '선지해장국', '우유', '모닝롤', '쌀밥', '사과파이', '연근조림', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '김구이', '우유', '모닝롤', '쌀밥', '오징어국', '흑임자죽', '포기김치', '옥수수샌드'],
#  ['시금치팬케익', '주스', '야채죽', '모닝롤', '우유', '쌀밥', '미역줄기볶음', '계란후라이', '포기김치', '재첩국'],
#  ['주스', '무청된장국', '누룽지탕', '우유', '모닝롤', '쌀밥', '브라우니', '김자반', '계란후라이', '포기김치'],
#  ['주스', '고추장찌개', '모닝롤', '우유', '쌀밥', '잣죽', '참치샌드', '콩조림', '계란후라이', '포기김치'],
#  ['시래기조림', '주스', '누룽지탕', '쇠고기무국', '모닝롤', '우유', '쌀밥', '계란후라이', '메론롤케익', '포기김치'],
#  ['주스', '스크램블에그', '소라살죽', '우유', '모닝롤', '쌀밥', '파래무침', '북어해장국', '포기김치', '단호박샌드'],
#  ['주스', '소고기죽', '우유', '모닝롤', '쌀밥', '콩나물국', '오이무침', '계란후라이', '포기김치', '고구마파이'],
#  ['느타리호박볶음',
#   '프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '어묵국',
#   '계란후라이',
#   '포기김치'],
#  ['견과류죽', '주스', '매운버섯국', '우유', '모닝롤', '식빵피자', '쌀밥', '꽈리고추찜', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '크림누룽지탕', '쌀밥', '명엽채무침', '아욱국', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '올챙이만두국',
#   '열무나물',
#   '바나나샌드',
#   '포기김치',
#   '양송이죽'],
#  ['멸치크랜베리볶음',
#   '주스',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '김치두부국',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '팬케익', '잣죽', '북어국', '김자반', '계란후라이', '포기김치'],
#  ['두부조림', '주스', '누룽지탕', '꽃게탕', '씨크립샌드', '모닝롤', '우유', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '볼어묵볶음', '우유', '모닝롤', '와플', '쌀밥', '감자국', '쇠고기죽', '포기김치'],
#  ['주스', '호박젓국찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘쫑볶음', '찐빵', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '마늘빵', '시래기국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '동전쥐포무침', '무채국', '인절미샌드', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '단배추나물', '오징어국', '계란후라이', '포기김치', '고구마파이'],
#  ['베이컨샌드', '주스', '스크램블에그', '선지해장국', '땅콩죽', '모닝롤', '우유', '쌀밥', '연근조림', '포기김치'],
#  ['알타리김치', '주스', '멸치볶음', '우유', '모닝롤', '꿀호떡', '쌀밥', '닭죽', '계란후라이', '김치국'],
#  ['프렌치토스트',
#   '주스',
#   '호박젓국찌개',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '명엽채무침',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '재첩국', '모닝롤', '우유', '쌀밥', '참치샌드', '검정콩조림', '계란후라이', '포기김치', '양송이죽'],
#  ['시래기조림', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '동태탕', '베이글', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '야채죽', '호박나물', '우유', '모닝롤', '쌀밥', '아욱국', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '단호박죽', '피바지락국', '콩나물무침', '계란후라이', '포기김치'],
#  ['시금치팬케익', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '황태국', '오이무침', '계란후라이', '포기김치'],
#  ['고구마순나물',
#   '주스',
#   '홍게살죽',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '쌀밥',
#   '두부젓국찌개',
#   '에그샌드',
#   '포기김치'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '쌀밥', '브라우니', '감자채햄볶음', '계란후라이', '포기김치'],
#  ['진미채무침', '주스', '스크램블에그', '밤죽', '우유', '모닝롤', '쌀밥', '감자국', '토마토샌드', '포기김치'],
#  ['주스', '팥죽', '모닝롤', '우유', '쌀밥', '계란후라이', '메론롤케익', '포기김치', '미역나물', '콩나물김치국'],
#  ['주스', '누룽지탕', '김구이', '차돌박이찌개', '모닝롤', '우유', '쌀밥', '녹차호떡', '계란후라이', '포기김치'],
#  ['베이컨샌드',
#   '주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '땅콩멸치볶음',
#   '새송이죽',
#   '계란후라이',
#   '포기김치',
#   '콩나물김치국'],
#  ['주스', '누룽지탕', '선지해장국', '우유', '모닝롤', '쌀밥', '우엉조림', '베이글', '계란후라이', '포기김치'],
#  ['주스',
#   '고추장찌개',
#   '스크램블에그',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '피자토스트',
#   '닭죽',
#   '문어꽈리초조림',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '사과파이', '무채국', '고구마죽', '브로컬리초장', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '민물새우찌개', '우유', '모닝롤', '쌀밥', '마늘빵', '김자반', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '쌀밥', '올챙이만두국', '인절미샌드', '콩나물무침', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '크로와상', '대구매운탕', '아삭고추무침', '계란후라이', '포기김치'],
#  ['주스', '새우살죽', '스크램블에그', '우유', '모닝롤', '쌀밥', '시래기국', '어묵볶음', '에그샌드', '포기김치'],
#  ['홍합탕',
#   '프렌치토스트',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '단배추나물',
#   '크림누룽지탕',
#   '계란후라이',
#   '포기김치'],
#  ['진미채무침', '주스', '호박젓국찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '핫케익', '계란후라이', '포기김치'],
#  ['주스', '모닝롤', '우유', '쌀밥', '꽈리고추찜', '김치두부국', '참치샌드', '계란후라이', '포기김치', '양송이죽'],
#  ['버섯매운탕', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '땅콩조림', '단팥빵', '계란후라이', '포기김치'],
#  ['김잔파무침', '주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '콩나물국', '쇠고기죽', '포기김치'],
#  ['김치죽', '멸치크랜베리볶음', '주스', '모닝롤', '우유', '쌀밥', '북어국', '치즈프레즐', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '감자국', '브로컬리들깨찜', '계란후라이', '포기김치'],
#  ['주스',
#   '호박나물',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '표고버섯죽',
#   '계란후라이',
#   '햄야채샌드',
#   '포기김치',
#   '맑은만두육개장'],
#  ['주스', '차돌박이찌개', '우유', '모닝롤', '쌀밥', '찐빵', '단호박죽', '계란후라이', '시금치나물', '포기김치'],
#  ['도라지나물',
#   '주스',
#   '고추장찌개',
#   '스크램블에그',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '바나나샌드',
#   '포기김치'],
#  ['주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '베이글', '피바지락국', '미역줄기볶음', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '콩나물국', '명엽채볶음', '마늘빵', '계란후라이', '포기김치'],
#  ['버섯매운탕',
#   '주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '감자채햄볶음',
#   '계란후라이',
#   '흑임자죽',
#   '포기김치',
#   '단호박샌드'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '매생이굴국', '숙주나물', '계란후라이', '포기김치'],
#  ['베이컨샌드', '홍합탕', '주스', '스크램블에그', '팥죽', '모닝롤', '우유', '쌀밥', '아삭고추무침', '포기김치'],
#  ['주스', '애플파이', '소라살죽', '모닝롤', '우유', '쌀밥', '닭개장', '연근조림', '계란후라이', '포기김치'],
#  ['김잔파무침', '주스', '누룽지탕', '우유', '모닝롤', '꿀호떡', '쌀밥', '북어국', '계란후라이', '포기김치'],
#  ['주스', '선지해장국', '감자조림', '우유', '모닝롤', '쌀밥', '닭죽', '계란후라이', '포기김치', '옥수수샌드'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '포기김치', '치커리유자청무침', '계란후라이', '김치국'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '식빵피자', '쌀밥', '꽈리고추찜', '어묵국', '녹두죽', '포기김치'],
#  ['주스', '땅콩죽', '꽃게탕', '우유', '모닝롤', '쌀밥', '계란후라이', '두부쑥갓무침', '포기김치', '고구마파이'],
#  ['주스', '호박젓국찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '팬케익', '쥐포무침', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '쌀밥', '대구매운탕', '토마토샌드', '감자채볶음', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '쇠고기무국', '멸치볶음', '우유', '모닝롤', '쌀밥', '브라우니', '계란후라이', '포기김치'],
#  ['주스', '고추장찌개', '스크램블에그', '우유', '모닝롤', '쌀밥', '김자반', '에그샌드', '포기김치', '양송이죽'],
#  ['미니케익', '김치죽', '주스', '모닝롤', '우유', '쌀밥', '시금치된장국', '포기김치', '계란후라이', '브로컬리무침'],
#  ['진미채무침', '주스', '우유', '모닝롤', '쌀밥', '잣죽', '김치두부국', '찐빵', '계란후라이', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '새송이볶음',
#   '계란후라이',
#   '포기김치',
#   '북어콩나물국'],
#  ['견과류죽',
#   '주스',
#   '스크램블에그',
#   '치커리사과무침',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '피바지락국',
#   '치즈프레즐',
#   '포기김치'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '냉이된장국',
#   '크로와상',
#   '마늘쫑건새우볶음',
#   '계란후라이',
#   '해물죽',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '와플', '쌀밥', '명엽채무침', '시래기국', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스', '누룽지탕', '치커리사과무침', '우유', '모닝롤', '계란후라이', '쌀밥', '어묵국', '에그샌드', '포기김치'],
#  ['주스', '스크램블에그', '선지해장국', '우유', '모닝롤', '쌀밥', '닭죽', '마늘빵', '브로컬리들깨찜', '포기김치'],
#  ['시금치죽',
#   '주스',
#   '가지두반장볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '매생이굴국',
#   '토마토샌드',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '누룽지탕', '민물새우찌개', '우유', '모닝롤', '쌀밥', '찐빵', '김자반', '계란후라이', '포기김치'],
#  ['견과류죽', '주스', '스크램블에그', '멸치볶음', '우유', '모닝롤', '식빵피자', '쌀밥', '감자국', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '유부김치국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '두부쑥갓무침',
#   '바나나샌드',
#   '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '시금치핫케익', '쌀밥', '닭개장', '감자채볶음', '녹두죽', '포기김치'],
#  ['주스', '야채죽', '모닝롤', '우유', '쌀밥', '콩나물국', '미역줄기볶음', '핫도그', '계란후라이', '포기김치'],
#  ['주스', '감자고추장찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '베이글', '계란후라이', '시금치나물', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '참치샌드',
#   '열무된장국',
#   '느타리호박볶음',
#   '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '대구매운탕', '아삭고추무침', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '호박젓국찌개',
#   '야채샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '검정콩조림',
#   '브로컬리죽',
#   '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '꿀호떡', '쌀밥', '고구마순볶음', '피바지락국', '계란후라이', '포기김치'],
#  ['후르츠팬케익',
#   '주스',
#   '누룽지탕',
#   '쇠고기무국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '두부양념조림',
#   '포기김치'],
#  ['베이컨샌드',
#   '주스',
#   '스크램블에그',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '꽈리고추찜',
#   '조랭이미역국',
#   '포기김치',
#   '양송이죽'],
#  ['홍합탕', '시래기조림', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '계란후라이', '포기김치'],
#  ['김잔파무침',
#   '주스',
#   '스크램블에그',
#   '땅콩죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '달래된장찌개',
#   '햄치즈샌드',
#   '포기김치'],
#  ['주스', '톳두부무침', '모닝롤', '우유', '쌀밥', '감자국', '계란후라이', '메론롤케익', '해물죽', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '꽃게탕', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '카레감자볶음',
#   '포기김치',
#   '크림누룽지탕',
#   '매생이떡국',
#   '옥수수샌드'],
#  ['주스', '누룽지탕', '콩가루배추국', '우유', '모닝롤', '와플', '쌀밥', '명엽채무침', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '피바지락국',
#   '흑임자죽',
#   '바나나샌드',
#   '포기김치',
#   '마늘쫑건새우무침'],
#  ['주스', '우유', '모닝롤', '쌀밥', '호박죽', '찐빵', '곰피초장', '계란후라이', '포기김치', '맑은만두육개장'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '황태국', '포기김치', '핫케익', '계란후라이', '애호박나물'],
#  ['주스', '스크램블에그', '선지해장국', '우유', '모닝롤', '쌀밥', '닭죽', '김자반', '에그샌드', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '브라우니', '브로컬리들깨찜', '계란후라이', '포기김치', '연두부국'],
#  ['주스',
#   '고구마샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '쇠고기미역국',
#   '마늘쫑무침',
#   '포기김치',
#   '양송이죽'],
#  ['김치죽', '주스', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '크로와상', '오징어국', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '봄동된장국', '숙주나물', '계란후라이', '포기김치'],
#  ['도라지나물',
#   '주스',
#   '새우살죽',
#   '스크램블에그',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '북어계란국',
#   '포기김치'],
#  ['주스', '땅콩죽', '우유', '모닝롤', '쌀밥', '콩나물국', '어묵볶음', '계란후라이', '포기김치', '고구마파이'],
#  ['모카카스테라',
#   '진미채무침',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '쌀밥',
#   '베이글',
#   '시래기된장국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '민물새우찌개', '우유', '모닝롤', '쌀밥', '잣죽', '단배추나물', '토마토샌드', '포기김치'],
#  ['주스', '누룽지탕', '꽃게탕', '우유', '모닝롤', '와플', '쌀밥', '감자채볶음', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '식빵피자', '쌀밥', '우엉조림', '느타리버섯국', '녹두죽', '포기김치'],
#  ['가지나물', '주스', '호박젓국찌개', '야채죽', '우유', '모닝롤', '팥호빵', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '쑥국', '우유', '모닝롤', '쌀밥', '사과파이', '포기김치', '계란후라이', '애호박나물'],
#  ['주스',
#   '스크램블에그',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '올챙이만두국',
#   '브로컬리들깨찜',
#   '바나나샌드',
#   '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '바지락국', '계란후라이', '메론롤케익', '시금치나물', '포기김치'],
#  ['주스', '팥죽', '우유', '모닝롤', '쌀밥', '명엽채무침', '감자국', '계란후라이', '포기김치', '옥수수샌드'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘빵', '시래기국', '오이무침', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '선지해장국', '우유', '모닝롤', '쌀밥', '쑥갓두부무침', '닭죽', '에그샌드', '포기김치'],
#  ['주스',
#   '고추장찌개',
#   '누룽지탕',
#   '크렌베리멸치볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '포기김치',
#   '초코핫케익'],
#  ['주스', '고구마샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '무채국', '단호박죽', '콩나물무침', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '김자반', '오징어국', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '호박젓국찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '브로컬리초장', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '황태국', '베이글', '느타리호박볶음', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '조랭이미역국',
#   '아삭고추무침',
#   '계란후라이',
#   '포기김치',
#   '단호박샌드'],
#  ['김잔파무침', '주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '잣죽', '단팥빵', '근대국', '포기김치'],
#  ['주스', '김치콩나물국', '모닝롤', '우유', '쌀밥', '참치샌드', '단호박죽', '취나물', '계란후라이', '포기김치'],
#  ['두부조림', '프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '감자국', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '스크램블에그', '꽃게탕', '우유', '모닝롤', '쌀밥', '미역줄기볶음', '흑임자죽', '포기김치'],
#  ['모카카스테라', '도라지나물', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '계란후라이', '포기김치', '대구찌개'],
#  ['진미채무침', '주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '아욱국', '포기김치', '양송이죽'],
#  ['주스', '고추장찌개', '우유', '모닝롤', '쌀밥', '검정콩조림', '계란후라이', '녹두죽', '포기김치', '고구마파이'],
#  ['주스', '누룽지탕', '김구이', '민물새우찌개', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치'],
#  ['주스', '고구마샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '닭죽', '무채국', '문어꽈리초조림', '포기김치'],
#  ['주스', '누룽지탕', '시금치나물', '우유', '모닝롤', '와플', '쌀밥', '계란후라이', '조랭이떡국', '포기김치'],
#  ['김치죽', '주스', '스크램블에그', '인절미토스트', '멸치볶음', '우유', '모닝롤', '쌀밥', '냉이된장국', '포기김치'],
#  ['견과류죽', '주스', '우유', '모닝롤', '쌀밥', '청포묵무침', '오징어국', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '연근조림', '베이글', '계란후라이', '포기김치', '미역국'],
#  ['주스',
#   '스크램블에그',
#   '콩가루배추국',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '감자채볶음',
#   '햄치즈샌드',
#   '해물죽',
#   '포기김치'],
#  ['주스', '누룽지탕', '모둠묵*장', '김치콩나물국', '우유', '모닝롤', '쌀밥', '크로와상', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '스크램블에그', '선지해장국', '팥죽', '우유', '모닝롤', '쌀밥', '바나나샌드', '포기김치'],
#  ['김잔파무침', '주스', '우유', '모닝롤', '쌀밥', '사과파이', '황태국', '계란후라이', '포기김치', '참치야채죽'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '시금치된장국',
#   '명엽채무침',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '느타리볶음', '모닝롤', '우유', '쌀밥', '감자국', '참치샌드', '표고버섯죽', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브라우니',
#   '브로컬리초장',
#   '계란후라이',
#   '포기김치',
#   '들깨시래기국'],
#  ['주스', '스크램블에그', '땅콩죽', '우유', '모닝롤', '쌀밥', '두부젓국찌개', '취나물', '에그샌드', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '팬케익', '김치두부국', '김자반', '쇠고기죽', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '북어계란국', '찐빵', '숙주나물', '계란후라이', '포기김치'],
#  ['옹심이만두떡국',
#   '주스',
#   '야채샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '고구마죽',
#   '어묵볶음',
#   '포기김치'],
#  ['비름나물', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '단팥빵', '계란후라이', '포기김치', '대구찌개'],
#  ['주스',
#   '고추장찌개',
#   '스크램블에그',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '포기김치',
#   '녹두죽',
#   '마늘쫑새우볶음'],
#  ['주스', '우유', '모닝롤', '꿀호떡', '쌀밥', '호박죽', '콩나물무침', '오징어국', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '감자국', '계란후라이', '포기김치'],
#  ['들깨버섯국', '주스', '스크램블에그', '야채죽', '모닝롤', '우유', '쌀밥', '도토리묵무침', '참치샌드', '포기김치'],
#  ['주스', '누룽지탕', '아욱된장국', '우유', '모닝롤', '쌀밥', '롤케익', '감자채피망볶음', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '꽃게탕', '팥죽', '우유', '모닝롤', '쌀밥', '콩자반', '포기김치', '단호박샌드'],
#  ['진미채무침', '주스', '우유', '모닝롤', '와플', '쌀밥', '잣죽', '냉이된장국', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '포기김치', '마늘빵', '북어해장국', '계란후라이', '애호박나물'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '떡국', '숙주나물', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '스크램블에그', '멸치볶음', '우유', '모닝롤', '쌀밥', '호밧젓국찌개', '참치죽', '바나나샌드', '포기김치'],
#  ['주스',
#   '새우살죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '브로컬리*초장',
#   '크로와상',
#   '계란후라이',
#   '포기김치',
#   '콩나물김치국'],
#  ['주스', '스크램블에그', '누룽지탕', '모닝롤', '우유', '쌀밥', '아삭고추무침', '핫도그', '들깨미역국', '포기김치'],
#  ['주스',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '김가루실파무침',
#   '표고버섯죽',
#   '열무된장국',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '매운버섯국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '마늘쫑볶음',
#   '흑임자죽',
#   '포기김치',
#   '옥수수샌드'],
#  ['오이사과무침', '주스', '우유', '모닝롤', '쌀밥', '브라우니', '북어계란국', '쇠고기죽', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '팬케익', '어묵국', '땅콩조림', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '스크램블에그', '쇠고기무국', '모닝롤', '우유', '쌀밥', '카스텔라', '호박죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '쑥갓두부무침', '베이글', '오징어국', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '선지해장국',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '브로컬리들깨찜',
#   '햄치즈샌드',
#   '포기김치',
#   '양송이죽'],
#  ['주스', '우유', '모닝롤', '쌀밥', '사과파이', '명엽채무침', '동태탕', '계란후라이', '녹두죽', '포기김치'],
#  ['도라지나물',
#   '프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '북어계란국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '감자국', '마늘쫑무침', '단팥빵', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '도토리묵*장',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '김치순두부찌개',
#   '닭죽',
#   '참치샌드',
#   '포기김치'],
#  ['소고기미역국',
#   '주스',
#   '모닝롤',
#   '우유',
#   '흑임자죽',
#   '쌀밥',
#   '꽈리고추찜',
#   '계란후라이',
#   '메론롤케익',
#   '포기김치'],
#  ['주스', '누룽지탕', '진미채볶음', '우유', '모닝롤', '쌀밥', '마늘빵', '열무된장국', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '황태국', '잣죽', '우엉조림', '인절미샌드', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '꿀호떡',
#   '쌀밥',
#   '계란후라이',
#   '참나물땅콩무침',
#   '포기김치',
#   '맑은만두육개장'],
#  ['주스',
#   '스크램블에그',
#   '콩나물김치국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '감자채볶음',
#   '해물죽',
#   '포기김치',
#   '단호박샌드'],
#  ['주스', '민물새우찌개', '우유', '모닝롤', '쌀밥', '버섯죽', '크로와상', '숙주나물', '계란후라이', '포기김치'],
#  ['구운어묵볶음', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '시금치된장국', '찐빵', '계란후라이', '포기김치'],
#  ['견과류죽', '주스', '야채샌드', '스크램블에그', '꽃게탕', '김구이', '우유', '모닝롤', '쌀밥', '포기김치'],
#  ['주스',
#   '호박젓국찌개',
#   '야채죽',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '아삭고추무침',
#   '계란후라이',
#   '포기김치'],
#  ['김치죽', '주스', '우유', '모닝롤', '쌀밥', '청포묵무침', '아욱국', '계란후라이', '포기김치', '고구마파이'],
# ...
#  ['주스', '모닝롤', '우유', '쌀밥', '오징어젓갈무침', '잣죽', '햄치즈샌드', '계란후라이', '열무김치', '미역국'],
#  ['주스', '어묵탕', '감자조림', '우유', '모닝롤', '와플', '쌀밥', '고구마죽', '계란후라이', '포기김치'],
#  ['김가루잔파무침',
#   '주스',
#   '누룽지탕',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치',
#   '들깨시래기국'],
#  ['주스', '호박젓국찌개', '땅콩죽', '우유', '모닝롤', '식빵피자', '쌀밥', '계란후라이', '두부쑥갓무침', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '차돌박이찌개',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '호박죽',
#   '찐빵',
#   '(샐러드닭가슴살',
#   '없이)',
#   '청포묵무침',
#   '포기김치'],
#  ['베이컨샌드', '깻순나물', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '맑은만두국', '계란후라이', '열무김치'],
#  ['호떡', '주스', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '감자국', '계란후라이', '해물죽', '포기김치'],
#  ['진미채무침', '주스', '스크램블에그', '누룽지탕', '우유', '모닝롤', '쌀밥', '황태국', '마늘빵', '포기김치'],
#  ['주스', '새우살죽', '스크램블에그', '우유', '모닝롤', '쌀밥', '아삭고추무침', '에그샌드', '포기김치', '미역국'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '대구매운탕', '베이글', '어묵볶음', '계란후라이', '포기김치'],
#  ['주스', '야채죽', '멸치볶음', '우유', '모닝롤', '팥호빵', '쌀밥', '무채국', '계란후라이', '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '연두부탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '고구마죽', '포기김치', '시금치국'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '크로와상', '김자반', '오징어국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '문어꽈리초조림', '잣죽', '토마토샌드', '근대국', '계란후라이', '포기김치'],
#  ['주스', '우거지해장국', '팥죽', '우유', '모닝롤', '쌀밥', '허니브레드', '열무나물', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '진미채볶음', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '들깨미역국', '포기김치'],
#  ['주스', '스크램블에그', '꽃게탕', '모닝롤', '우유', '쌀밥', '닭죽', '참치샌드', '시금치나물', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '멸치볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '해물순두부찌개',
#   '계란후라이',
#   '애플잼쿠키',
#   '포기김치'],
#  ['주스', '민물새우찌개', '우유', '모닝롤', '쌀밥', '호박죽', '감자채볶음', '계란후라이', '포기김치', '옥수수샌드'],
#  ['비름나물', '주스', '야채죽', '차돌박이찌개', '우유', '모닝롤', '와플', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '시래기국', '핫케익', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '콩나물국', '무나물', '햄치즈샌드', '흑임자죽', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '콩가루배추국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '알감자조림',
#   '포기김치',
#   '고구마파이'],
#  ['주스', '우유', '모닝롤', '쌀밥', '참나물생채', '치킨샌드', '오징어국', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '소고기죽', '감자고추장찌개', '우유', '모닝롤', '쌀밥', '우엉조림', '베이글', '계란후라이', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '느타리볶음',
#   '우유',
#   '모닝롤',
#   '시금치핫케익',
#   '쌀밥',
#   '두부젓국찌개',
#   '계란후라이',
#   '포기김치'],
#  ['건새우마늘쫑볶음', '주스', '야채샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '호박죽', '무채국', '포기김치'],
#  ['진미채무침', '주스', '누룽지탕', '꽃게탕', '모닝롤', '우유', '쌀밥', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '콩나물국', '포기김치', '잣죽', '미역줄기볶음', '계란후라이', '감자샌드'],
#  ['호박채나물', '주스', '우유', '모닝롤', '쌀밥', '황태국', '롤케익', '계란후라이', '해물죽', '포기김치'],
#  ['김잔파무침',
#   '프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '쇠고기무국',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '포기김치'],
#  ['주스',
#   '고추장찌개',
#   '고구마샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '표고버섯죽',
#   '시금치나물',
#   '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '동태탕', '브로컬리초장', '계란후라이', '포기김치'],
#  ['주스', '새우살죽', '멸치아몬드볶음', '우유', '모닝롤', '쌀밥', '감자국', '계란후라이', '바나나샌드', '포기김치'],
#  ['깻순나물', '견과류죽', '주스', '매운버섯국', '모닝롤', '우유', '쌀밥', '핫도그', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '핫케이크', '쌀밥', '무채국', '김자반', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '야채샌드', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '조랭이떡국', '포기김치'],
#  ['주스', '누룽지탕', '연두부탕', '우유', '모닝롤', '꿀호떡', '쌀밥', '명엽채무침', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '영양부추생채', '인절미샌드', '열무된장국', '계란후라이', '녹두죽', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '콩나물국', '연근조림', '찐빵', '계란후라이', '흑임자죽', '포기김치'],
#  ['김잔파무침', '주스', '호박젓국찌개', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '감자국', '동전문어조림', '닭죽', '포기김치', '홍루이젠'],
#  ['주스', '누룽지탕', '감자조림', '우유', '모닝롤', '쌀밥', '시래기국', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '우유', '모닝롤', '식빵피자', '쌀밥', '올챙이만두국', '어묵볶음', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '쇠고기샤브국', '모닝롤', '우유', '쌀밥', '포기김치', '잣죽', '카스텔라', '계란후라이', '애호박나물'],
#  ['진미채무침',
#   '프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '북어해장국',
#   '계란후라이',
#   '포기김치'],
#  ['깻순나물', '주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '포기김치', '에그샌드', '흑임자죽', '두부김치국'],
#  ['주스', '누룽지탕', '멸치볶음', '우유', '모닝롤', '쌀밥', '단호박찐빵', '열무된장국', '계란후라이', '포기김치'],
#  ['주스',
#   '씨크립샌드',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '노각무침',
#   '표고버섯죽',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '우거지해장국', '홍게살죽', '우유', '모닝롤', '쌀밥', '사과파이', '땅콩조림', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '아삭고추무침', '단팥빵', '계란후라이', '조랭이떡국', '포기김치'],
#  ['김잔파무침', '주스', '스크램블에그', '모닝롤', '우유', '쌀밥', '감자국', '참치샌드', '녹두죽', '포기김치'],
#  ['주스', '누룽지탕', '느타리볶음', '우유', '모닝롤', '쌀밥', '크로와상', '새우살미역국', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '우유', '모닝롤', '쌀밥', '호박죽', '토마토샌드', '계란후라이', '포기김치', '연두부국'],
#  ['김치죽', '주스', '쇠고기무국', '모닝롤', '우유', '쌀밥', '치즈프레즐', '쥐포무침', '계란후라이', '포기김치'],
#  ['사과잼쿠키',
#   '주스',
#   '누룽지탕',
#   '오이맛살냉채',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '포기김치',
#   '계란후라이',
#   '두부김치국'],
#  ['고구마줄기볶음', '주스', '스크램블에그', '팥죽', '우유', '모닝롤', '쌀밥', '무채국', '포기김치', '옥수수샌드'],
#  ['주스', '누룽지탕', '소시지감자볶음', '우유', '모닝롤', '와플', '쌀밥', '동태탕', '계란후라이', '포기김치'],
#  ['주스', '볼어묵볶음', '우유', '모닝롤', '쌀밥', '찐빵', '근대국', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '핫케이크', '쌀밥', '김자반', '오징어국', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '식빵피자', '쌀밥', '호박새우젓국', '연근조림', '흑임자죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '만두국', '롤케익', '계란후라이', '두부쑥갓무침', '포기김치'],
#  ['주스', '야채죽', '우유', '모닝롤', '쌀밥', '연두부찌개', '마늘쫑볶음', '계란후라이', '바나나샌드', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '실곤약흑임자무침', '잣죽', '된장찌개', '계란후라이', '포기김치', '고구마파이'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '명엽채무침', '감자국', '마늘빵', '계란후라이', '포기김치'],
#  ['김치죽', '주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '어묵국', '포기김치', '단호박샌드'],
#  ['주스', '메추리알조림', '누룽지탕', '모닝롤', '우유', '쌀밥', '열무된장국', '핫도그', '계란후라이', '포기김치'],
#  ['오이사과무침',
#   '주스',
#   '새우살야채죽',
#   '황태해장국',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '단팥빵',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '느타리볶음', '우유', '모닝롤', '꿀호떡', '쌀밥', '대구매운탕', '계란후라이', '녹두죽', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '조랭이떡미역국',
#   '동전쥐포무침',
#   '계란후라이',
#   '포기김치'],
#  ['김잔파무침', '주스', '스크램블에그', '땅콩죽', '우유', '모닝롤', '쌀밥', '포기김치', '두부김치국', '옥수수샌드'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '시래기국', '감자채볶음', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '야채죽', '모닝롤', '우유', '쌀밥', '참치샌드', '오징어국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '찐빵', '영양부추생채', '계란후라이', '해물죽', '포기김치', '맑은만두육개장'],
#  ['주스', '누룽지탕', '비트무생채', '모닝롤', '우유', '쌀밥', '떡국', '녹차호떡', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '연근조림', '포기김치', '잣죽', '열무된장국', '감자샌드'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '감자국', '얼갈이나물', '계란후라이', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '두반장가지볶음',
#   '시래기국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '새우살죽', '스크램블에그', '순두부국', '우유', '모닝롤', '쌀밥', '검정콩조림', '에그샌드', '포기김치'],
#  ['주스', '누룽지탕', '차돌박이찌개', '우유', '모닝롤', '쌀밥', '사과파이', '우엉조림', '계란후라이', '포기김치'],
#  ['주스', '멸치볶음', '우유', '모닝롤', '쌀밥', '감자국', '계란후라이', '흑임자죽', '포기김치', '단호박샌드'],
#  ['시금치팬케익', '주스', '야채죽', '도토리묵*장', '모닝롤', '우유', '쌀밥', '닭개장', '계란후라이', '포기김치'],
#  ['진미채무침', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '마늘빵', '계란후라이', '포기김치', '배추된장국'],
#  ['주스', '스크램블에그', '김구이', '씨크립샌드', '모닝롤', '우유', '쌀밥', '포기김치', '고구마죽', '대구탕'],
#  ['시래기조림', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '오징어국', '단팥빵', '계란후라이', '포기김치'],
#  ['느타리호박볶음',
#   '주스',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '계란후라이',
#   '들깨미역국',
#   '포기김치',
#   '대만샌드위치'],
#  ['두부쑥갓무침', '주스', '모닝롤', '우유', '쌀밥', '카스텔라', '된장찌개', '계란후라이', '참치죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '콩나물국', '꽈리고추찜', '찐빵', '계란후라이', '포기김치'],
#  ['주스', '소고기무국', '누룽지탕', '모닝롤', '우유', '쌀밥', '땅콩조림', '핫도그', '계란후라이', '포기김치'],
#  ['주스', '홍게살죽', '모닝롤', '우유', '쌀밥', '황태국', '치즈프레즐', '쥐포무침', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '꿀호떡', '쌀밥', '감자국', '명엽채무침', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '쇠고기죽', '미역줄기볶음', '근대국', '계란후라이', '바나나샌드', '포기김치'],
#  ['주스',
#   '호박젓국찌개',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '김자반',
#   '크림누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '옥수수샌드'],
#  ['주스', '우유', '모닝롤', '쌀밥', '바지락국', '크로와상', '닭죽', '취나물', '계란후라이', '포기김치'],
#  ['무생채', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '얼갈이국', '계란후라이', '포기김치'],
#  ['주스',
#   '고구마샌드',
#   '스크램블에그',
#   '야채죽',
#   '멸치볶음',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '조랭이떡미역국',
#   '포기김치'],
#  ['주스', '누룽지탕', '김구이', '우유', '모닝롤', '와플', '쌀밥', '오징어국', '계란후라이', '포기김치'],
#  ['연근땅콩조림', '주스', '팥죽', '우유', '모닝롤', '쌀밥', '참치새드', '시래기국', '계란후라이', '포기김치'],
#  ['도라지나물', '주스', '애플파이', '땅콩죽', '모닝롤', '우유', '쌀밥', '김치두부국', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '김치콩나물국', '모닝롤', '우유', '쌀밥', '녹차호떡', '김자반', '계란후라이', '포기김치'],
#  ['주스', '소고기무국', '야채샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '잣죽', '두부쑥갓무침', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '꽈리고추찜', '크로와상', '무채국', '계란후라이', '포기김치'],
#  ['김치죽', '주스', '우유', '모닝롤', '식빵피자', '쌀밥', '동전쥐포무침', '꽃게된장국', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '감자국', '열무나물', '롤케익', '계란후라이', '흑임자죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '포기김치', '땅콩조림', '마늘빵', '계란후라이', '두부김치국'],
#  ['베이컨샌드',
#   '진미채무침',
#   '주스',
#   '스크램블에그',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '포기김치',
#   '배추된장국'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '황태국',
#   '문어꽈리초조림',
#   '계란후라이',
#   '포기김치',
#   '오렌지케익빵'],
#  ['견과류죽', '주스', '모닝롤', '우유', '쌀밥', '어묵볶음', '아욱국', '단팥빵', '계란후라이', '포기김치'],
#  ['시래기조림', '인기가요샌드', '주스', '우유', '모닝롤', '쌀밥', '계란후라이', '녹두죽', '포기김치', '재첩국'],
#  ['주스', '누룽지탕', '민물새우찌개', '모닝롤', '우유', '쌀밥', '미역줄기볶음', '핫도그', '계란후라이', '포기김치'],
#  ['가지나물', '주스', '스크램블에그', '야채죽', '우유', '모닝롤', '쌀밥', '에그샌드', '포기김치', '연두부국'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '와플', '쌀밥', '연근조림', '포기김치', '계란후라이', '대구탕'],
#  ['주스',
#   '소고기죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '도토리묵무침',
#   '피바지락국',
#   '토마토샌드',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '참치죽', '모닝롤', '우유', '쌀밥', '명엽채무침', '감자국', '계란후라이', '메론롤케익', '포기김치'],
#  ['미역국', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '아삭고추무침', '계란후라이', '포기김치', '초코핫케익'],
#  ['주스', '고구마샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '연근조림', '잣죽', '북어해장국', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '찐빵', '김자반', '계란후라이', '조랭이떡국', '포기김치'],
#  ['시래기조림', '주스', '모닝롤', '우유', '쌀밥', '된장찌개', '참치샌드', '계란후라이', '해물죽', '포기김치'],
#  ['무생채', '주스', '애플파이', '팥죽', '모닝롤', '우유', '쌀밥', '어묵국', '계란후라이', '포기김치'],
#  ['호빵', '주스', '누룽지탕', '배추시래기국', '김구이', '우유', '모닝롤', '쌀밥', '계란후라이', '포기김치'],
#  ['주스',
#   '스크램블에그',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '감자채볶음',
#   '꽃게된장찌개',
#   '포기김치',
#   '옥수수샌드'],
#  ['홍합탕', '무비트생채', '주스', '누룽지탕', '우유', '모닝롤', '크림치즈프레즐', '쌀밥', '계란후라이', '포기김치'],
#  ['주스', '닭곰탕', '볼어묵조림', '야채죽', '우유', '모닝롤', '계란후라이', '쌀밥', '에그샌드', '포기김치'],
#  ['김치죽', '주스', '모닝롤', '우유', '쌀밥', '카스텔라', '콩가루된장국', '계란후라이', '시금치나물', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '콩나물국', '쥐포무침', '계란후라이', '포기김치', '오렌지케익빵'],
#  ['주스', '야채샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '감자국', '쑥갓두부무침', '쇠고기죽', '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '무채국', '문어꽈리초조림', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '황태국', '호박죽', '토마토샌드', '미역줄기볶음', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '크로와상', '숙주나물', '순두부찌개', '계란후라이', '참치죽', '포기김치'],
#  ['느타리호박볶음', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '포기김치', '핫케익', '계란후라이', '대구탕'],
#  ['견과류죽',
#   '주스',
#   '스크램블에그',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '명엽채무침',
#   '포기김치',
#   '올갱이아욱국'],
#  ['주스', '누룽지탕', '애플파이', '꽃게탕', '모닝롤', '우유', '쌀밥', '감자채볶음', '계란후라이', '포기김치'],
#  ['주스', '소라살죽', '우유', '모닝롤', '식빵피자', '쌀밥', '어묵국', '얼갈이나물', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '닭죽', '마늘빵', '김자반', '계란후라이', '포기김치', '배추된장국'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '된장찌개',
#   '사과오이초무침',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '콩나물국', '연근조림', '인절미샌드', '녹두죽', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '두부떡국',
#   '느타리버섯볶음',
#   '계란후라이',
#   '포기김치',
#   '고구마파이'],
#  ['주스', '야채샌드', '우유', '모닝롤', '쌀밥', '바지락국', '소시지볶음', '계란후라이', '해물죽', '포기김치'],
#  ['주스', '닭곰탕', '야채죽', '우유', '모닝롤', '쌀밥', '찐빵', '얼갈이겉절이', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '김구이', '야채호빵', '모닝롤', '우유', '쌀밥', '맑은순두부국', '계란후라이', '포기김치'],
#  ['시래기조림', '주스', '고구마샌드', '스크램블에그', '우유', '모닝롤', '쌀밥', '콩나물국', '잣죽', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '차돌박이된장찌개',
#   '크로와상',
#   '미역줄기볶음',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '만두국', '우엉간장조림', '계란후라이', '바나나샌드', '포기김치', '참치야채죽'],
#  ['주스',
#   '소고기죽',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '느타리버섯장조림',
#   '카스텔라',
#   '계란후라이',
#   '동태찌개',
#   '포기김치'],
#  ['순두부탕', '주스', '누룽지탕', '어묵꽈리고추볶음', '우유', '모닝롤', '꿀호떡', '쌀밥', '계란후라이', '포기김치'],
#  ['진미채무침', '주스', '새우살죽', '스크램블에그', '꽃게탕', '우유', '모닝롤', '쌀밥', '에그샌드', '포기김치'],
#  ['주스', '감자채볶음', '우유', '모닝롤', '쌀밥', '크림누룽지탕', '계란후라이', '포기김치', '옥수수샌드', '미역국'],
#  ['홍합탕',
#   '주스',
#   '홍게살죽',
#   '멸치아몬드볶음',
#   '우유',
#   '모닝롤',
#   '시금치핫케익',
#   '쌀밥',
#   '계란후라이',
#   '포기김치'],
#  ['프렌치토스트', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '김자반', '계란후라이', '포기김치', '콩나물김치국'],
#  ['주스',
#   '야채샌드',
#   '스크램블에그',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '고구마죽',
#   '열무된장국',
#   '두부쑥갓무침',
#   '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '북어계란국', '콩나물무침', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '포기김치', '찐빵', '단호박죽', '미역줄기볶음', '계란후라이', '대구탕'],
#  ['주스', '누룽지탕', '김구이', '연두부탕', '우유', '모닝롤', '쌀밥', '핫케익', '계란후라이', '포기김치'],
#  ['견과류죽', '주스', '스크램블에그', '씨크립샌드', '모닝롤', '우유', '쌀밥', '포기김치', '숙주나물', '매생이떡국'],
#  ['주스', '누룽지탕', '애플파이', '모닝롤', '우유', '쌀밥', '어묵국', '감자채볶음', '계란후라이', '포기김치'],
#  ['주스', '소라살죽', '우유', '모닝롤', '식빵피자', '쌀밥', '북어해장국', '계란후라이', '두부양념조림', '포기김치'],
#  ['주스', '우유', '모닝롤', '계란후라이', '쌀밥', '콩비지찌개', '연근조림', '닭죽', '케익', '포기김치'],
#  ['주스', '고추장찌개', '누룽지탕', '모닝롤', '우유', '쌀밥', '카스텔라', '김자반', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '멸치볶음', '우유', '모닝롤', '쌀밥', '감자양파국', '흑임자죽', '바나나샌드', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '볼어묵조림',
#   '차돌박이찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '치즈프레즐',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '우유', '모닝롤', '쌀밥', '우엉조림', '조랭이떡국', '계란후라이', '녹두죽', '포기김치', '옥수수샌드'],
#  ['주스', '연두부*장', '팥죽', '우유', '모닝롤', '꿀호떡', '쌀밥', '무채국', '계란후라이', '포기김치'],
#  ['주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '명엽채무침', '오징어국', '핫도그', '계란후라이', '포기김치'],
#  ['주스', '스크램블에그', '봄동겉절이', '우유', '와플', '쌀밥', '표고버섯죽', '동태탕', '모닝에그빵', '포기김치'],
#  ['주스', '누룽지탕', '딤섬', '우유', '모닝롤', '쌀밥', '크로와상', '계란후라이', '포기김치', '재첩국'],
#  ['크래미숙주무침',
#   '주스',
#   '땅콩죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '토마토샌드',
#   '계란후라이',
#   '포기김치',
#   '피바지락배추국'],
#  ['주스', '누룽지탕', '우유', '쌀밥', '팬케익', '김치두부국', '베이글', '쥐포무침', '계란후라이', '포기김치'],
#  ['주스', '야채샌드', '스크램블에그', '꽃게탕', '우유', '모닝롤', '쌀밥', '고구마죽', '미역줄기볶음', '포기김치'],
#  ['호빵', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '감자국', '오징어젓갈무침', '계란후라이', '포기김치'],
#  ['느타리호박볶음', '주스', '모닝롤', '우유', '쌀밥', '포기김치', '잣죽', '참치샌드', '계란후라이', '대구탕'],
#  ['주스', '소보루빵', '누룽지탕', '김구이', '우유', '모닝롤', '쌀밥', '계란후라이', '포기김치', '시금치국'],
#  ['진미채무침', '주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '된장찌개', '포기김치', '피자빵', '양송이죽'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '만두국', '땅콩조림', '계란후라이', '포기김치', '초코핫케익'],
#  ['주스',
#   '호박젓국찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '마늘쫑볶음',
#   '햄치즈샌드',
#   '계란후라이',
#   '흑임자죽',
#   '포기김치'],
#  ['주스',
#   '소고기무국',
#   '야채죽',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '김치도토리묵무침',
#   '계란후라이',
#   '포기김치',
#   '고구마파이'],
#  ['주스',
#   '통아몬드멸치볶음',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '롤케익',
#   '새우살미역국',
#   '계란후라이',
#   '배추겉절이'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '떡국', '에그샌드', '알감자조림', '녹두죽', '포기김치'],
#  ['주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '사과파이', '무채국', '계란후라이', '두부양념조림', '포기김치'],
#  ['주스',
#   '야채샌드',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '참나물무침',
#   '크림누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '북어맑은국'],
#  ['주스', '꽃게탕', '우유', '모닝롤', '꿀호떡', '쌀밥', '호박죽', '계란후라이', '숙주나물무침', '포기김치'],
#  ['프렌치토스트',
#   '주스',
#   '누룽지탕',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '꽈리고추찜',
#   '김치두부국',
#   '계란후라이',
#   '포기김치'],
#  ['견과류죽',
#   '주스',
#   '스크램블에그',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '쥐포무침',
#   '얼갈이된장국',
#   '포기김치'],
#  ['김잔파무침', '주스', '누룽지탕', '모닝롤', '우유', '쌀밥', '오징어국', '단팥빵', '계란후라이', '포기김치'],
#  ['주스', '새우살죽', '볼어묵볶음', '모닝롤', '우유', '쌀밥', '감자국', '참치샌드', '계란후라이', '포기김치'],
#  ['버섯매운탕', '주스', '팥죽', '우유', '모닝롤', '쌀밥', '땅콩조림', '마늘빵', '계란후라이', '포기김치'],
#  ['시금치팬케익',
#   '주스',
#   '누룽지탕',
#   '민물새우찌개',
#   '모닝롤',
#   '우유',
#   '쌀밥',
#   '명엽채무침',
#   '계란후라이',
#   '포기김치'],
#  ['시금치초무침', '주스', '스크램블에그', '우유', '모닝롤', '식빵피자', '쌀밥', '잣죽', '봄동된장국', '포기김치'],
#  ['홍합탕', '주스', '누룽지탕', '우유', '모닝롤', '쌀밥', '감자채볶음', '계란후라이', '포기김치', '고구마파이'],
#  ['가지나물', '주스', '홍게살죽', '연두부탕', '우유', '모닝롤', '쌀밥', '토마토샌드', '계란후라이', '포기김치'],
#  ['주스', '호박젓국찌개', '모닝롤', '우유', '쌀밥', '카스텔라', '닭죽', '김자반', '계란후라이', '포기김치'],
#  ['주스',
#   '누룽지탕',
#   '연두부*참깨드레싱소스',
#   '우유',
#   '모닝롤',
#   '쌀밥',
#   '찐빵',
#   '무채국',
#   '계란후라이',
#   '포기김치'],
#  ['주스', '스크램블에그', '우유', '모닝롤', '쌀밥', '황태국', '포기김치', '꽈리고추멸치볶음', '녹두죽', '감자샌드'],
#  ['주스', '누룽지탕', '감자조림', '우유', '모닝롤', '쌀밥', '크로와상', '계란후라이', '포기김치', '연두부국'],
#  ['주스',
#   '우유',
#   '모닝롤',
#   '계란후라이',
#   '쌀밥',
#   '숙주나물무침',
#   '에그샌드',
#   '해물죽',
#   '포기김치',
#   '맑은만두육개장'],
#  ...]

# %%
# Train or load w2v model

TRAIN_W2V = True
try:
    model = Word2Vec.load('food_embedding.model')
    print("Model loaded")
except:
    if TRAIN_W2V:
        print("Training w2v")
        model = Word2Vec(sentences=food_combinations, vector_size=args.emb_dim, window=7, min_count=0, workers=4, sg=0, epochs=5000)
        model.save('food_embedding.model')
    else:
        print("Model loading failed. Do not train.")
# Out:
# Training w2v

# %%
# w2v demo
model.wv.most_similar('된장찌개')
# Out:
# [('차돌박이찌개', 0.5862919092178345),
#  ('감자국', 0.5642290115356445),
#  ('조랭이떡미역국', 0.5440123677253723),
#  ('오징어국', 0.5439068675041199),
#  ('민물새우찌개', 0.5349517464637756),
#  ('열무된장국', 0.5214429497718811),
#  ('대구매운탕', 0.5209029912948608),
#  ('얼갈이국', 0.5151638984680176),
#  ('어묵국', 0.5150087475776672),
#  ('무채국', 0.5106183290481567)]

# %% [markdown]
# # Preprocess

# %%
def process_date(df):
    df['일자'] = pd.to_datetime(df['일자'], format="%Y-%m-%d")
    df['year'] = df['일자'].dt.year
    df['month'] = df['일자'].dt.month
    df['day'] = df['일자'].dt.day
    df = df.drop('일자', axis=1)
    return df

def get_food_embedding(x):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    vec_ = np.zeros(args.emb_dim)
    for i in x_:
        vec = model.wv.get_vector(i)
        vec_ += vec
    vec_ /= len(x_)
    return vec_

# %%
# General preprocessing
df_train = process_date(df_train)
day_encoder = LabelEncoder()
df_train['요일'] = day_encoder.fit_transform(df_train['요일'])

# %%
df_train.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0   3   2601      50     150             238          0.0
# 1   4   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계  year  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0  2016
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0  2016
#
#    month  day
# 0      2    1
# 1      2    2

# %%
# Get embedding
df_train['조식메뉴_embedding'] = df_train['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['중식메뉴_embedding'] = df_train['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['석식메뉴_embedding'] = df_train['석식메뉴'].apply(lambda x: get_food_embedding(x))

# %%
df_train.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0   3   2601      50     150             238          0.0
# 1   4   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계  year  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0  2016
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0  2016
#
#    month  day                                     조식메뉴_embedding  \
# 0      2    1  [-0.71683776920492, -0.06340987980365753, -0.3...
# 1      2    2  [-1.0162153514948757, -0.3312900824980302, -0....
#
#                                       중식메뉴_embedding  \
# 0  [0.38581283390522003, 0.20111292228102684, -0....
# 1  [0.9491143021732569, 0.8505529686808586, -0.22...
#
#                                       석식메뉴_embedding
# 0  [0.015068284102848597, 0.2719016426375934, -0....
# 1  [-0.49416922715802986, -0.2673995991547902, 0....

# %%
y_lunch = df_train['중식계']
y_dinner = df_train['석식계']
df_train.drop(['조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계'], axis=1, inplace=True)

# %%
X_common = df_train.iloc[:, :9]
X_common.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  year  month  day
# 0   3   2601      50     150             238          0.0  2016      2    1
# 1   4   2601      50     173             319          0.0  2016      2    2

# %%
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # 점심메뉴단어임베딩벡터 추가 
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # 저녁메뉴단어임베딩벡터 추가

X_train_lunch = np.concatenate((X_common.to_numpy(), emb_arr_lunch), axis=1)
X_train_dinner = np.concatenate((X_common.to_numpy(), emb_arr_dinner), axis=1)

# %%
X_train_lunch.shape
# Out:
# (1205, 209)

# %%
X_train_dinner.shape
# Out:
# (1205, 209)

# %% [markdown]
# # Modeling
