# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.input_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>"))
display(HTML("<style>.output_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.input_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>
# <style>.output_area pre {font-family: Consolas; font-size: 11pt; line-height: 140%;}</style>

# %%
# pip install --upgrade gensim

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
# Out:
# C:\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# HYPER PARAMETERS

class CFG:
    emb_dim = 200

args = CFG

# %%
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # Word Embedding

# %%
df_all = pd.concat([df_train, df_test])

# %%
df_all.head(2)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0

# %%
# Basic text preprocessing

def split_process(x, q):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    return x_

# %%
# Get all combinations for training w2v (train + test)

food_combinations = []
for i in ['조식메뉴', '중식메뉴', '석식메뉴']:
    food_combinations += df_all[i].apply(lambda x: split_process(x, i)).to_list()

# %%
len(food_combinations)
# Out:
# 3765

# %%
food_combinations
# Out:
# [['우유',
#   '호두죽',
#   '된장찌개',
#   '쥐어채무침',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '찐빵',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '팥죽',
#   '단호박샌드',
#   '호박젓국찌개',
#   '시래기조림',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '표고버섯죽',
#   '콩나물국',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '베이글',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '느타리호박볶음'],
#  ['우유',
#   '닭죽',
#   '근대국',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '토마토샌드',
#   '멸치볶음'],
#  ['우유', '주스', '방풍나물', '포기김치', '쇠고기죽', '재첩국', '쌀밥', '두유', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '주스',
#   '팬케익',
#   '견과류죽',
#   '감자찌개',
#   '포기김치',
#   '명엽채무침',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '찐빵'],
#  ['우유',
#   '주스',
#   '숙주나물',
#   '봄동된장국',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '고구마죽',
#   '모닝롤',
#   '야채샌드'],
#  ['우유',
#   '주스',
#   '콩조림',
#   '잣죽',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '치즈프레즐'],
#  ['우유', '단호박죽', '어묵국', '주스', '포기김치', '마늘빵', '쌀밥', '두유', '계란후라이', '김구이', '모닝롤'],
#  ['우유',
#   '참치샌드',
#   '주스',
#   '포기김치',
#   '무생채',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '북어계란국',
#   '흑임자죽'],
#  ['우유', '인절미토스트', '주스', '포기김치', '두유', '계란후라이', '모닝롤', '톳두부무침', '선지해장국'],
#  ['우유',
#   '주스',
#   '씨크립샌드',
#   '밤죽',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '홍합탕',
#   '오이생채'],
#  ['우유', '주스', '팬케익', '브로컬리죽', '고추장찌개', '시금치나물', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '주스', '참나물땅콩가루무침', '포기김치', '재첩국', '쌀밥', '계란후라이', '모닝롤', '야채샌드'],
#  ['우유', '김치죽', '주스', '꿀호떡', '애호박나물', '무채국', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '어묵볶음', '봄동된장국', '크로와상', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '에그샌드', '주스', '꽃게탕', '밤죽', '포기김치', '시래기조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '호두죽',
#   '곰피초장',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '콩나물김치국'],
#  ['우유',
#   '단팥빵',
#   '주스',
#   '올갱이아욱국',
#   '오이무침',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '참치야채죽'],
#  ['우유',
#   '주스',
#   '팥죽',
#   '포기김치',
#   '피바지락국',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '가지볶음',
#   '바나나샌드'],
#  ['우유',
#   '시금치국',
#   '주스',
#   '야채죽',
#   '볼어묵볶음',
#   '사과파이',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '브라우니',
#   '쑥갓무침',
#   '주스',
#   '무채국',
#   '포기김치',
#   '땅콩죽',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '고구마샌드',
#   '호박젓국찌개',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '유채나물',
#   '새송이죽'],
#  ['우유', '단호박죽', '어묵국', '주스', '포기김치', '김자반', '롤케익', '두유', '계란후라이', '쌀밥', '모닝롤'],
#  ['우유',
#   '주스',
#   '햄치즈샌드',
#   '포기김치',
#   '냉이된장국',
#   '녹두죽',
#   '명엽채무침',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '재첩국',
#   '검정콩조림',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '찐빵',
#   '모닝롤',
#   '고구마죽'],
#  ['우유', '롤케이크', '주스', '포기김치', '쌀밥', '계란후라이', '황태국', '모닝롤', '미역줄기볶음', '흑임자죽'],
#  ['우유', '에그샌드', '해물죽', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '브로컬리들깨찜', '쇠고기무국'],
#  ['우유',
#   '주스',
#   '시래기국',
#   '포기김치',
#   '쌀밥',
#   '느타리호박볶음',
#   '계란후라이',
#   '모닝롤',
#   '치즈프레즐',
#   '홍게살죽'],
#  ['우유', '베이컨샌드', '오징어국', '주스', '브로컬리죽', '숙주나물', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '표고버섯죽', '들깨미역국', '주스', '크로와상', '방풍나물', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '김치죽', '주스', '무채국', '포기김치', '마늘빵', '쌀밥', '계란후라이', '김실파무침', '모닝롤'],
#  ['우유',
#   '브로컬리초장',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '참치야채죽',
#   '선지해장국'],
#  ['우유', '근대국', '주스', '포기김치', '카스텔라', '쌀밥', '계란후라이', '모닝롤', '새송이버섯죽', '쑥갓두부무침'],
#  ['우유', '순두부국', '주스', '밤죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '크랜베리멸치볶음', '토마토샌드'],
#  ['우유', '진미채무침', '콩나물국', '주스', '견과류죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '새우살죽',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '두부김치국',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '미역레몬초무침'],
#  ['우유', '주스', '참치샌드', '야채죽', '오이무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '쇠고기버섯국'],
#  ['우유', '닭죽', '주스', '핫도그', '포기김치', '쌀밥', '감자국', '계란후라이', '참나물무침', '모닝롤'],
#  ['우유', '단팥빵', '주스', '마늘쫑무침', '늙은호박죽', '포기김치', '쌀밥', '바지락쑥국', '계란후라이', '모닝롤'],
#  ['우유', '주스', '구이김', '포기김치', '녹두죽', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤', '야채샌드'],
#  ['우유', '근대국', '주스', '팬케익', '잣죽', '마늘쫑무침', '포기김치', '쌀밥', '두유', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '두부젓국찌개',
#   '단호박샌드',
#   '포기김치',
#   '양송이죽',
#   '두유',
#   '계란후라이',
#   '쌀밥',
#   '모닝롤',
#   '미역줄기볶음'],
#  ['우유',
#   '주스',
#   '팥죽',
#   '꽃게탕',
#   '방풍나물',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '치즈프레즐'],
#  ['우유',
#   '열무된장국',
#   '진미채무침',
#   '주스',
#   '치킨샌드',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤',
#   '흑임자죽'],
#  ['우유',
#   '브라우니',
#   '주스',
#   '콩조림',
#   '대구찌개',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '고구마죽',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '견과류죽',
#   '고추장찌개',
#   '포기김치',
#   '마늘빵',
#   '김자반',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '감자채볶음',
#   '씨크립샌드',
#   '포기김치',
#   '쇠고기죽',
#   '얼갈이된장국',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '에그샌드',
#   '주스',
#   '브로컬리죽',
#   '포기김치',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '황태국',
#   '모닝롤',
#   '콩나물무침'],
#  ['우유',
#   '새우살죽',
#   '주스',
#   '크로와상',
#   '시금치나물',
#   '포기김치',
#   '재첩국',
#   '쌀밥',
#   '두유',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '주스', '꿀호떡', '오이무침', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유',
#   '표고버섯죽',
#   '콩나물국',
#   '주스',
#   '포기김치',
#   '곤약어묵볶음',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '토마토샌드'],
#  ['우유', '느타리볶음', '주스', '포기김치', '쌀밥', '베이글', '계란후라이', '김치국', '모닝롤', '홍게살죽'],
#  ['우유', '비름나물', '주스', '고구마샌드', '늙은호박죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '선지해장국'],
#  ['우유', '주스', '숙주나물', '포기김치', '카스텔라', '쌀밥', '계란후라이', '고구마죽', '모닝롤', '아욱국'],
#  ['우유', '주스', '포기김치', '프렌치토스트', '땅콩죽', '쌀밥', '김구이', '계란후라이', '모닝롤', '차돌박이찌개'],
#  ['우유', '베이컨샌드', '주스', '포기김치', '연두부탕', '열무나물', '녹두죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '주스', '감자채볶음', '포기김치', '쌀밥', '계란후라이', '매운어묵국', '모닝롤', '와플'],
#  ['우유', '표고버섯죽', '주스', '포기김치', '롤케익', '쌀밥', '계란후라이', '우거지해장국', '모닝롤', '마늘쫑볶음'],
#  ['우유', '진미채무침', '야채햄샌드', '김치죽', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '우렁살된장국'],
#  ['우유', '주스', '야채죽', '호박젓국찌개', '포기김치', '마늘빵', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '팥죽', '오이도라지무침', '포기김치', '재첩국', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '주스', '밤죽', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '브로컬리들깨찜', '콩나물김치국'],
#  ['우유', '호두죽', '들깨미역국', '진미채무침', '주스', '팬케익', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '에그샌드', '근대국', '주스', '브로컬리죽', '감자채볶음', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '느타리버섯국', '주스', '호박나물', '크로와상', '포기김치', '쌀밥', '계란후라이', '모닝롤', '홍게살죽'],
#  ['우유', '주스', '참치샌드', '야채죽', '포기김치', '취나물', '쌀밥', '계란후라이', '모닝롤', '북어계란국'],
#  ['우유', '주스', '포기김치', '노각무침', '쌀밥', '계란후라이', '모닝롤', '아욱국', '흑임자죽', '치즈프레즐'],
#  ['우유', '주스', '잣죽', '포기김치', '프렌치토스트', '연두부탕', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '새우살죽', '스크램블에그', '콩나물국', '느타리볶음', '주스', '햄치즈샌드', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '단팥빵', '주스', '어묵볶음', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '씨크립샌드', '대구찌개', '포기김치', '명엽채무침', '양송이죽', '쌀밥', '모닝롤'],
#  ['우유', '단호박죽', '근대국', '주스', '고구마파이', '포기김치', '머위대나물', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '마늘빵', '얼갈이된장국', '땅콩죽', '쌀밥', '계란후라이', '모닝롤', '미역레몬초무침'],
#  ['우유', '인절미토스트', '스크램블에그', '콩나물국', '주스', '포기김치', '녹두죽', '쌀밥', '김구이', '모닝롤'],
#  ['우유', '김치죽', '주스', '열무김치', '올갱이아욱국', '검정콩조림', '쌀밥', '계란후라이', '모닝롤', '야채샌드'],
#  ['우유', '어묵국', '스크램블에그', '주스', '마늘쫑무침', '소라살죽', '포기김치', '쌀밥', '베이글', '모닝롤'],
#  ['우유', '브로컬리초장', '주스', '식빵피자', '밤죽', '포기김치', '피바지락국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '멸치캐슈넛볶음', '주스', '미역국', '포기김치', '카스텔라', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '새우살죽', '주스', '치킨샌드', '포기김치', '쌀밥', '계란후라이', '모닝롤', '쇠고기무국', '가지나물'],
#  ['우유', '브라우니', '주스', '팥죽', '홍초콩나물국', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '에그샌드', '주스', '야채죽', '애호박나물', '포기김치', '쌀밥', '황태국', '모닝롤'],
#  ['우유', '사각어묵무침', '주스', '열무김치', '크로와상', '무채국', '쌀밥', '계란후라이', '모닝롤', '홍게살죽'],
#  ['우유', '주스', '견과류죽', '포기김치', '두부김치국', '명엽채무침', '쌀밥', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '주스', '포기김치', '쌀밥', '계란후라이', '고구마죽', '모닝롤', '아욱국', '오이생채', '바나나샌드'],
#  ['우유', '느타리버섯국', '스크램블에그', '주스', '핫도그', '숙주나물', '늙은호박죽', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '꽃게탕', '포기김치', '취나물', '쌀밥', '계란후라이', '모닝롤', '참치야채죽', '토마토샌드'],
#  ['우유',
#   '주스',
#   '잣죽',
#   '포기김치',
#   '프렌치토스트',
#   '멸치고추장무침',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기무국'],
#  ['우유', '동태찌개', '주스', '포기김치', '녹두죽', '쌀밥', '새송이버섯볶음', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '시금치국', '주스', '감자채볶음', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '베이컨샌드',
#   '표고버섯죽',
#   '콩나물국',
#   '고구마순나물',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '닭죽', '주스', '팬케익', '포기김치', '쌀밥', '느타리호박볶음', '계란후라이', '우거지해장국', '모닝롤'],
#  ['우유', '진미채무침', '주스', '야채죽', '포기김치', '마늘빵', '쌀밥', '계란후라이', '근대된장국', '모닝롤'],
#  ['우유', '주스', '김치콩나물국', '고구마샌드', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '오징어국', '스크램블에그', '주스', '팥죽', '포기김치', '노각무침', '롤케익', '쌀밥', '모닝롤'],
#  ['우유', '주스', '열무김치', '치킨샌드', '검정콩조림', '쌀밥', '계란후라이', '모닝롤', '북어계란국', '홍게살죽'],
#  ['우유', '된장찌개', '비름나물', '주스', '밤죽', '포기김치', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유',
#   '쥐어채무침',
#   '북어콩나물국',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '땅콩죽',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '새우살미역국', '느타리볶음', '주스', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤', '햄야채샌드'],
#  ['우유', '스크램블에그', '동태찌개', '주스', '잣죽', '애호박나물', '포기김치', '쌀밥', '모닝롤', '애플파이'],
#  ['우유', '단팥빵', '단호박죽', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '소고기무국', '가지나물'],
#  ['우유', '시금치국', '주스', '참치샌드', '브로컬리죽', '포기김치', '쌀밥', '계란후라이', '볼어묵조림', '모닝롤'],
#  ['우유', '호두죽', '주스', '무채국', '포기김치', '카스텔라', '두부조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '표고버섯죽', '주스', '꽃게탕', '시금치나물', '포기김치', '쌀밥', '계란후라이', '모닝롤', '바나나샌드'],
#  ['우유', '닭죽', '느타리버섯국', '주스', '크로와상', '포기김치', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '멸치호두볶음',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '김치콩나물국',
#   '포기김치',
#   '쇠고기죽',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '김치죽', '주스', '근대국', '포기김치', '머위대나물', '쌀밥', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '주스', '포기김치', '쌀밥', '베이글', '계란후라이', '감자국', '모닝롤', '마늘쫑볶음', '흑임자죽'],
#  ['우유',
#   '숙주미나리나물',
#   '에그샌드',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기무국',
#   '홍게살죽'],
#  ['우유',
#   '브라우니',
#   '스크램블에그',
#   '고구마순나물',
#   '주스',
#   '대구찌개',
#   '포기김치',
#   '쌀밥',
#   '모닝롤',
#   '참치야채죽'],
#  ['우유', '진미채무침', '주스', '햄치즈샌드', '포기김치', '새알미역국', '쌀밥', '계란후라이', '모닝롤', '새송이죽'],
#  ['우유', '주스', '팥죽', '포기김치', '두부김치국', '김자반', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '시금치국', '주스', '포기김치', '프렌치토스트', '명엽채무침', '땅콩죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '어묵국', '스크램블에그', '콩자반', '주스', '포기김치', '녹두죽', '쌀밥', '모닝롤', '토마토샌드'],
#  ['우유', '주스', '고구마파이', '무채국', '오이무침', '포기김치', '양송이죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '해물죽', '주스', '버섯볶음', '포기김치', '쌀밥', '계란후라이', '근대된장국', '모닝롤', '옥수수샌드'],
#  ['우유', '닭죽', '주스', '포기김치', '쌀밥', '바나나팬케이크', '계란후라이', '모닝롤', '북어계란국', '멸치볶음'],
#  ['우유', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤', '김실파무침'],
#  ['우유', '김치죽', '주스', '식빵피자', '바지락콩나물국', '포기김치', '쌀밥', '시래기나물', '계란후라이', '모닝롤'],
#  ['우유', '단팥빵', '주스', '고추장찌개', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '브로컬리들깨찜'],
#  ['우유', '새우살죽', '에그샌드', '주스', '숙주나물', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '주스', '스크램블', '애호박나물', '포기김치', '쇠고기죽', '카스텔라', '쌀밥', '모닝롤', '북어국'],
#  ['우유',
#   '근대국',
#   '주스',
#   '사각어묵볶음',
#   '포기김치',
#   '프렌치토스트',
#   '보리누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '단호박죽', '스크램블에그', '오징어국', '주스', '씨크립샌드', '포기김치', '쌀밥', '모닝롤', '새송이볶음'],
#  ['우유', '주스', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '차돌박이찌개', '치즈프레즐'],
#  ['우유',
#   '느타리버섯국',
#   '주스',
#   '참치샌드',
#   '야채죽',
#   '포기김치',
#   '쌀밥',
#   '구운계란',
#   '모닝롤',
#   '크랜베리멸치볶음'],
#  ['우유', '동태찌개', '주스', '크로와상', '포기김치', '아삭고추무침', '쌀밥', '계란후라이', '모닝롤', '홍게살죽'],
#  ['우유', '주스', '포기김치', '누룽지탕', '명엽채무침', '롤케익', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '스크램블에그', '주스', '야채죽', '고구마샌드', '올갱이아욱국', '포기김치', '쌀밥', '호박볶음', '모닝롤'],
#  ['우유', '새우살미역국', '고구마순나물', '주스', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '녹두죽', '참나물땅콩무침', '쌀밥', '구운계란', '모닝롤', '야채샌드', '쇠고기샤브국'],
#  ['우유', '해물죽', '주스', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤', '가지볶음', '와플'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '잣죽', '꿀호떡', '포기김치', '쌀밥', '모닝롤', '북어국'],
#  ['우유', '어묵국', '주스', '포기김치', '누룽지탕', '쌀밥', '콩나물무침', '계란후라이', '모닝롤', '토마토샌드'],
#  ['우유', '브라우니', '주스', '포기김치', '쌀밥', '구운계란', '우거지해장국', '모닝롤', '미역줄기볶음', '흑임자죽'],
#  ['우유', '오징어국', '주스', '포기김치', '쇠고기죽', '도라지나물', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '스크램블에그', '주스', '잣죽', '포기김치', '쌀밥', '새송이버섯볶음', '우거지해장국', '모닝롤', '와플'],
#  ['우유', '주스', '참치샌드', '조랭이떡미역국', '포기김치', '꽈리고추찜', '쌀밥', '계란후라이', '모닝롤', '호박죽'],
#  ['우유', '주스', '애호박볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤', '북어국'],
#  ['우유', '시금치국', '주스', '인절미샌드', '포기김치', '쌀밥', '구운계란', '고구마죽', '모닝롤', '김잔파무침'],
#  ['우유', '주스', '포기김치', '카스텔라', '누룽지탕', '쌀밥', '도라지나물', '계란후라이', '모닝롤', '민물새우찌깨'],
#  ['우유', '느타리버섯국', '주스', '포기김치', '프렌치토스트', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '근대국', '주스', '야채죽', '포기김치', '명엽채무침', '쌀밥', '구운계란', '모닝롤', '바나나샌드'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '크림누룽지탕',
#   '사과파이',
#   '대구찌개',
#   '곤약어묵볶음',
#   '포기김치',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '고구마순나물', '콩나물국', '햄에그치즈토스트', '주스', '김치죽', '포기김치', '쌀밥', '구운계란'],
#  ['우유', '주스', '팥죽', '크로와상', '포기김치', '맑은만두육개장', '쌀밥', '계란후라이', '모닝롤', '가지나물'],
#  ['우유', '주스', '감자조림', '바나나팬케익', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '구운계란', '모닝롤'],
#  ['우유', '스크램블에그', '에그샌드', '해물죽', '주스', '콩나물된장국', '구이김', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '진미채무침', '주스', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤', '쇠고기무국'],
#  ['우유', '주스', '햄치즈샌드', '늙은호박죽', '취나물', '포기김치', '쌀밥', '구운계란', '모닝롤', '김치두부국'],
#  ['우유', '단팥빵', '주스', '포기김치', '아욱된장국', '땅콩죽', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유', '주스', '고구마파이', '꽃게탕', '포기김치', '김자반', '누룽지탕', '쌀밥', '구운계란', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '멸치볶음', '포기김치', '쌀밥', '감자국', '모닝롤', '토마토샌드', '새송이죽'],
#  ['우유', '주스', '포기김치', '누룽지탕', '쌀밥', '김구이', '구운계란', '모닝롤', '와플', '북어해장국'],
#  ['우유', '스크램블에그', '주스', '잣죽', '고구마샌드', '포기김치', '쇠고기미역국', '명엽채무침', '쌀밥', '모닝롤'],
#  ['우유',
#   '주스',
#   '김가루실파무침',
#   '사과파이',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '버섯들깨탕',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '된장찌개',
#   '주스',
#   '브로컬리들깨무침',
#   '포기김치',
#   '쇠고기죽',
#   '쌀밥',
#   '구운계란',
#   '모닝롤',
#   '옥수수샌드'],
#  ['우유', '주스', '숙주나물', '크림누룽지탕', '포기김치', '카스텔라', '쌀밥', '김치국', '계란후라이', '모닝롤'],
#  ['우유', '주스', '꽃게탕', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '도라지나물',
#   '쌀밥',
#   '민물새우찌개',
#   '모닝롤',
#   '흑임자죽'],
#  ['우유', '주스', '수삼닭죽', '포기김치', '무생채', '맑은만두육개장', '쌀밥', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '에그샌드', '치커리무침', '주스', '포기김치', '누룽지탕', '쌀밥', '감자국', '구운계란', '모닝롤'],
#  ['우유',
#   '단호박죽',
#   '콩나물국',
#   '주스',
#   '크로와상',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '크랜베리멸치볶음'],
#  ['우유', '주스', '견과류죽', '포기김치', '김자반', '쌀밥', '구운계란', '모닝롤', '북어채국', '후르츠팬케익'],
#  ['우유', '어묵국', '스크램블에그', '주스', '참치샌드', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '브라우니', '해물죽', '주스', '고추장찌개', '구구마순나물', '포기김치', '쌀밥', '구운계란', '모닝롤'],
#  ['우유', '베이컨샌드', '주스', '팥죽', '포기김치', '연두부탕', '시래기조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '호박젓국찌개',
#   '프렌치토스트',
#   '포기김치',
#   '검정콩조림',
#   '쌀밥',
#   '구운계란',
#   '모닝롤',
#   '홍게살죽'],
#  ['우유', '오징어국', '주스', '포기김치', '양송이죽', '쌀밥', '계란후라이', '모닝롤', '바나나샌드', '미역나물'],
#  ['우유', '스크램블에그', '주스', '얼큰소고기국', '포기김치', '누룽지탕', '롤케익', '쌀밥', '김구이', '모닝롤'],
#  ['우유', '주스', '브로컬리죽', '식빵피자', '포기김치', '꽈리고추찜', '쌀밥', '구운계란', '모닝롤', '김치두부국'],
#  ['우유', '단팥빵', '진미채무침', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '아욱국'],
#  ['우유', '주스', '포기김치', '마늘빵', '명엽채무침', '쌀밥', '감자국', '구운계란', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '시금치나물', '포기김치', '녹두죽', '쌀밥', '매운버섯국', '계란후라이', '모닝롤', '야채샌드'],
#  ['우유', '스크램블에그', '주스', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '베이글', '모닝롤', '북어해장국'],
#  ['우유', '주스', '고추장찌개', '씨크립샌드', '늙은호박죽', '연근조림', '포기김치', '쌀밥', '구운계란', '모닝롤'],
#  ['우유', '프레즐', '주스', '포기김치', '누룽지탕', '쌀밥', '콩나물무침', '계란후라이', '모닝롤', '쇠고기무국'],
#  ['우유', '어묵국', '고구마순나물', '주스', '포기김치', '누룽지탕', '쌀밥', '찐빵', '모닝롤', '삶은계란'],
#  ['우유', '근대국', '주스', '견과류죽', '햄치즈샌드', '오이무침', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '단호박샌드',
#   '포기김치',
#   '연두부찌개',
#   '누룽지탕',
#   '쌀밥',
#   '마늘쫑맛살볶음',
#   '모닝롤',
#   '삶은계란'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '고구마파이',
#   '포기김치',
#   '모시조개시금치국',
#   '쌀밥',
#   '모닝롤',
#   '호박죽',
#   '가지나물'],
#  ['우유', '인절미토스트', '콩나물국', '주스', '야채죽', '쥐포무침', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '들깨미역국',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '호박볶음',
#   '모닝롤',
#   '후르츠팬케익'],
#  ['우유', '에그샌드', '주스', '콩조림', '포기김치', '쇠고기죽', '아욱된장국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '크로와상', '대구찌개', '포기김치', '김자반', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '주스', '시래기국', '포기김치', '두부조림', '양송이죽', '쌀밥', '모닝롤', '토마토샌드', '삶은계란'],
#  ['우유', '브라우니', '닭죽', '주스', '브로컬리들깨무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '스크램블에그', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '모닝롤', '북어해장국', '김잔파무침'],
#  ['우유',
#   '주스',
#   '크림누룽지탕',
#   '고추장찌개',
#   '씨크립샌드',
#   '청포묵무침',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '시금치나물',
#   '포기김치',
#   '누룽지탕',
#   '맑은만두육개장',
#   '쌀밥',
#   '모닝롤',
#   '애플파이'],
#  ['우유', '주스', '야채죽', '마늘쫑무침', '어묵탕', '식빵피자', '포기김치', '쌀밥', '모닝롤', '삶은계란'],
#  ['우유', '주스', '건새우무국', '가지두반장볶음', '포기김치', '롤케익', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '바나나팬케익', '포기김치', '누룽지탕', '쌀밥', '감자국', '모닝롤'],
#  ['우유', '에그샌드', '주스', '밤죽', '포기김치', '시래기조림', '피바지락국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '얼큰소고기국', '우엉조림', '포기김치', '누룽지탕', '쌀밥', '찐빵', '모닝롤'],
#  ['우유', '주스', '호박젓국찌개', '포기김치', '쌀밥', '미역줄기볶음', '모닝롤', '야채샌드', '삶은계란', '홍게살죽'],
#  ['우유', '주스', '고구마파이', '팥죽', '포기김치', '쌀밥', '콩나물무침', '계란후라이', '근대된장국', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '콩나물국',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '모닝롤',
#   '쑥갓두부무침'],
#  ['우유', '해물죽', '주스', '참치샌드', '무채국', '포기김치', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '포기김치', '재첩국', '누룽지탕', '꽈리고추찜', '쌀밥', '모닝롤', '와플'],
#  ['우유', '단호박죽', '숙주미나리나물', '주스', '포기김치', '쌀밥', '모닝롤', '아욱국', '삶은계란', '바나나샌드'],
#  ['우유', '느타리버섯볶음', '주스', '꽃게탕', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '단팥빵', '스크램블에그', '치커리무침', '주스', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '새우살죽', '어묵국', '주스', '방풍나물', '포기김치', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '스크램블에그', '주스', '고추장찌개', '포기김치', '김자반', '카스텔라', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '주스', '쥐포무침', '포기김치', '땅콩죽', '쌀밥', '배추된장국', '모닝롤', '토마토샌드', '삶은계란'],
#  ['우유', '주스', '팥죽', '포기김치', '쌀밥', '베이글', '계란후라이', '황태국', '모닝롤', '새송이볶음'],
#  ['우유', '스크램블에그', '주스', '무채국', '오이무침', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '주스', '애호박나물', '포기김치', '롤케익', '쌀밥', '계란후라이', '모닝롤', '북어계란국', '흑임자죽'],
#  ['우유', '스크램블에그', '주스', '냉이국', '고구마샌드', '포기김치', '누룽지탕', '두부조림', '쌀밥', '모닝롤'],
#  ['우유', '닭죽', '주스', '호박젓국찌개', '시래기조림', '포기김치', '쌀밥', '모닝롤', '야채샌드', '삶은계란'],
#  ['우유', '진미채무침', '해물죽', '주스', '포기김치', '얼갈이국', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '토란국', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '꽃맛살볶음', '모닝롤'],
#  ['우유',
#   '주스',
#   '크림누룽지탕',
#   '포기김치',
#   '검정콩조림',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '선지해장국',
#   '바나나샌드'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '연두부탕',
#   '누룽지탕',
#   '쌀밥',
#   '미역줄기볶음',
#   '모닝롤',
#   '녹차카스테라'],
#  ['우유', '어묵국', '주스', '씨크립샌드', '포기김치', '쌀밥', '콩나물무침', '모닝롤', '참치야채죽', '삶은계란'],
#  ['우유', '주스', '잣죽', '포기김치', '재첩국', '쌀밥', '김구이', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '스크램블에그', '주스', '팬케익', '포기김치', '누룽지탕', '쌀밥', '모닝롤', '김치두부국', '멸치볶음'],
#  ['우유',
#   '열무된장국',
#   '해물죽',
#   '주스',
#   '미니새송이볶음',
#   '단호박샌드',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '주스', '크로와상', '포기김치', '김자반', '누룽지탕', '쌀밥', '쇠고기매운국', '모닝롤'],
#  ['우유', '에그샌드', '근대국', '주스', '포기김치', '명엽채무침', '양송이죽', '쌀밥', '모닝롤', '삶은계란'],
#  ['우유', '브라우니', '주스', '고추장찌개', '시금치나물', '포기김치', '쌀밥', '계란후라이', '모닝롤', '호박죽'],
#  ['우유', '스크램블에그', '주스', '쥐포무침', '포기김치', '누룽지탕', '쌀밥', '찐빵', '모닝롤', '아욱국'],
#  ['우유',
#   '베이컨샌드',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '브로컬리들깨찜',
#   '홍게살죽'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '고구마파이',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '느타리호박볶음',
#   '모닝롤',
#   '북어계란국'],
#  ['우유', '주스', '햄치즈샌드', '포기김치', '쌀밥', '감자국', '모닝롤', '유채나물', '삶은계란', '새송이죽'],
#  ['우유', '주스', '포기김치', '취나물', '쇠고기죽', '쌀밥', '계란후라이', '매운어묵국', '모닝롤', '와플'],
#  ['우유', '스크램블에그', '콩자반', '주스', '포기김치', '냉이된장국', '마늘빵', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '인절미토스트', '새우살죽', '주스', '톳무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '차돌박이찌개'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '사과파이', '포기김치', '토란탕', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '주스', '밤죽', '오이무침', '연두부탕', '포기김치', '쌀밥', '모닝롤', '토마토샌드', '삶은계란'],
#  ['우유', '주스', '겨울초나물', '포기김치', '쇠고기죽', '쌀밥', '베이글', '계란후라이', '김치국', '모닝롤'],
#  ['우유',
#   '느타리버섯국',
#   '주스',
#   '바나나팬케익',
#   '포기김치',
#   '누룽지탕',
#   '두부조림',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '해물죽', '주스', '근대국', '숙주나물', '피자토스트', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '꿀호떡',
#   '포기김치',
#   '누룽지탕',
#   '맑은만두육개장',
#   '쌀밥',
#   '미역줄기볶음',
#   '모닝롤'],
#  ['우유', '주스', '마늘쫑무침', '씨크립샌드', '포기김치', '재첩국', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '크림누룽지탕', '포기김치', '쌀밥', '무채나물', '계란후라이', '찐빵', '모닝롤', '북어국'],
#  ['우유', '주스', '고추장찌개', '포기김치', '프렌치토스트', '취나물', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '열무된장국', '스크램블에그', '주스', '팥죽', '어묵볶음', '포기김치', '쌀밥', '모닝롤', '야채샌드'],
#  ['우유', '주스', '꽃게탕', '포기김치', '누룽지탕', '명엽채무침', '롤케익', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '참치샌드',
#   '브로컬리무침',
#   '포기김치',
#   '땅콩죽',
#   '쌀밥',
#   '민물새우찌개',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '소라살죽',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '새송이볶음',
#   '치즈프레즐',
#   '콩나물김치국'],
#  ['우유', '시금치핫케익', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '북어계란국', '가지나물'],
#  ['우유', '단호박죽', '스크램블에그', '느타리볶음', '근대국', '주스', '크로와상', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '두부젓국찌개', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '토마토샌드'],
#  ['우유', '오징어국', '스크램블에그', '주스', '야채죽', '크래미숙주무침', '포기김치', '쌀밥', '모닝롤', '와플'],
#  ['우유', '스크램블에그', '주스', '꽃게탕', '포기김치', '땅콩죽', '쌀밥', '김구이', '모닝롤', '치즈프레즐'],
#  ['우유', '주스', '포기김치', '검정콩조림', '누룽지탕', '쌀밥', '계란후라이', '황태국', '모닝롤', '옥수수샌드'],
#  ['우유', '스크램블에그', '주스', '고구마파이', '시금치죽', '포기김치', '연근조림', '쌀밥', '모닝롤', '선지해장국'],
#  ['우유', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '홍합탕', '겨울초겉절이', '새송이죽', '바나나샌드'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '마늘빵',
#   '누룽지탕',
#   '쌀밥',
#   '느타리호박볶음',
#   '모닝롤',
#   '콩나물김치국'],
#  ['우유', '주스', '단호박샌드', '포기김치', '재첩국', '양송이죽', '쌀밥', '계란후라이', '모닝롤', '가지나물'],
#  ['우유', '스크램블에그', '주스', '어묵볶음', '사과파이', '포기김치', '아욱된장국', '쌀밥', '모닝롤', '호박죽'],
#  ['우유', '주스', '참치샌드', '오이무침', '포기김치', '누룽지탕', '쌀밥', '감자국', '모닝롤', '삶은계란'],
#  ['우유', '닭죽', '주스', '꿀호떡', '포기김치', '맑은연두부탕', '쌀밥', '계란후라이', '모닝롤', '참나물생채'],
#  ['우유',
#   '진미채무침',
#   '스크램블에그',
#   '주스',
#   '봄동된장국',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '모닝롤'],
#  ['우유',
#   '표고버섯죽',
#   '주스',
#   '햄치즈샌드',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '브로컬리들깨찜'],
#  ['우유', '단팥빵', '주스', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '북어국'],
#  ['우유',
#   '스크램블에그',
#   '에그샌드',
#   '주스',
#   '김치콩나물국',
#   '포기김치',
#   '쌀밥',
#   '고구마죽',
#   '모닝롤',
#   '새송이볶음'],
#  ['우유', '근대국', '주스', '포기김치', '무생채', '쌀밥', '베이글', '계란후라이', '모닝롤', '홍게살죽'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '달래된장찌개',
#   '누룽지탕',
#   '쌀밥',
#   '찐빵',
#   '모닝롤',
#   '크랜베리멸치볶음'],
#  ['우유',
#   '스크램블에그',
#   '해물죽',
#   '주스',
#   '고추장찌개',
#   '김가루실파무침',
#   '포기김치',
#   '쌀밥',
#   '모닝롤',
#   '야채샌드'],
#  ['우유', '브라우니', '주스', '꽃게탕', '포기김치', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '씨크립샌드', '호박젓국찌개', '포기김치', '녹두죽', '쌀밥', '모닝롤', '가지나물'],
#  ['우유', '주스', '포기김치', '쇠고기죽', '아욱된장국', '두부조림', '롤케익', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '건새우무채국', '주스', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤', '토스트'],
#  ['우유', '스크램블에그', '콩자반', '주스', '참치샌드', '팥죽', '시금치된장국', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '잣죽', '매운감자국', '시래기조림', '포기김치', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '표고버섯죽', '스크램블에그', '주스', '핫도그', '쇠고기우거지국', '포기김치', '쌀밥', '참나물', '모닝롤'],
#  ['우유', '시래기된장국', '주스', '팬케익', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '쑥갓두부무침'],
#  ['우유', '단호박죽', '스크램블에그', '주스', '햄치즈샌드', '포기김치', '쌀밥', '모닝롤', '북어해장국', '가지나물'],
#  ['우유', '주스', '포기김치', '마늘빵', '맑은만두육개장', '땅콩죽', '쌀밥', '아삭고추무침', '계란후라이', '모닝롤'],
#  ['우유', '주스', '피자빵', '포기김치', '재첩국', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '유채나물'],
#  ['우유', '스크램블에그', '주스', '야채죽', '크로와상', '대구찌개', '포기김치', '쌀밥', '미역줄기볶음', '모닝롤'],
#  ['우유', '주스', '어묵볶음', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '된장찌개', '스크램블에그', '느타리볶음', '주스', '견과류죽', '씨크립샌드', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '단팥빵', '새우살죽', '주스', '쥐포무침', '두부젓국찌개', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '베이컨샌드', '쑥국', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '브로컬리들깨찜'],
#  ['우유', '스크램블에그', '주스', '포기김치', '김자반', '쌀밥', '모닝롤', '김치두부국', '흑임자죽', '치즈프레즐'],
#  ['우유', '시금치핫케익', '어묵국', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유', '들깨감자국', '스크램블에그', '주스', '포기김치', '쌀밥', '모닝롤', '오이생채', '바나나샌드', '홍게살죽'],
#  ['우유', '콩나물국', '김치죽', '주스', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '김실파무침'],
#  ['우유', '주스', '꽃게탕', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '명엽채볶음', '모닝롤', '와플'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '사과파이',
#   '포기김치',
#   '시래기조림',
#   '쌀밥',
#   '모닝롤',
#   '참치야채죽',
#   '선지해장국'],
#  ['우유',
#   '진미채무침',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '건새우아욱국'],
#  ['우유', '스크램블에그', '주스', '참치샌드', '브로컬리죽', '배추맑은국', '포기김치', '두부조림', '쌀밥', '모닝롤'],
#  ['우유',
#   '시래기들깨탕',
#   '주스',
#   '메론롤케익',
#   '포기김치',
#   '양송이죽',
#   '쌀밥',
#   '계란후라이',
#   '느타리호박볶음',
#   '모닝롤'],
#  ['우유',
#   '인절미토스트',
#   '주스',
#   '대추채멸치볶음',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '닭곰탕'],
#  ['우유', '스크램블에그', '주스', '고구마파이', '포기김치', '두부김치국', '쇠고기죽', '쌀밥', '모닝롤', '미역나물'],
#  ['우유', '주스', '사과파이', '포기김치', '무생채', '누룽지탕', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '팥죽', '햄치즈샌드', '포기김치', '쌀밥', '꽃맛살볶음', '모닝롤'],
#  ['우유',
#   '주스',
#   '크림누룽지탕',
#   '크로와상',
#   '포기김치',
#   '검정콩조림',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '차돌박이찌개'],
#  ['우유', '주스', '단배추나물', '단호박샌드', '두부들깨탕', '쌀밥', '계란후라이', '모닝롤', '깍두기', '홍게살죽'],
#  ['우유', '스크램블에그', '주스', '견과류죽', '포기김치', '쌀밥', '김치황태국', '모닝롤', '치즈프레즐', '가지나물'],
#  ['우유', '콩나물국', '주스', '팬케익', '쥐포무침', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '표고버섯죽', '스크램블에그', '에그샌드', '주스', '포기김치', '취나물', '쌀밥', '민물새우찌개', '모닝롤'],
#  ['우유', '단팥빵', '주스', '포기김치', '쇠고기해장국', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '유채나물'],
#  ['우유', '느타리볶음', '주스', '밤죽', '두부젓국찌개', '치킨샌드', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '마늘쫑건새우볶음',
#   '근대국',
#   '주스',
#   '늙은호박죽',
#   '포기김치',
#   '쌀밥',
#   '베이글',
#   '모닝롤'],
#  ['우유', '브라우니', '어묵국', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유', '멸치호두볶음', '스크램블에그', '김치죽', '주스', '씨크립샌드', '포기김치', '쌀밥', '감자국', '모닝롤'],
#  ['우유', '오징어국', '주스', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '주스', '포기김치', '녹두죽', '쌀밥', '매운버섯국', '계란후라이', '모닝롤', '야채샌드', '쑥갓두부무침'],
#  ['우유', '닭죽', '스크램블에그', '주스', '포기김치', '피바지락국', '명엽채무침', '롤케익', '쌀밥', '모닝롤'],
#  ['우유', '주스', '근대감자국', '포기김치', '프렌치토스트', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '참치샌드', '팥죽', '포기김치', '우엉어묵볶음', '쌀밥', '모닝롤'],
#  ['우유', '된장찌개', '주스', '포기김치', '검정콩조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '주스', '야채죽', '애호박볶음', '피자빵', '포기김치', '쌀밥', '계란후라이', '모닝롤', '북어해장국'],
#  ['우유', '스크램블에그', '주스', '조랭이떡국', '사과파이', '오이무침', '포기김치', '쌀밥', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '시금치죽', '포기김치', '쌀밥', '김구이', '계란후라이', '황태국', '모닝롤', '야채샌드'],
#  ['우유',
#   '진미채무침',
#   '시래기된장국',
#   '주스',
#   '단호박샌드',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '홍게살죽'],
#  ['우유',
#   '열무된장국',
#   '멸치크랜베리볶음',
#   '주스',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '베이글',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '어묵국', '김치죽', '주스', '포기김치', '쌀밥', '김구이', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유', '청경채무침', '스크램블에그', '주스', '고구마샌드', '포기김치', '누룽지탕', '쌀밥', '감자국', '모닝롤'],
#  ['우유', '스크램블에그', '해물죽', '주스', '호박젓국찌개', '포기김치', '카스텔라', '쌀밥', '모닝롤', '가지나물'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '쑥갓두부무침'],
#  ['우유', '에그샌드', '주스', '야채죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '브로컬리들깨찜', '북어채국'],
#  ['우유', '단팥빵', '주스', '포기김치', '검정콩조림', '누룽지탕', '쌀밥', '계란후라이', '대구매운탕', '모닝롤'],
#  ['우유',
#   '인절미토스트',
#   '스크램블에그',
#   '주스',
#   '참치죽',
#   '포기김치',
#   '명엽채무침',
#   '쌀밥',
#   '우거지해장국',
#   '모닝롤'],
#  ['우유', '단호박죽', '주스', '크로와상', '시금치나물', '포기김치', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '어묵국', '주스', '숙주나물', '크림누룽지탕', '포기김치', '마늘빵', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '오징어국', '주스', '김가루실파무침', '포기김치', '땅콩죽', '쌀밥', '계란후라이', '모닝롤', '야채샌드'],
#  ['우유', '주스', '애호박볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플', '닭곰탕'],
#  ['우유', '스크램블에그', '주스', '브로컬리죽', '포기김치', '열무나물', '쌀밥', '감자국', '모닝롤', '옥수수샌드'],
#  ['우유', '주스', '고구마파이', '팥죽', '포기김치', '맑은만두육개장', '꽈리고추찜', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '미역국', '대추채멸치볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '토스트'],
#  ['우유', '스크램블에그', '비름나물', '주스', '소고기무국', '포기김치', '쌀밥', '모닝롤', '토마토샌드', '수삼닭죽'],
#  ['우유', '주스', '두부젓국찌개', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '자반김', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '동태찌개',
#   '주스',
#   '밤죽',
#   '고구마샌드',
#   '포기김치',
#   '브로컬리들깨소스',
#   '쌀밥',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '감자채볶음',
#   '메론롤케익',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '건새우아욱국',
#   '홍게살죽'],
#  ['우유',
#   '시금치핫케익',
#   '주스',
#   '쥐포무침',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기버섯국'],
#  ['우유', '호두죽', '주스', '호박나물', '포기김치', '쌀밥', '계란후라이', '모닝롤', '김치두부국', '치즈프레즐'],
#  ['우유', '어묵국', '스크램블에그', '주스', '참치샌드', '포기김치', '누룽지탕', '쌀밥', '모닝롤', '땅콩조림'],
#  ['우유', '주스', '대구찌개', '포기김치', '시래기조림', '쌀밥', '계란후라이', '찐빵', '모닝롤', '고구마죽'],
#  ['우유', '브라우니', '오징어국', '느타리볶음', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '표고버섯죽',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '쑥갓두부무침'],
#  ['우유',
#   '마늘쫑건새우볶음',
#   '주스',
#   '꿀호떡',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기무국'],
#  ['우유', '시금치국', '스크램블에그', '진미채무침', '김치죽', '주스', '치킨샌드', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '사과파이', '포기김치', '녹두죽', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤', '북어국'],
#  ['우유', '주스', '꽃게탕', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤'],
#  ['우유', '비름나물', '주스', '무채국', '포기김치', '양송이죽', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유',
#   '동태찌개',
#   '주스',
#   '고구마파이',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '새송이버섯볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '열무된장국', '스크램블에그', '주스', '팥죽', '단호박샌드', '포기김치', '검정콩조림', '쌀밥', '모닝롤'],
#  ['우유', '주스', '조랭이떡국', '잣죽', '크로와상', '포기김치', '꽈리고추찜', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '느타리버섯볶음', '주스', '팬케익', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '해물죽', '주스', '호박잎찌개', '햄치즈샌드', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '단팥빵', '고구마순나물', '주스', '포기김치', '누룽지탕', '쌀밥', '쇠고기매운국', '계란후라이', '모닝롤'],
#  ['우유',
#   '베이컨샌드',
#   '스크램블에그',
#   '주스',
#   '참치죽',
#   '고추장찌개',
#   '포기김치',
#   '쌀밥',
#   '브로컬리두부무침',
#   '모닝롤'],
#  ['우유', '주스', '시래기국', '크로와상', '오이무침', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '된장찌개', '주스', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '가지나물'],
#  ['우유', '에그샌드', '주스', '밤죽', '두부젓국찌개', '포기김치', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '오징어국', '주스', '포기김치', '시금치프리타타', '누룽지탕', '쌀밥', '호박볶음', '모닝롤', '와플'],
#  ['우유', '주스', '지리멸치볶음', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤', '쇠고기무국', '바나나샌드'],
#  ['우유', '단호박죽', '주스', '꽃게탕', '메론롤케익', '포기김치', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유', '무청된장국', '주스', '쥐포무침', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '주스', '야채죽', '식빵피자', '포기김치', '열무나물', '쌀밥', '계란후라이', '황태국', '모닝롤'],
#  ['우유', '브라우니', '바지락국', '주스', '오이도라지무침', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '느타리볶음', '주스', '팥죽', '고구마샌드', '포기김치', '연두부탕', '쌀밥', '모닝롤'],
#  ['우유', '새우살죽', '깻순나물', '주스', '포기김치', '쌀밥', '계란후라이', '우거지해장국', '모닝롤', '치즈프레즐'],
#  ['우유',
#   '호떡',
#   '브로컬리된장무침',
#   '주스',
#   '김치순두부찌개',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '콩나물국', '주스', '잣죽', '햄치즈샌드', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '시래기조림', '쇠고기미역국', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유',
#   '진미채무침',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '녹두죽',
#   '쌀밥',
#   '모닝롤',
#   '건새우아욱국'],
#  ['우유', '주스', '차돌박이찌개', '사과파이', '포기김치', '검정콩조림', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '시금치국', '주스', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤'],
#  ['우유', '오징어국', '김치죽', '주스', '참치샌드', '고구마줄기볶음', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '단팥빵', '주스', '숙주나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['우유',
#   '무청된장국',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '새송이버섯볶음',
#   '모닝롤',
#   '야채샌드',
#   '호박죽'],
#  ['우유', '동태찌개', '주스', '크림누룽지탕', '포기김치', '취나물', '마늘빵', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '두부김치국', '누룽지탕', '명엽채무침', '쌀밥', '핫케익', '계란후라이', '모닝롤'],
#  ['우유', '주스', '단호박샌드', '오이무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '북어국', '수삼닭죽'],
#  ['우유',
#   '주스',
#   '크로와상',
#   '호박젓국찌개',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '미역줄기볶음',
#   '모닝롤'],
#  ['우유', '스크램블에그', '에그샌드', '주스', '대구찌개', '포기김치', '쇠고기죽', '도라지나물', '쌀밥', '모닝롤'],
#  ['우유', '주스', '포기김치', '땅콩죽', '쌀밥', '감자국', '계란후라이', '찐빵', '모닝롤', '김실파무침'],
#  ['우유', '된장찌개', '주스', '포기김치', '김자반', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유', '들깨버섯국', '주스', '야채죽', '씨크립샌드', '포기김치', '연근조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '열무된장국', '주스', '포기김치', '누룽지탕', '쌀밥', '콩나물무침', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '영양부추생채',
#   '포기김치',
#   '쌀밥',
#   '우거지해장국',
#   '모닝롤',
#   '토마토샌드',
#   '홍게살죽'],
#  ['우유', '주스', '시금치나물', '무채국', '포기김치', '쌀밥', '계란후라이', '고구마죽', '모닝롤', '치즈프레즐'],
#  ['우유', '주스', '감자조림', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '김치국', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '메론롤케익',
#   '고추장찌개',
#   '포기김치',
#   '쇠고기죽',
#   '쌀밥',
#   '계란후라이',
#   '문어꽈리초조림',
#   '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '치킨샌드',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '황태국',
#   '모닝롤',
#   '느타리애호박볶음'],
#  ['우유', '주스', '멸치볶음', '포기김치', '양송이죽', '쌀밥', '계란후라이', '모닝롤', '차돌박이찌개', '애플파이'],
#  ['버섯죽',
#   '우유',
#   '주스',
#   '키위드레싱샐러드',
#   '포기김치',
#   '사과',
#   '시금치프리타타',
#   '옥수수스프',
#   '쌀밥',
#   '모닝롤',
#   '와플',
#   '북어해장국'],
#  ['우유', '주스', '참치샌드', '잣죽', '버섯볶음', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '연두부국', '주스', '포기김치', '카스텔라', '누룽지탕', '쌀밥', '얼갈이나물', '모닝롤'],
#  ['우유', '새우살죽', '어묵국', '주스', '고구마줄기볶음', '인절미샌드', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '고구마파이', '포기김치', '호박새우젓찌개', '김자반', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '근대국', '주스', '포기김치', '프렌치토스트', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '해물죽', '주스', '햄치즈샌드', '포기김치', '취나물', '쌀밥', '매운버섯국', '계란후라이', '모닝롤'],
#  ['우유', '브라우니', '스크램블에그', '오징어국', '주스', '도라지볶음', '포기김치', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유', '주스', '무채국', '포기김치', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤', '바나나샌드', '홍게살죽'],
#  ['우유', '단팥빵', '단호박죽', '주스', '대구찌개', '포기김치', '쌀밥', '계란후라이', '깻순나물', '모닝롤'],
#  ['우유', '진미채무침', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤', '아욱국'],
#  ['우유',
#   '표고버섯죽',
#   '에그샌드',
#   '주스',
#   '포기김치',
#   '꽈리고추찜',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['우유', '어묵국', '주스', '크로와상', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '참나물무침', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '팥죽', '포기김치', '얼갈이된장국', '쌀밥', '콩나물무침', '모닝롤', '야채샌드'],
#  ['우유', '닭죽', '주스', '포기김치', '마늘빵', '쌀밥', '감자국', '계란후라이', '모닝롤', '브로컬리들깨찜'],
#  ['우유', '주스', '숙주나물', '꿀호떡', '열무김치', '두부김치국', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '새우살죽', '주스', '대구찌개', '포기김치', '쌀밥', '계란후라이', '무나물', '모닝롤', '토마토샌드'],
#  ['우유', '주스', '사과파이', '포기김치', '연근조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '선지해장국'],
#  ['우유', '오징어국', '스크램블에그', '주스', '포기김치', '쌀밥', '김구이', '모닝롤', '흑임자죽', '옥수수샌드'],
#  ['우유', '주스', '야채죽', '포기김치', '재첩국', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤', '시금치팬케익'],
#  ['우유', '브라우니', '무청된장국', '주스', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '참치샌드', '잣죽', '콩조림', '고추장찌개', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '메론롤케익', '포기김치', '시래기조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '쇠고기무국'],
#  ['우유', '스크램블에그', '파래무침', '주스', '소라살죽', '단호박샌드', '포기김치', '쌀밥', '모닝롤', '북어해장국'],
#  ['우유', '콩나물국', '주스', '고구마파이', '오이무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '소고기죽'],
#  ['우유',
#   '어묵국',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '느타리호박볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '주스', '견과류죽', '식빵피자', '포기김치', '꽈리고추찜', '쌀밥', '매운버섯국', '계란후라이', '모닝롤'],
#  ['우유', '단팥빵', '주스', '크림누룽지탕', '포기김치', '명엽채무침', '쌀밥', '계란후라이', '모닝롤', '아욱국'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '열무나물',
#   '올챙이만두국',
#   '양송이죽',
#   '쌀밥',
#   '모닝롤',
#   '바나나샌드'],
#  ['우유',
#   '멸치크랜베리볶음',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '김치두부국',
#   '치즈프레즐',
#   '홍게살죽'],
#  ['우유', '주스', '팬케익', '잣죽', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤', '북어국'],
#  ['우유', '주스', '꽃게탕', '씨크립샌드', '포기김치', '누룽지탕', '두부조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '볼어묵볶음', '포기김치', '쇠고기죽', '쌀밥', '감자국', '모닝롤', '와플'],
#  ['우유', '주스', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '마늘쫑볶음', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '주스', '시래기국', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤'],
#  ['우유', '동전쥐포무침', '주스', '인절미샌드', '무채국', '포기김치', '쌀밥', '계란후라이', '모닝롤', '흑임자죽'],
#  ['우유', '오징어국', '주스', '고구마파이', '단배추나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '베이컨샌드', '스크램블에그', '주스', '포기김치', '연근조림', '땅콩죽', '쌀밥', '모닝롤', '선지해장국'],
#  ['우유', '닭죽', '주스', '꿀호떡', '알타리김치', '쌀밥', '김치국', '계란후라이', '모닝롤', '멸치볶음'],
#  ['우유',
#   '주스',
#   '호박젓국찌개',
#   '프렌치토스트',
#   '포기김치',
#   '누룽지탕',
#   '명엽채무침',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '주스', '참치샌드', '포기김치', '재첩국', '검정콩조림', '양송이죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '시래기조림', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤', '동태탕'],
#  ['우유', '스크램블에그', '주스', '야채죽', '호박나물', '고구마샌드', '포기김치', '쌀밥', '모닝롤', '아욱국'],
#  ['우유', '단호박죽', '주스', '크로와상', '포기김치', '피바지락국', '쌀밥', '콩나물무침', '계란후라이', '모닝롤'],
#  ['우유', '주스', '오이무침', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '황태국', '모닝롤', '시금치팬케익'],
#  ['우유',
#   '고구마순나물',
#   '에그샌드',
#   '주스',
#   '두부젓국찌개',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '홍게살죽'],
#  ['우유', '브라우니', '감자채햄볶음', '주스', '꽃게탕', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '밤죽', '포기김치', '쌀밥', '감자국', '모닝롤', '토마토샌드'],
#  ['우유', '주스', '팥죽', '메론롤케익', '포기김치', '쌀밥', '계란후라이', '모닝롤', '콩나물김치국', '미역나물'],
#  ['우유', '주스', '녹차호떡', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤', '차돌박이찌개'],
#  ['우유',
#   '베이컨샌드',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '땅콩멸치볶음',
#   '계란후라이',
#   '모닝롤',
#   '새송이죽',
#   '콩나물김치국'],
#  ['우유', '주스', '우엉조림', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤', '선지해장국'],
#  ['우유',
#   '닭죽',
#   '스크램블에그',
#   '주스',
#   '고추장찌개',
#   '피자토스트',
#   '포기김치',
#   '쌀밥',
#   '문어꽈리초조림',
#   '모닝롤'],
#  ['우유', '브로컬리초장', '주스', '사과파이', '무채국', '포기김치', '쌀밥', '계란후라이', '고구마죽', '모닝롤'],
#  ['우유', '주스', '포기김치', '마늘빵', '누룽지탕', '김자반', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['우유', '주스', '야채죽', '인절미샌드', '포기김치', '올챙이만두국', '쌀밥', '콩나물무침', '계란후라이', '모닝롤'],
#  ['우유', '주스', '크로와상', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '계란후라이', '대구매운탕', '모닝롤'],
#  ['우유', '새우살죽', '스크램블에그', '에그샌드', '주스', '시래기국', '어묵볶음', '포기김치', '쌀밥', '모닝롤'],
#  ['우유',
#   '주스',
#   '크림누룽지탕',
#   '단배추나물',
#   '포기김치',
#   '프렌치토스트',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '홍합탕'],
#  ['우유', '진미채무침', '주스', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '핫케익', '계란후라이', '모닝롤'],
#  ['우유', '주스', '참치샌드', '포기김치', '꽈리고추찜', '양송이죽', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '단팥빵', '주스', '포기김치', '누룽지탕', '버섯매운탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '씨크립샌드', '포기김치', '쇠고기죽', '쌀밥', '모닝롤', '김잔파무침'],
#  ['우유', '멸치크랜베리볶음', '김치죽', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '북어국', '치즈프레즐'],
#  ['우유', '주스', '포기김치', '브로컬리들깨찜', '누룽지탕', '쌀밥', '감자국', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '표고버섯죽',
#   '주스',
#   '호박나물',
#   '포기김치',
#   '맑은만두육개장',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '햄야채샌드'],
#  ['우유', '단호박죽', '주스', '시금치나물', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '차돌박이찌개'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '고추장찌개',
#   '포기김치',
#   '누룽지탕',
#   '도라지나물',
#   '쌀밥',
#   '모닝롤',
#   '바나나샌드'],
#  ['우유', '주스', '포기김치', '피바지락국', '땅콩죽', '쌀밥', '베이글', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유', '콩나물국', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '명엽채볶음', '모닝롤'],
#  ['우유',
#   '감자채햄볶음',
#   '주스',
#   '단호박샌드',
#   '포기김치',
#   '버섯매운탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '흑임자죽'],
#  ['우유', '주스', '숙주나물', '포기김치', '프렌치토스트', '누룽지탕', '매생이굴국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '베이컨샌드', '스크램블에그', '주스', '팥죽', '포기김치', '아삭고추무침', '쌀밥', '모닝롤', '홍합탕'],
#  ['우유', '주스', '소라살죽', '포기김치', '연근조림', '쌀밥', '계란후라이', '모닝롤', '닭개장', '애플파이'],
#  ['우유', '주스', '꿀호떡', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '북어국', '김잔파무침'],
#  ['우유', '닭죽', '주스', '감자조림', '포기김치', '쌀밥', '계란후라이', '모닝롤', '선지해장국', '옥수수샌드'],
#  ['우유', '치커리유자청무침', '주스', '포기김치', '누룽지탕', '쌀밥', '김치국', '계란후라이', '모닝롤', '와플'],
#  ['우유', '어묵국', '스크램블에그', '주스', '식빵피자', '포기김치', '녹두죽', '꽈리고추찜', '쌀밥', '모닝롤'],
#  ['우유', '주스', '고구마파이', '꽃게탕', '포기김치', '땅콩죽', '쌀밥', '계란후라이', '모닝롤', '두부쑥갓무침'],
#  ['우유', '주스', '팬케익', '쥐포무침', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '야채죽', '감자채볶음', '포기김치', '쌀밥', '계란후라이', '대구매운탕', '모닝롤', '토마토샌드'],
#  ['우유', '브라우니', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '쇠고기무국', '멸치볶음'],
#  ['우유', '스크램블에그', '에그샌드', '주스', '고추장찌개', '포기김치', '김자반', '양송이죽', '쌀밥', '모닝롤'],
#  ['우유', '김치죽', '주스', '시금치된장국', '브로컬리무침', '미니케익', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '진미채무침', '주스', '잣죽', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '김치두부국'],
#  ['우유',
#   '북어콩나물국',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '새송이볶음'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '견과류죽',
#   '치커리사과무침',
#   '포기김치',
#   '피바지락국',
#   '쌀밥',
#   '모닝롤',
#   '치즈프레즐'],
#  ['우유',
#   '마늘쫑건새우볶음',
#   '해물죽',
#   '주스',
#   '크로와상',
#   '포기김치',
#   '냉이된장국',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '주스', '시래기국', '포기김치', '흑임자죽', '명엽채무침', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '어묵국', '에그샌드', '주스', '치커리사과무침', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '스크램블에그', '주스', '포기김치', '마늘빵', '쌀밥', '모닝롤', '브로컬리들깨찜', '선지해장국'],
#  ['우유',
#   '주스',
#   '시금치죽',
#   '가지두반장볶음',
#   '포기김치',
#   '매생이굴국',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '토마토샌드'],
#  ['우유', '민물새우찌개', '주스', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '견과류죽', '식빵피자', '포기김치', '쌀밥', '감자국', '모닝롤', '멸치볶음'],
#  ['우유',
#   '주스',
#   '두부쑥갓무침',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '유부김치국',
#   '바나나샌드'],
#  ['우유', '시금치핫케익', '스크램블에그', '주스', '감자채볶음', '포기김치', '녹두죽', '쌀밥', '모닝롤', '닭개장'],
#  ['우유', '콩나물국', '주스', '핫도그', '야채죽', '포기김치', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유', '주스', '시금치나물', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤', '감자고추장찌개'],
#  ['우유',
#   '열무된장국',
#   '스크램블에그',
#   '주스',
#   '참치샌드',
#   '포기김치',
#   '쌀밥',
#   '느타리호박볶음',
#   '모닝롤',
#   '홍게살죽'],
#  ['우유', '단팥빵', '주스', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '계란후라이', '대구매운탕', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '브로컬리죽',
#   '호박젓국찌개',
#   '포기김치',
#   '검정콩조림',
#   '쌀밥',
#   '모닝롤',
#   '야채샌드'],
#  ['우유', '주스', '팥죽', '꿀호떡', '포기김치', '피바지락국', '쌀밥', '계란후라이', '고구마순볶음', '모닝롤'],
#  ['우유',
#   '두부양념조림',
#   '주스',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기무국',
#   '후르츠팬케익'],
#  ['우유',
#   '베이컨샌드',
#   '스크램블에그',
#   '조랭이미역국',
#   '주스',
#   '포기김치',
#   '꽈리고추찜',
#   '양송이죽',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '주스', '사과파이', '포기김치', '시래기조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '홍합탕'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '햄치즈샌드',
#   '포기김치',
#   '달래된장찌개',
#   '땅콩죽',
#   '쌀밥',
#   '모닝롤',
#   '김잔파무침'],
#  ['우유', '해물죽', '주스', '메론롤케익', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤', '톳두부무침'],
#  ['우유', '주스', '꽃게탕', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '크림누룽지탕',
#   '포기김치',
#   '쌀밥',
#   '매생이떡국',
#   '카레감자볶음',
#   '모닝롤',
#   '옥수수샌드'],
#  ['우유', '콩가루배추국', '주스', '포기김치', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '마늘쫑건새우무침',
#   '포기김치',
#   '피바지락국',
#   '쌀밥',
#   '모닝롤',
#   '흑임자죽',
#   '바나나샌드'],
#  ['우유', '곰피초장', '주스', '포기김치', '맑은만두육개장', '쌀밥', '계란후라이', '찐빵', '모닝롤', '호박죽'],
#  ['우유', '주스', '애호박나물', '포기김치', '누룽지탕', '쌀밥', '핫케익', '계란후라이', '황태국', '모닝롤'],
#  ['우유', '닭죽', '스크램블에그', '에그샌드', '주스', '포기김치', '김자반', '쌀밥', '모닝롤', '선지해장국'],
#  ['우유', '브라우니', '연두부국', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '브로컬리들깨찜'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '마늘쫑무침',
#   '고구마샌드',
#   '포기김치',
#   '쇠고기미역국',
#   '양송이죽',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '오징어국', '김치죽', '주스', '크로와상', '포기김치', '꽈리고추찜', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '숙주나물', '봄동된장국', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '새우살죽',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '도라지나물',
#   '쌀밥',
#   '모닝롤',
#   '북어계란국'],
#  ['우유', '콩나물국', '주스', '고구마파이', '어묵볶음', '포기김치', '땅콩죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '진미채무침',
#   '시래기된장국',
#   '주스',
#   '포기김치',
#   '모카카스테라',
#   '누룽지탕',
#   '쌀밥',
#   '베이글',
#   '계란후라이'],
#  ['우유', '스크램블에그', '주스', '잣죽', '단배추나물', '포기김치', '쌀밥', '민물새우찌개', '모닝롤', '토마토샌드'],
#  ['우유', '주스', '꽃게탕', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '느타리버섯국', '스크램블에그', '주스', '우엉조림', '식빵피자', '포기김치', '녹두죽', '쌀밥', '모닝롤'],
#  ['우유', '팥호빵', '주스', '야채죽', '호박젓국찌개', '포기김치', '쌀밥', '계란후라이', '모닝롤', '가지나물'],
#  ['우유', '쑥국', '주스', '애호박나물', '사과파이', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '올챙이만두국',
#   '땅콩죽',
#   '쌀밥',
#   '모닝롤',
#   '브로컬리들깨찜',
#   '바나나샌드'],
#  ['우유', '바지락국', '주스', '메론롤케익', '시금치나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '팥죽', '포기김치', '명엽채무침', '쌀밥', '감자국', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '주스', '시래기국', '오이무침', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '스크램블에그', '에그샌드', '주스', '포기김치', '쌀밥', '모닝롤', '쑥갓두부무침', '선지해장국'],
#  ['우유',
#   '주스',
#   '고추장찌개',
#   '초코핫케익',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '크렌베리멸치볶음'],
#  ['우유', '단호박죽', '스크램블에그', '주스', '고구마샌드', '무채국', '포기김치', '쌀밥', '콩나물무침', '모닝롤'],
#  ['우유', '오징어국', '해물죽', '주스', '크로와상', '포기김치', '김자반', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '브로컬리초장', '주스', '호박젓국찌개', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '야채죽', '포기김치', '쌀밥', '베이글', '느타리호박볶음', '황태국', '모닝롤'],
#  ['우유',
#   '조랭이미역국',
#   '주스',
#   '단호박샌드',
#   '포기김치',
#   '아삭고추무침',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '단팥빵', '스크램블에그', '근대국', '주스', '잣죽', '포기김치', '쌀밥', '모닝롤', '김잔파무침'],
#  ['우유', '단호박죽', '주스', '참치샌드', '김치콩나물국', '포기김치', '취나물', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '프렌치토스트', '누룽지탕', '두부조림', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '꽃게탕', '포기김치', '쌀밥', '미역줄기볶음', '모닝롤', '야채샌드', '흑임자죽'],
#  ['우유', '주스', '대구찌개', '포기김치', '모카카스테라', '누룽지탕', '도라지나물', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '씨크립샌드', '포기김치', '양송이죽', '쌀밥', '모닝롤', '아욱국'],
#  ['우유', '주스', '고구마파이', '고추장찌개', '포기김치', '녹두죽', '검정콩조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '김구이', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['우유', '닭죽', '스크램블에그', '주스', '고구마샌드', '무채국', '포기김치', '쌀밥', '문어꽈리초조림', '모닝롤'],
#  ['우유', '주스', '조랭이떡국', '시금치나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '인절미토스트', '스크램블에그', '김치죽', '주스', '포기김치', '냉이된장국', '쌀밥', '모닝롤', '멸치볶음'],
#  ['우유', '오징어국', '주스', '고구마파이', '견과류죽', '청포묵무침', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '미역국', '포기김치', '연근조림', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤'],
#  ['우유',
#   '콩가루배추국',
#   '스크램블에그',
#   '해물죽',
#   '주스',
#   '감자채볶음',
#   '햄치즈샌드',
#   '포기김치',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '주스', '크로와상', '김치콩나물국', '포기김치', '누룽지탕', '쌀밥', '모둠묵*장', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '팥죽', '포기김치', '쌀밥', '모닝롤', '선지해장국', '가지나물', '바나나샌드'],
#  ['우유', '주스', '사과파이', '포기김치', '쌀밥', '계란후라이', '황태국', '모닝롤', '참치야채죽', '김잔파무침'],
#  ['우유',
#   '주스',
#   '시금치된장국',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '명엽채무침',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '표고버섯죽', '스크램블에그', '느타리볶음', '주스', '참치샌드', '포기김치', '쌀밥', '감자국', '모닝롤'],
#  ['우유',
#   '브라우니',
#   '브로컬리초장',
#   '주스',
#   '들깨시래기국',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '에그샌드', '주스', '두부젓국찌개', '포기김치', '취나물', '땅콩죽', '쌀밥', '모닝롤'],
#  ['우유', '주스', '팬케익', '포기김치', '쇠고기죽', '김자반', '쌀밥', '계란후라이', '모닝롤', '김치두부국'],
#  ['우유', '주스', '숙주나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤', '북어계란국'],
#  ['우유',
#   '옹심이만두떡국',
#   '스크램블에그',
#   '주스',
#   '어묵볶음',
#   '포기김치',
#   '쌀밥',
#   '고구마죽',
#   '모닝롤',
#   '야채샌드'],
#  ['우유', '단팥빵', '비름나물', '주스', '대구찌개', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '고추장찌개',
#   '씨크립샌드',
#   '포기김치',
#   '녹두죽',
#   '쌀밥',
#   '마늘쫑새우볶음',
#   '모닝롤'],
#  ['우유', '오징어국', '주스', '꿀호떡', '포기김치', '쌀밥', '콩나물무침', '계란후라이', '모닝롤', '호박죽'],
#  ['우유', '주스', '포기김치', '프렌치토스트', '누룽지탕', '쌀밥', '감자국', '계란후라이', '김구이', '모닝롤'],
#  ['우유', '스크램블에그', '들깨버섯국', '주스', '참치샌드', '야채죽', '도토리묵무침', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '포기김치', '아욱된장국', '누룽지탕', '롤케익', '쌀밥', '계란후라이', '모닝롤', '감자채피망볶음'],
#  ['우유', '스크램블에그', '콩자반', '주스', '팥죽', '꽃게탕', '단호박샌드', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '진미채무침', '주스', '잣죽', '포기김치', '냉이된장국', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '주스', '애호박나물', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '북어해장국'],
#  ['우유', '주스', '고구마파이', '숙주나물', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '떡국'],
#  ['우유', '스크램블에그', '주스', '참치죽', '포기김치', '쌀밥', '모닝롤', '호밧젓국찌개', '멸치볶음', '바나나샌드'],
#  ['우유',
#   '새우살죽',
#   '주스',
#   '크로와상',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '콩나물김치국',
#   '브로컬리*초장'],
#  ['우유', '들깨미역국', '스크램블에그', '주스', '핫도그', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '모닝롤'],
#  ['우유',
#   '표고버섯죽',
#   '열무된장국',
#   '주스',
#   '김가루실파무침',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '치즈프레즐'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '매운버섯국',
#   '마늘쫑볶음',
#   '모닝롤',
#   '흑임자죽',
#   '옥수수샌드'],
#  ['우유', '브라우니', '오이사과무침', '주스', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '모닝롤', '북어계란국'],
#  ['우유', '어묵국', '주스', '팬케익', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유', '스크램블에그', '주스', '포기김치', '카스텔라', '쌀밥', '쇠고기무국', '모닝롤', '호박죽', '가지나물'],
#  ['우유', '오징어국', '주스', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '모닝롤', '쑥갓두부무침'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '햄치즈샌드',
#   '포기김치',
#   '양송이죽',
#   '쌀밥',
#   '모닝롤',
#   '브로컬리들깨찜',
#   '선지해장국'],
#  ['우유', '주스', '사과파이', '포기김치', '녹두죽', '명엽채무침', '쌀밥', '계란후라이', '모닝롤', '동태탕'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '도라지나물',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '북어계란국'],
#  ['우유', '단팥빵', '주스', '마늘쫑무침', '포기김치', '누룽지탕', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유',
#   '닭죽',
#   '스크램블에그',
#   '주스',
#   '참치샌드',
#   '도토리묵*장',
#   '김치순두부찌개',
#   '포기김치',
#   '쌀밥',
#   '모닝롤'],
#  ['우유',
#   '주스',
#   '메론롤케익',
#   '포기김치',
#   '꽈리고추찜',
#   '쌀밥',
#   '소고기미역국',
#   '계란후라이',
#   '모닝롤',
#   '흑임자죽'],
#  ['우유', '열무된장국', '진미채볶음', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '우엉조림', '잣죽', '인절미샌드', '포기김치', '쌀밥', '황태국', '모닝롤'],
#  ['우유',
#   '주스',
#   '꿀호떡',
#   '포기김치',
#   '누룽지탕',
#   '맑은만두육개장',
#   '쌀밥',
#   '참나물땅콩무침',
#   '계란후라이',
#   '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '해물죽',
#   '주스',
#   '감자채볶음',
#   '단호박샌드',
#   '포기김치',
#   '쌀밥',
#   '모닝롤',
#   '콩나물김치국'],
#  ['우유', '버섯죽', '주스', '숙주나물', '크로와상', '포기김치', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤'],
#  ['우유', '주스', '시금치된장국', '구운어묵볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '꽃게탕', '견과류죽', '포기김치', '쌀밥', '김구이', '모닝롤', '야채샌드'],
#  ['우유',
#   '주스',
#   '야채죽',
#   '씨크립샌드',
#   '호박젓국찌개',
#   '포기김치',
#   '아삭고추무침',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '김치죽', '주스', '고구마파이', '청포묵무침', '포기김치', '쌀밥', '계란후라이', '모닝롤', '아욱국'],
# ...
#  ['우유', '주스', '잣죽', '열무김치', '미역국', '햄치즈샌드', '오징어젓갈무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '감자조림', '어묵탕', '포기김치', '쌀밥', '계란후라이', '고구마죽', '모닝롤', '와플'],
#  ['우유',
#   '주스',
#   '들깨시래기국',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '김가루잔파무침',
#   '치즈프레즐'],
#  ['우유', '주스', '식빵피자', '호박젓국찌개', '포기김치', '땅콩죽', '쌀밥', '계란후라이', '모닝롤', '두부쑥갓무침'],
#  ['우유',
#   '호박죽',
#   '스크램블에그',
#   '주스',
#   '청포묵무침',
#   '포기김치',
#   '쌀밥',
#   '찐빵',
#   '모닝롤',
#   '차돌박이찌개',
#   '(샐러드닭가슴살',
#   '없이)'],
#  ['우유', '베이컨샌드', '주스', '열무김치', '누룽지탕', '쌀밥', '계란후라이', '깻순나물', '모닝롤', '맑은만두국'],
#  ['우유', '호떡', '해물죽', '주스', '포기김치', '꽈리고추찜', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '진미채무침', '스크램블에그', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '황태국', '모닝롤'],
#  ['우유', '새우살죽', '스크램블에그', '에그샌드', '주스', '미역국', '포기김치', '아삭고추무침', '쌀밥', '모닝롤'],
#  ['우유', '주스', '어묵볶음', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '대구매운탕', '모닝롤'],
#  ['우유', '팥호빵', '주스', '야채죽', '무채국', '포기김치', '쌀밥', '계란후라이', '모닝롤', '멸치볶음'],
#  ['우유', '주스', '포기김치', '프렌치토스트', '연두부탕', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '시금치국', '스크램블에그', '주스', '씨크립샌드', '포기김치', '쌀밥', '고구마죽', '모닝롤', '가지나물'],
#  ['우유', '오징어국', '주스', '크로와상', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '근대국', '주스', '잣죽', '포기김치', '쌀밥', '계란후라이', '문어꽈리초조림', '모닝롤', '토마토샌드'],
#  ['우유', '주스', '팥죽', '허니브레드', '포기김치', '열무나물', '쌀밥', '계란후라이', '우거지해장국', '모닝롤'],
#  ['우유', '들깨미역국', '진미채볶음', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '스크램블에그', '주스', '참치샌드', '꽃게탕', '시금치나물', '포기김치', '쌀밥', '모닝롤'],
#  ['우유',
#   '주스',
#   '해물순두부찌개',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '애플잼쿠키',
#   '계란후라이',
#   '모닝롤',
#   '멸치볶음'],
#  ['우유', '주스', '감자채볶음', '포기김치', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤', '호박죽', '옥수수샌드'],
#  ['우유', '비름나물', '주스', '야채죽', '차돌박이찌개', '포기김치', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '주스', '시래기국', '포기김치', '누룽지탕', '쌀밥', '핫케익', '계란후라이', '김구이', '모닝롤'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '햄치즈샌드', '포기김치', '쌀밥', '무나물', '모닝롤', '흑임자죽'],
#  ['우유',
#   '콩가루배추국',
#   '알감자조림',
#   '주스',
#   '고구마파이',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '오징어국', '주스', '치킨샌드', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤', '참나물생채'],
#  ['우유', '주스', '우엉조림', '포기김치', '쌀밥', '베이글', '계란후라이', '모닝롤', '소고기죽', '감자고추장찌개'],
#  ['우유',
#   '시금치핫케익',
#   '느타리볶음',
#   '주스',
#   '두부젓국찌개',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '주스', '무채국', '포기김치', '쌀밥', '건새우마늘쫑볶음', '모닝롤', '야채샌드', '호박죽'],
#  ['우유', '단팥빵', '진미채무침', '주스', '꽃게탕', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '콩나물국', '주스', '감자샌드', '잣죽', '포기김치', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤'],
#  ['우유', '호박채나물', '해물죽', '주스', '포기김치', '롤케익', '쌀밥', '계란후라이', '황태국', '모닝롤'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '쇠고기무국',
#   '김잔파무침'],
#  ['우유',
#   '표고버섯죽',
#   '스크램블에그',
#   '주스',
#   '고추장찌개',
#   '시금치나물',
#   '고구마샌드',
#   '포기김치',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '브로컬리초장', '주스', '사과파이', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '동태탕'],
#  ['우유', '새우살죽', '멸치아몬드볶음', '주스', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤', '바나나샌드'],
#  ['우유', '주스', '핫도그', '견과류죽', '포기김치', '쌀밥', '매운버섯국', '계란후라이', '깻순나물', '모닝롤'],
#  ['우유', '핫케이크', '주스', '무채국', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '야채죽', '조랭이떡국', '포기김치', '쌀밥', '모닝롤', '야채샌드', '가지나물'],
#  ['우유', '주스', '꿀호떡', '포기김치', '연두부탕', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '열무된장국', '주스', '영양부추생채', '인절미샌드', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '콩나물국', '주스', '포기김치', '연근조림', '쌀밥', '계란후라이', '찐빵', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '호박젓국찌개', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '김잔파무침'],
#  ['우유', '닭죽', '스크램블에그', '주스', '홍루이젠', '포기김치', '쌀밥', '감자국', '모닝롤', '동전문어조림'],
#  ['우유', '주스', '고구마파이', '시래기국', '감자조림', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '해물죽', '주스', '어묵볶음', '식빵피자', '포기김치', '올챙이만두국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '잣죽', '애호박나물', '포기김치', '카스텔라', '쌀밥', '계란후라이', '모닝롤', '쇠고기샤브국'],
#  ['우유',
#   '진미채무침',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '북어해장국'],
#  ['우유', '스크램블에그', '에그샌드', '주스', '포기김치', '두부김치국', '쌀밥', '깻순나물', '모닝롤', '흑임자죽'],
#  ['우유', '열무된장국', '주스', '포기김치', '누룽지탕', '쌀밥', '단호박찐빵', '계란후라이', '모닝롤', '멸치볶음'],
#  ['우유',
#   '표고버섯죽',
#   '주스',
#   '씨크립샌드',
#   '포기김치',
#   '노각무침',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤'],
#  ['우유', '주스', '사과파이', '포기김치', '쌀밥', '계란후라이', '우거지해장국', '모닝롤', '땅콩조림', '홍게살죽'],
#  ['우유', '단팥빵', '주스', '조랭이떡국', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '참치샌드', '포기김치', '녹두죽', '쌀밥', '감자국', '모닝롤', '김잔파무침'],
#  ['우유', '새우살미역국', '느타리볶음', '주스', '크로와상', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '연두부국', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '토마토샌드', '호박죽', '가지나물'],
#  ['우유', '김치죽', '주스', '쥐포무침', '포기김치', '쌀밥', '쇠고기무국', '계란후라이', '모닝롤', '치즈프레즐'],
#  ['우유',
#   '주스',
#   '사과잼쿠키',
#   '포기김치',
#   '두부김치국',
#   '오이맛살냉채',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '주스', '팥죽', '고구마줄기볶음', '무채국', '포기김치', '쌀밥', '모닝롤', '옥수수샌드'],
#  ['우유', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '소시지감자볶음', '모닝롤', '와플', '동태탕'],
#  ['우유', '해물죽', '주스', '근대국', '볼어묵볶음', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '오징어국', '핫케이크', '주스', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '식빵피자', '포기김치', '연근조림', '호박새우젓국', '쌀밥', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '포기김치', '만두국', '누룽지탕', '롤케익', '쌀밥', '계란후라이', '모닝롤', '두부쑥갓무침'],
#  ['우유', '주스', '야채죽', '포기김치', '연두부찌개', '쌀밥', '마늘쫑볶음', '계란후라이', '모닝롤', '바나나샌드'],
#  ['우유', '된장찌개', '실곤약흑임자무침', '주스', '고구마파이', '잣죽', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '마늘빵', '누룽지탕', '명엽채무침', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '어묵국', '스크램블에그', '김치죽', '주스', '단호박샌드', '포기김치', '꽈리고추찜', '쌀밥', '모닝롤'],
#  ['우유', '열무된장국', '주스', '핫도그', '메추리알조림', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '단팥빵',
#   '오이사과무침',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '새우살야채죽',
#   '계란후라이',
#   '모닝롤',
#   '황태해장국'],
#  ['우유', '느타리볶음', '주스', '꿀호떡', '포기김치', '녹두죽', '쌀밥', '계란후라이', '대구매운탕', '모닝롤'],
#  ['우유',
#   '동전쥐포무침',
#   '주스',
#   '조랭이떡미역국',
#   '프렌치토스트',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '주스', '포기김치', '두부김치국', '땅콩죽', '쌀밥', '모닝롤', '김잔파무침', '옥수수샌드'],
#  ['우유', '주스', '시래기국', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유', '오징어국', '주스', '참치샌드', '야채죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '가지나물'],
#  ['우유', '해물죽', '주스', '영양부추생채', '포기김치', '맑은만두육개장', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '주스', '녹차호떡', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '비트무생채', '떡국'],
#  ['우유', '열무된장국', '스크램블에그', '주스', '감자샌드', '잣죽', '포기김치', '연근조림', '쌀밥', '모닝롤'],
#  ['우유', '주스', '사과파이', '포기김치', '누룽지탕', '쌀밥', '감자국', '계란후라이', '얼갈이나물', '모닝롤'],
#  ['우유',
#   '주스',
#   '시래기국',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '두반장가지볶음'],
#  ['우유', '새우살죽', '스크램블에그', '에그샌드', '순두부국', '주스', '포기김치', '검정콩조림', '쌀밥', '모닝롤'],
#  ['우유', '주스', '우엉조림', '사과파이', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '차돌박이찌개'],
#  ['우유', '주스', '단호박샌드', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤', '흑임자죽', '멸치볶음'],
#  ['우유', '주스', '야채죽', '도토리묵*장', '닭개장', '포기김치', '쌀밥', '계란후라이', '모닝롤', '시금치팬케익'],
#  ['우유', '진미채무침', '주스', '포기김치', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '배추된장국', '모닝롤'],
#  ['우유', '대구탕', '스크램블에그', '주스', '씨크립샌드', '포기김치', '쌀밥', '김구이', '고구마죽', '모닝롤'],
#  ['우유', '단팥빵', '오징어국', '주스', '포기김치', '시래기조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '들깨미역국',
#   '주스',
#   '대만샌드위치',
#   '포기김치',
#   '땅콩죽',
#   '쌀밥',
#   '느타리호박볶음',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '된장찌개', '주스', '참치죽', '포기김치', '카스텔라', '쌀밥', '계란후라이', '모닝롤', '두부쑥갓무침'],
#  ['우유', '콩나물국', '주스', '포기김치', '누룽지탕', '꽈리고추찜', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '주스', '핫도그', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '소고기무국', '땅콩조림'],
#  ['우유', '주스', '쥐포무침', '포기김치', '쌀밥', '계란후라이', '황태국', '모닝롤', '치즈프레즐', '홍게살죽'],
#  ['우유', '주스', '꿀호떡', '포기김치', '누룽지탕', '명엽채무침', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '근대국', '주스', '포기김치', '쇠고기죽', '쌀밥', '계란후라이', '미역줄기볶음', '모닝롤', '바나나샌드'],
#  ['우유',
#   '주스',
#   '크림누룽지탕',
#   '호박젓국찌개',
#   '포기김치',
#   '김자반',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '옥수수샌드'],
#  ['우유', '닭죽', '바지락국', '주스', '크로와상', '포기김치', '취나물', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '무생채', '얼갈이국', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '야채죽',
#   '고구마샌드',
#   '조랭이떡미역국',
#   '포기김치',
#   '쌀밥',
#   '모닝롤',
#   '멸치볶음'],
#  ['우유', '오징어국', '주스', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤', '와플'],
#  ['우유', '주스', '참치새드', '팥죽', '시래기국', '포기김치', '쌀밥', '계란후라이', '모닝롤', '연근땅콩조림'],
#  ['우유', '주스', '포기김치', '도라지나물', '땅콩죽', '쌀밥', '계란후라이', '모닝롤', '김치두부국', '애플파이'],
#  ['우유', '주스', '녹차호떡', '김치콩나물국', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '잣죽', '포기김치', '쌀밥', '모닝롤', '두부쑥갓무침', '야채샌드', '소고기무국'],
#  ['우유', '주스', '크로와상', '무채국', '포기김치', '누룽지탕', '꽈리고추찜', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '동전쥐포무침', '김치죽', '주스', '식빵피자', '포기김치', '꽃게된장국', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '포기김치', '열무나물', '롤케익', '쌀밥', '계란후라이', '감자국', '모닝롤', '흑임자죽'],
#  ['우유', '주스', '포기김치', '두부김치국', '마늘빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유',
#   '베이컨샌드',
#   '스크램블에그',
#   '진미채무침',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '배추된장국',
#   '모닝롤',
#   '홍게살죽'],
#  ['우유',
#   '주스',
#   '문어꽈리초조림',
#   '포기김치',
#   '오렌지케익빵',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '황태국',
#   '모닝롤'],
#  ['우유', '단팥빵', '주스', '견과류죽', '어묵볶음', '포기김치', '쌀밥', '계란후라이', '모닝롤', '아욱국'],
#  ['우유', '주스', '포기김치', '시래기조림', '녹두죽', '재첩국', '쌀밥', '계란후라이', '모닝롤', '인기가요샌드'],
#  ['우유', '주스', '핫도그', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '민물새우찌개', '모닝롤', '미역줄기볶음'],
#  ['우유', '스크램블에그', '에그샌드', '연두부국', '주스', '야채죽', '포기김치', '쌀밥', '모닝롤', '가지나물'],
#  ['우유', '대구탕', '주스', '포기김치', '연근조림', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '와플'],
#  ['우유',
#   '주스',
#   '도토리묵무침',
#   '포기김치',
#   '피바지락국',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '토마토샌드',
#   '소고기죽'],
#  ['우유', '주스', '참치죽', '메론롤케익', '포기김치', '명엽채무침', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '주스', '미역국', '초코핫케익', '포기김치', '아삭고추무침', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '잣죽', '고구마샌드', '포기김치', '연근조림', '쌀밥', '모닝롤', '북어해장국'],
#  ['우유', '주스', '조랭이떡국', '포기김치', '김자반', '누룽지탕', '쌀밥', '계란후라이', '찐빵', '모닝롤'],
#  ['우유', '된장찌개', '해물죽', '주스', '참치샌드', '포기김치', '시래기조림', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '어묵국', '주스', '팥죽', '포기김치', '무생채', '쌀밥', '계란후라이', '모닝롤', '애플파이'],
#  ['우유', '호빵', '주스', '배추시래기국', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '감자채볶음',
#   '포기김치',
#   '땅콩죽',
#   '쌀밥',
#   '꽃게된장찌개',
#   '모닝롤',
#   '옥수수샌드'],
#  ['우유', '무비트생채', '주스', '크림치즈프레즐', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '홍합탕'],
#  ['우유', '에그샌드', '주스', '야채죽', '포기김치', '쌀밥', '계란후라이', '볼어묵조림', '모닝롤', '닭곰탕'],
#  ['우유', '김치죽', '주스', '콩가루된장국', '시금치나물', '포기김치', '카스텔라', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '콩나물국', '주스', '쥐포무침', '포기김치', '오렌지케익빵', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '포기김치', '쇠고기죽', '쌀밥', '감자국', '모닝롤', '야채샌드', '쑥갓두부무침'],
#  ['우유', '단팥빵', '주스', '무채국', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '문어꽈리초조림', '모닝롤'],
#  ['우유', '주스', '포기김치', '쌀밥', '계란후라이', '황태국', '모닝롤', '미역줄기볶음', '토마토샌드', '호박죽'],
#  ['우유', '주스', '숙주나물', '참치죽', '크로와상', '포기김치', '순두부찌개', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '대구탕', '주스', '포기김치', '누룽지탕', '쌀밥', '핫케익', '계란후라이', '느타리호박볶음', '모닝롤'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '견과류죽',
#   '씨크립샌드',
#   '올갱이아욱국',
#   '포기김치',
#   '명엽채무침',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '주스', '꽃게탕', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '애플파이'],
#  ['우유', '어묵국', '주스', '식빵피자', '소라살죽', '포기김치', '쌀밥', '얼갈이나물', '계란후라이', '모닝롤'],
#  ['우유', '닭죽', '주스', '포기김치', '마늘빵', '김자반', '쌀밥', '계란후라이', '배추된장국', '모닝롤'],
#  ['우유',
#   '된장찌개',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '사과오이초무침'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '인절미샌드', '연근조림', '포기김치', '녹두죽', '쌀밥', '모닝롤'],
#  ['우유',
#   '느타리버섯볶음',
#   '주스',
#   '고구마파이',
#   '두부떡국',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '바지락국', '해물죽', '주스', '포기김치', '쌀밥', '계란후라이', '모닝롤', '야채샌드', '소시지볶음'],
#  ['우유', '주스', '야채죽', '얼갈이겉절이', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '닭곰탕'],
#  ['우유', '주스', '야채호빵', '포기김치', '누룽지탕', '쌀밥', '김구이', '계란후라이', '모닝롤', '맑은순두부국'],
#  ['우유', '스크램블에그', '콩나물국', '주스', '잣죽', '고구마샌드', '포기김치', '시래기조림', '쌀밥', '모닝롤'],
#  ['우유',
#   '주스',
#   '크로와상',
#   '차돌박이된장찌개',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '미역줄기볶음',
#   '모닝롤'],
#  ['우유', '우엉간장조림', '주스', '포기김치', '만두국', '쌀밥', '계란후라이', '모닝롤', '참치야채죽', '바나나샌드'],
#  ['우유',
#   '느타리버섯장조림',
#   '동태찌개',
#   '주스',
#   '포기김치',
#   '카스텔라',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '소고기죽'],
#  ['우유', '주스', '꿀호떡', '포기김치', '누룽지탕', '쌀밥', '어묵꽈리고추볶음', '계란후라이', '모닝롤', '순두부탕'],
#  ['우유', '새우살죽', '스크램블에그', '에그샌드', '진미채무침', '주스', '꽃게탕', '포기김치', '쌀밥', '모닝롤'],
#  ['우유', '주스', '크림누룽지탕', '미역국', '감자채볶음', '포기김치', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유',
#   '시금치핫케익',
#   '멸치아몬드볶음',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '홍합탕',
#   '홍게살죽'],
#  ['우유', '주스', '포기김치', '프렌치토스트', '김자반', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '콩나물김치국'],
#  ['우유',
#   '열무된장국',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '쌀밥',
#   '고구마죽',
#   '모닝롤',
#   '두부쑥갓무침',
#   '야채샌드'],
#  ['우유', '단팥빵', '주스', '포기김치', '누룽지탕', '쌀밥', '콩나물무침', '계란후라이', '모닝롤', '북어계란국'],
#  ['우유', '단호박죽', '대구탕', '주스', '포기김치', '쌀밥', '계란후라이', '찐빵', '모닝롤', '미역줄기볶음'],
#  ['우유', '주스', '포기김치', '연두부탕', '누룽지탕', '쌀밥', '핫케익', '계란후라이', '김구이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '견과류죽', '숙주나물', '씨크립샌드', '포기김치', '쌀밥', '매생이떡국', '모닝롤'],
#  ['우유', '어묵국', '주스', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '애플파이'],
#  ['우유', '두부양념조림', '주스', '식빵피자', '소라살죽', '포기김치', '쌀밥', '계란후라이', '모닝롤', '북어해장국'],
#  ['우유', '닭죽', '주스', '케익', '포기김치', '연근조림', '콩비지찌개', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '주스', '고추장찌개', '포기김치', '김자반', '카스텔라', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '스크램블에그', '주스', '포기김치', '감자양파국', '쌀밥', '모닝롤', '흑임자죽', '멸치볶음', '바나나샌드'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '누룽지탕',
#   '쌀밥',
#   '계란후라이',
#   '볼어묵조림',
#   '모닝롤',
#   '차돌박이찌개',
#   '치즈프레즐'],
#  ['우유', '주스', '조랭이떡국', '우엉조림', '포기김치', '녹두죽', '쌀밥', '계란후라이', '모닝롤', '옥수수샌드'],
#  ['우유', '주스', '팥죽', '연두부*장', '꿀호떡', '무채국', '포기김치', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '오징어국', '주스', '핫도그', '포기김치', '누룽지탕', '명엽채무침', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유', '표고버섯죽', '스크램블에그', '주스', '모닝에그빵', '포기김치', '봄동겉절이', '쌀밥', '와플', '동태탕'],
#  ['우유', '주스', '크로와상', '포기김치', '재첩국', '누룽지탕', '쌀밥', '딤섬', '계란후라이', '모닝롤'],
#  ['우유',
#   '피바지락배추국',
#   '주스',
#   '포기김치',
#   '땅콩죽',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '토마토샌드',
#   '크래미숙주무침'],
#  ['우유', '주스', '팬케익', '쥐포무침', '포기김치', '누룽지탕', '쌀밥', '베이글', '계란후라이', '김치두부국'],
#  ['우유', '스크램블에그', '주스', '꽃게탕', '포기김치', '쌀밥', '고구마죽', '미역줄기볶음', '모닝롤', '야채샌드'],
#  ['우유', '호빵', '주스', '포기김치', '오징어젓갈무침', '누룽지탕', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '대구탕', '주스', '참치샌드', '잣죽', '포기김치', '쌀밥', '느타리호박볶음', '계란후라이', '모닝롤'],
#  ['우유', '시금치국', '주스', '포기김치', '누룽지탕', '쌀밥', '김구이', '소보루빵', '계란후라이', '모닝롤'],
#  ['우유', '된장찌개', '스크램블에그', '진미채무침', '주스', '피자빵', '포기김치', '양송이죽', '쌀밥', '모닝롤'],
#  ['우유', '주스', '초코핫케익', '포기김치', '만두국', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유',
#   '주스',
#   '햄치즈샌드',
#   '호박젓국찌개',
#   '포기김치',
#   '쌀밥',
#   '마늘쫑볶음',
#   '계란후라이',
#   '모닝롤',
#   '흑임자죽'],
#  ['우유',
#   '주스',
#   '고구마파이',
#   '야채죽',
#   '김치도토리묵무침',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '소고기무국'],
#  ['우유',
#   '새우살미역국',
#   '배추겉절이',
#   '주스',
#   '누룽지탕',
#   '통아몬드멸치볶음',
#   '롤케익',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤'],
#  ['우유', '스크램블에그', '에그샌드', '알감자조림', '주스', '포기김치', '녹두죽', '쌀밥', '모닝롤', '떡국'],
#  ['우유', '두부양념조림', '주스', '사과파이', '무채국', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '북어맑은국',
#   '크림누룽지탕',
#   '포기김치',
#   '쌀밥',
#   '계란후라이',
#   '참나물무침',
#   '모닝롤',
#   '야채샌드'],
#  ['우유', '주스', '꽃게탕', '꿀호떡', '포기김치', '쌀밥', '계란후라이', '모닝롤', '숙주나물무침', '호박죽'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '프렌치토스트',
#   '누룽지탕',
#   '꽈리고추찜',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '김치두부국'],
#  ['우유',
#   '스크램블에그',
#   '주스',
#   '견과류죽',
#   '쥐포무침',
#   '씨크립샌드',
#   '포기김치',
#   '얼갈이된장국',
#   '쌀밥',
#   '모닝롤'],
#  ['우유', '단팥빵', '오징어국', '주스', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '김잔파무침'],
#  ['우유', '새우살죽', '주스', '참치샌드', '볼어묵볶음', '포기김치', '쌀밥', '감자국', '계란후라이', '모닝롤'],
#  ['우유', '주스', '팥죽', '포기김치', '마늘빵', '버섯매운탕', '쌀밥', '계란후라이', '모닝롤', '땅콩조림'],
#  ['우유',
#   '주스',
#   '포기김치',
#   '누룽지탕',
#   '명엽채무침',
#   '쌀밥',
#   '계란후라이',
#   '민물새우찌개',
#   '모닝롤',
#   '시금치팬케익'],
#  ['우유', '스크램블에그', '주스', '잣죽', '봄동된장국', '식빵피자', '포기김치', '쌀밥', '시금치초무침', '모닝롤'],
#  ['우유', '주스', '고구마파이', '감자채볶음', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤', '홍합탕'],
#  ['우유', '주스', '포기김치', '연두부탕', '쌀밥', '계란후라이', '모닝롤', '토마토샌드', '가지나물', '홍게살죽'],
#  ['우유', '닭죽', '주스', '호박젓국찌개', '포기김치', '김자반', '카스텔라', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '주스',
#   '무채국',
#   '포기김치',
#   '누룽지탕',
#   '연두부*참깨드레싱소스',
#   '쌀밥',
#   '계란후라이',
#   '찐빵',
#   '모닝롤'],
#  ['우유', '스크램블에그', '꽈리고추멸치볶음', '주스', '감자샌드', '포기김치', '녹두죽', '쌀밥', '황태국', '모닝롤'],
#  ['우유', '연두부국', '주스', '감자조림', '크로와상', '포기김치', '누룽지탕', '쌀밥', '계란후라이', '모닝롤'],
#  ['우유',
#   '에그샌드',
#   '해물죽',
#   '주스',
#   '포기김치',
#   '맑은만두육개장',
#   '쌀밥',
#   '계란후라이',
#   '모닝롤',
#   '숙주나물무침'],
#  ...]

# %%
# Train or load w2v model

TRAIN_W2V = True
try:
    model = Word2Vec.load('food_embedding.model')
    print("Model loaded")
except:
    if TRAIN_W2V:
        print("Training w2v")
        model = Word2Vec(sentences=food_combinations, vector_size=args.emb_dim, window=7, min_count=0, workers=4, sg=0, epochs =5000)
        model.save('food_embedding.model')
    else:
        print("Model loading failed. Do not train.")
# Out:
# Model loaded

# %%
# w2v demo
model.wv.most_similar('된장찌개')
# Out:
# [('차돌박이찌개', 0.5862919688224792),
#  ('감자국', 0.5642290115356445),
#  ('조랭이떡미역국', 0.5440123677253723),
#  ('오징어국', 0.5439069271087646),
#  ('민물새우찌개', 0.5349516868591309),
#  ('열무된장국', 0.5214429497718811),
#  ('대구매운탕', 0.5209029912948608),
#  ('얼갈이국', 0.5151638984680176),
#  ('어묵국', 0.5150087475776672),
#  ('무채국', 0.5106183886528015)]

# %% [markdown]
# # Preprocess

# %%
def process_date(df):
    df['일자'] = pd.to_datetime(df['일자'], format="%Y-%m-%d")
    df['year'] = df['일자'].dt.year
    df['month'] = df['일자'].dt.month
    df['day'] = df['일자'].dt.day
    df = df.drop('일자', axis=1)
    return df

def get_food_embedding(x):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    vec_ = np.zeros(args.emb_dim)
    for i in x_:
        vec = model.wv.get_vector(i)
        vec_ += vec
    vec_ /= len(x_)
    return vec_

# %%
# General preprocessing
df_train = process_date(df_train)
day_encoder = LabelEncoder()
df_train['요일'] = day_encoder.fit_transform(df_train['요일'])

# %%
df_train.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0   3   2601      50     150             238          0.0
# 1   4   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계  year  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0  2016
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0  2016
#
#    month  day
# 0      2    1
# 1      2    2

# %%
# Get embedding
df_train['조식메뉴_embedding'] = df_train['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['중식메뉴_embedding'] = df_train['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['석식메뉴_embedding'] = df_train['석식메뉴'].apply(lambda x: get_food_embedding(x))

# %%
y_lunch = df_train['중식계']
y_dinner = df_train['석식계']
df_train.drop(['조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계'], axis=1, inplace=True)

# %%
X_common = df_train.iloc[:, :9]
X_common.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  year  month  day
# 0   3   2601      50     150             238          0.0  2016      2    1
# 1   4   2601      50     173             319          0.0  2016      2    2

# %%
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # 점심메뉴단어임베딩벡터 추가 
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # 저녁메뉴단어임베딩벡터 추가

X_train_lunch = np.concatenate((X_common.to_numpy(), emb_arr_lunch), axis=1)
X_train_dinner = np.concatenate((X_common.to_numpy(), emb_arr_dinner), axis=1)

# %%
X_train_lunch.shape
# Out:
# (1205, 209)

# %%
X_train_dinner.shape
# Out:
# (1205, 209)

# %%
X_train_lunch, X_test_lunch, y_train_lunch, y_test_lunch = train_test_split(X_train_lunch, y_lunch, test_size=0.1, random_state=42)
X_train_dinner, X_test_dinner, y_train_dinner, y_test_dinner = train_test_split(X_train_dinner, y_dinner, test_size=0.1, random_state=42)

# %% [markdown]
# # Modeling

# %%
# Simple LGBM Regressor w/o tuning
model_lunch = LGBMRegressor()
model_lunch.fit(X_train_lunch, y_train_lunch)

model_dinner = LGBMRegressor()
model_dinner.fit(X_train_dinner, y_train_dinner)

# Validate
pred_lunch = model_lunch.predict(X_test_lunch)
pred_dinner = model_dinner.predict(X_test_dinner)

print("lunch mae: ", mean_absolute_error(y_test_lunch, pred_lunch))
print("dinner mae: ", mean_absolute_error(y_test_dinner, pred_dinner))
# Out:
# lunch mae:  81.13258088998049
# dinner mae:  47.23218586192287

# %% [markdown]
# # Inference

# %%
df_test = pd.read_csv('../data/test.csv')

# Apply general preprocessing
df_test= process_date(df_test)
df_test['요일'] = day_encoder.transform(df_test['요일'])
df_test['조식메뉴_embedding'] = df_test['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_test['중식메뉴_embedding'] = df_test['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_test['석식메뉴_embedding'] = df_test['석식메뉴'].apply(lambda x: get_food_embedding(x))
df_test.drop(['조식메뉴', '중식메뉴', '석식메뉴'], axis=1, inplace=True)
X_test_common = df_test.iloc[:, :9]

# %%
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # Ver 2
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # Ver 2

# %%
# Get embedding
test_emb_arr_lunch = np.array(df_test.iloc[:, 10].to_numpy().tolist()) # Ver 2
test_emb_arr_dinner = np.array(df_test.iloc[:, 11].to_numpy().tolist()) # Ver 2
# Concat
test_lunch = np.concatenate((X_test_common.to_numpy(), test_emb_arr_lunch), axis=1)
test_dinner = np.concatenate((X_test_common.to_numpy(), test_emb_arr_dinner), axis=1)

# %%
# Inference

test_pred_lunch = model_lunch.predict(test_lunch)
test_pred_dinner = model_dinner.predict(test_dinner)

submission_df = pd.read_csv('../data/sample_submission.csv')
submission_df['중식계'] = test_pred_lunch
submission_df['석식계'] = test_pred_dinner

# %%
# Save

submission_df.to_csv('../sub_2nd_0618.csv', index=False)
